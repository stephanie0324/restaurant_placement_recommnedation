# %% [markdown]
# # Create the features DF
# * using by_postal_code dataset

# %% [markdown]
# # Import

# %%
import pandas as pd
import json
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
import pickle
import math 
from sklearn.model_selection import train_test_split

from scipy import sparse as sp
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

# %%
RANDOM_STATE = 24

# %%
res_df = pd.read_pickle ('/home/adam/Steph_C/my_thesis/data/ORI_by_postal_code_s_dropped.pkl').reset_index(drop=True)
venue_df = pd.read_pickle ('../Data/yelp/other_venues.pkl').reset_index(drop=True)
all_df = pd.read_pickle('../Data/yelp/restaurant_only.pkl')

# %%
print(res_df.shape , venue_df.shape , all_df.shape)
# Out:
# (192547, 20) (700010, 20) (2112553, 20)

# %%
# drop duplicates
df = pd.concat([all_df,venue_df]) # for check in calculation
res_df = res_df.drop_duplicates(subset=['name','postal_code']).reset_index(drop=True)
venue_df = venue_df.drop_duplicates(subset=['name','postal_code']).reset_index(drop=True)
all_df = all_df.drop_duplicates(subset=['name','postal_code']).reset_index(drop=True)

# %%
# drop postal_codes not in U.S
drop_postal = [i for i in range(len(all_df)) if not all_df.postal_code[i].isdigit()]
all_df = all_df.drop(drop_postal).reset_index(drop=True)

# %%
print(res_df.shape , venue_df.shape , df.shape , all_df.shape)
# Out:
# (1848, 20) (14791, 20) (2812563, 20) (19901, 20)

# %%
len(Counter(res_df.name))
# Out:
# 405

# %%
# create relevance score
cnt = 0
new_df = pd.DataFrame()
for i in Counter(res_df.name):
    tmp = res_df[res_df.name==i].reset_index(drop=True)
    tmp['relevance']=''
    score = 12
    for j in range(len(tmp)):
        tmp['relevance'][j]=score
        score -=1
    new_df = pd.concat([new_df,tmp])

# check the shape
if new_df.shape[0] != res_df.shape[0]:
    print(f'There is a mistake creating the relevance score')
else:
    print(f'Relevance score added')
res_df = new_df
# Out:
# /home/adam/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# Relevance score added

# %%
# create a overall postal_code features
# postal code and feature dict
postal_code_feature_dict = {}

for postal in Counter(all_df.postal_code):
    
    postal_code_feature_dict[postal]={}
    tmp = df[df.postal_code == postal].reset_index(drop=True)
    tmp_venue = venue_df[venue_df == postal].reset_index(drop=True)
    
    # density 
    postal_code_feature_dict[postal]['density'] = len(Counter(tmp.name))
    
    # neighborhood_entropy
    entropy_sum = 0
    for category in Counter(tmp.categories):
        entropy_sum+=(len(Counter(tmp[tmp.categories==category].name))/len(Counter(tmp.name)))\
        *np.log(len(Counter(tmp[tmp.categories==category].name))/len(Counter(tmp.name)))
    postal_code_feature_dict[postal]['entropy'] = -entropy_sum
    
    # area popularity
    postal_code_feature_dict[postal]['area_pop'] = len(tmp)
    
    # traffic accessibility + complementary
    transportation_cnt = 0
    dep_cnt = 0
    parking_cnt =0
    
    store_cnt = len(Counter(tmp_venue.name))
    
    for i in range(len(tmp_venue)):
        try:
            if 'Public Transportation' in tmp_venue.categories[i]:
                transportation_cnt+=1
            if 'Department Stores' in tmp_venue.categories[i]:
                dep_cnt+=1
            if 'Parking' in tmp_venue.categories[i]:
                parking_cnt+=1
        except:
            pass
    
    postal_code_feature_dict[postal]['accessibility'] = transportation_cnt
    if store_cnt >1:
        postal_code_feature_dict[postal]['complementary'] = (2*(dep_cnt+parking_cnt) )/(store_cnt*(store_cnt-1)) 
    else:
        postal_code_feature_dict[postal]['complementary']=0

# %%
len(postal_code_feature_dict)
# Out:
# 750

# %%
# # # to check the features
# postal_df = pd.DataFrame(postal_code_feature_dict).T.reset_index().rename(columns={'index': 'postal_code'})
# postal_df
# # Counter(postal_df.complementary)

# %% [markdown]
# # Train Test Split with Feature Engineering

# %%
def create_new (new ,category,postal, all_df, postal_df):
    
    new = new.drop(columns=['density', 'entropy','area_pop', 'accessibility', 'complementary'])
    new['postal_code'] = postal
    new = pd.DataFrame(new.merge(postal_df, on='postal_code', how='left'))
    new['relevance'] = 0
    # add competitiveness
    new['competitiveness']=''
    place = all_df[all_df.postal_code == postal].reset_index(drop=True)
    new['competitiveness'] = -(len(Counter(place[place.categories == category].name))\
                                  /len(Counter(place.name)))
    # TO-DO Add reviews
    
    return new

# %% [markdown]
# ## Pointwise

# %%
# # POINTWISE v1
# # split train test 
# # 拿每一個餐廳一半的分店當作 testing set (雖然大部分只有兩家分店)

# cnt = 0
# train_df = pd.DataFrame()
# test_df = pd.DataFrame()
# pos_train_post = Counter()
# neg_train_post ={}

# for i in Counter(res_df.name):
    
    
#     tmp = res_df[res_df.name==i]
#     tmp_train , tmp_test = train_test_split(tmp, test_size=0.33, shuffle= True,random_state=RANDOM_STATE)
    
#     postal_df = pd.DataFrame(postal_code_feature_dict).T.reset_index().rename(columns={'index': 'postal_code'})
#     postal_df = postal_df.sort_values(['postal_code'],
#               ascending = [True]).reset_index(drop=True)
    
    
#     # merge with location features
#     tmp_train = pd.DataFrame(tmp_train.merge(postal_df, on='postal_code', how='left')).reset_index(drop=True)
#     tmp_test = pd.DataFrame(tmp_test.merge(postal_df, on='postal_code', how='left')).reset_index(drop=True)
    
#     pos_train_post += Counter(tmp_train.postal_code)
#     ori_train, ori_test = tmp_train.shape , tmp_test.shape
    
#     ############################## reconstruct ################################
#     postal_codes_list_train = list(postal_df.postal_code)
#     postal_codes_list_test= list(postal_df.postal_code)
    
    
#     for j in Counter(tmp_train.postal_code):
#         postal_codes_list_train.remove(j)
#         postal_codes_list_test.remove(j)
    
#     for j in Counter(tmp_test.postal_code):
#         postal_codes_list_train.remove(j)
#         postal_codes_list_test.remove(j)
    
    
#     ## train 
#     tmp_train['competitiveness'] =''
#     neg_df = pd.DataFrame()
    
#     for j in range(len(tmp_train)):
        
#         cnt =0 
#         category = tmp_train.categories[j]

        
#         # add competitiveness
#         place = all_df[all_df.postal_code == tmp_train['postal_code'][j]]
#         tmp_train['competitiveness'][j] = -(len(Counter(place[place.categories == category].name))/len(Counter(place.name)))
    
#         ## TO-DO Add reviews 
        
#         # add the negative samples
#         for k in range(len(postal_df)):
#             if cnt<2:
#                 if postal_df.postal_code[k] in postal_codes_list_train and\
#                 abs(int(postal_df.postal_code[k])- int(tmp_train['postal_code'][j])) <= 1000:
#                     cnt+=1
#                     new = pd.DataFrame(tmp_train.iloc[j]).T.reset_index(drop=True)
#                     new = create_new (new ,category, all_df, postal_df)
#                     neg_df = pd.concat([neg_df ,new ])
    
#                     ##### create a negative sample dict
#                     if postal_df.postal_code[k] in neg_train_post:
#                         neg_train_post[postal_df.postal_code[k]] +=1
#                     else:
#                         neg_train_post[postal_df.postal_code[k]]=1
#             else:
#                 break
    
#     tmp_train = pd.concat([tmp_train ,neg_df ])
    
#     ## test 
    
#     tmp_test['competitiveness'] =''
    
#     neg_df = pd.DataFrame()
#     for j in range(len(tmp_test)):
#         cnt =0
#         category = tmp_test.categories[j]
#         # add competitiveness
#         place = all_df[all_df.postal_code == tmp_test['postal_code'][j]]
#         tmp_test['competitiveness'][j] = -(len(Counter(place[place.categories == tmp_test.categories[j]].name))/len(Counter(place.name)))
        
#         # TO-DO add review 
        
#         # add negative samples
#         for k in range(len(postal_df)):
#             if cnt<2:
#                 if postal_df.postal_code[k] in postal_codes_list_test and\
#                 abs(int(postal_df.postal_code[k])-int(tmp_test['postal_code'][j])) <= 1000:
#                     cnt+=1
#                     new = pd.DataFrame(tmp_test.iloc[j]).T.reset_index(drop=True)
#                     new = create_new (new ,category, all_df, postal_df)
#                     neg_df = pd.concat([neg_df ,new ])
#             else:
#                 break
                
#     tmp_test = pd.concat([tmp_test ,neg_df ])   
#     if int(tmp_train.shape[0]) != int(ori_train[0]*3) or int(tmp_test.shape[0]) != int(ori_test[0]*3):
#         print('Original: ' ,ori_train, ori_test )
#         print('After : ',tmp_train.shape[0] , tmp_test.shape[0])
#         print(f'There is sth wrong !!!!!!!!')
#         break
    
#     train_df =  pd.concat([train_df ,tmp_train ])
#     test_df =  pd.concat([test_df ,tmp_test ])
# print(f'Finished constructing....  train : {len(Counter(train_df.name))} test : {len(Counter(test_df.name))}')

# %%
# # # POINTWISE v2
# # # 取每間餐廳分店中郵遞區號最大，取其 +-500 的所有地區 再去切 train test
# # # split train test 
# train_df = pd.DataFrame()
# test_df = pd.DataFrame()

# for i in Counter(res_df.name):
    
#     tmp = res_df[res_df.name==i].sort_values(['postal_code'],ascending = [False]).reset_index(drop=True)
#     max_postal = max(tmp.postal_code.astype(int))
#     category = tmp.categories[0]
#     postal_df = pd.DataFrame(postal_code_feature_dict).T.reset_index().rename(columns={'index': 'postal_code'})
#     postal_df = postal_df.sort_values(['postal_code'],ascending = [True]).reset_index(drop=True)
#     postal_codes_list = list(postal_df.postal_code)
    
#     # remove the known postal codes
#     for postal in Counter(tmp.postal_code):
#         postal_codes_list.remove(postal)

#     # merge with location features
#     tmp = pd.DataFrame(tmp.merge(postal_df, on='postal_code', how='left')).reset_index(drop=True)
    
#     # add competitiveness and review (TO-DO)
#     tmp['competitiveness']= ''
# #     tmp['review']= ''
#     for j in range(len(tmp)):
        
#         # competitiveness
#         place = all_df[all_df.postal_code == tmp['postal_code'][j]]
#         tmp['competitiveness'][j] = -(len(Counter(place[place.categories == category].name))/len(Counter(place.name)))

    
#     # create negative 
#     neg_df = pd.DataFrame()
#     cnt = 0 
    
#     for j in range(len(postal_df)):
#         if cnt > 20 :
#             break
#         if postal_df.postal_code[j] in postal_codes_list and \
#         abs(max_postal - int(postal_df.postal_code[j])) <= 500:
#             cnt+=1
#             new = pd.DataFrame(tmp.iloc[0]).T.reset_index(drop=True)
#             postal_codes_list.remove(postal_df.postal_code[j])
#             new = create_new (new ,category, all_df, postal_df)
#             neg_df = pd.concat([neg_df ,new ])

#     if len(neg_df)<3:
#         print(f'Something is wrong with the shape of the neg sample for {i}')
#         break
    
#     # train test split
#     tmp_train , tmp_test = train_test_split(tmp, test_size=0.33, shuffle= True,random_state=RANDOM_STATE)
#     neg_train , neg_test = train_test_split(neg_df, test_size=0.33, shuffle= True,random_state=RANDOM_STATE)
    
    
#     # merge with neg
#     tmp_train = pd.concat([tmp_train,neg_train])
#     tmp_test = pd.concat([tmp_test,neg_test])
    
#     train_df = pd.concat([train_df,tmp_train])
#     test_df = pd.concat([test_df,tmp_test])

# %%
# # POINTWISE v3
# 2-4 間分店用方法一取負樣本，其他參照方法二（解決2-4間分店開在非常遙遠的地方）
# # split train test 

train_df = pd.DataFrame()
test_df = pd.DataFrame()

for i in Counter(res_df.name):
    
    max_postal = max(tmp.postal_code.astype(int))
    category = tmp.categories[0]
    
    tmp = res_df[res_df.name==i].sort_values(['postal_code'],ascending = [False]).reset_index(drop=True)
    postal_df = pd.DataFrame(postal_code_feature_dict).T.reset_index().rename(columns={'index': 'postal_code'})
    postal_df = postal_df.sort_values(['postal_code'],ascending = [True]).reset_index(drop=True)
    postal_codes_list = list(postal_df.postal_code)
    
    # remove the known postal codes
    for postal in Counter(tmp.postal_code):
        postal_codes_list.remove(postal)

    # merge with location features
    tmp = pd.DataFrame(tmp.merge(postal_df, on='postal_code', how='left')).reset_index(drop=True)
    
    # add competitiveness and review (TO-DO)
    tmp['competitiveness']= ''
#     tmp['review']= ''
    for j in range(len(tmp)):
        
        # competitiveness
        place = all_df[all_df.postal_code == tmp['postal_code'][j]]
        tmp['competitiveness'][j] = -(len(Counter(place[place.categories == category].name))/len(Counter(place.name)))
        
        # TO-DO add review

    # 看差距過大的店家
    if max(tmp.postal_code.astype(int))- min(tmp.postal_code.astype(int)) > 10000 and len(tmp)<4:

        # train test split
        tmp_train , tmp_test = train_test_split(tmp, test_size=0.33, shuffle= True,random_state=RANDOM_STATE)
        tmp_train = tmp_train.reset_index(drop=True)
        tmp_test = tmp_test.reset_index(drop=True)
        
        ## train 
        neg_df = pd.DataFrame()

        for j in range(len(tmp_train)):

            cnt =0 
            category = tmp_train.categories[j]

            # add the negative samples
            for k in range(len(postal_df)):
                if cnt<2:
                    if postal_df.postal_code[k] in postal_codes_list and\
                    abs(int(postal_df.postal_code[k])- int(tmp_train['postal_code'][j])) <= 1000:
                        cnt+=1
                        new = pd.DataFrame(tmp_train.iloc[j]).T.reset_index(drop=True)
                        postal_codes_list.remove(postal_df.postal_code[k])
                        new = create_new (new ,category,postal_df.postal_code[k], all_df, postal_df)
                        neg_df = pd.concat([neg_df ,new ])
                else:
                    break
        print(f' over 100000 {i}pos : {tmp_test.postal_code}  train : {neg_df.postal_code}')
#         tmp_train = pd.concat([tmp_train ,neg_df ])

        ## test 

        neg_df = pd.DataFrame()
        for j in range(len(tmp_test)):
            cnt =0
            category = tmp_test.categories[j]

            # add negative samples
            for k in range(len(postal_df)):
                if cnt<2:
                    if postal_df.postal_code[k] in postal_codes_list and\
                    abs(int(postal_df.postal_code[k])-int(tmp_test['postal_code'][j])) <= 1000:
                        cnt+=1
                        new = pd.DataFrame(tmp_test.iloc[j]).T.reset_index(drop=True)
                        postal_codes_list.remove(postal_df.postal_code[k])
                        new = create_new (new ,category,postal_df.postal_code[k], all_df, postal_df)
                        neg_df = pd.concat([neg_df ,new ])
                else:
                    break
        print(f' over 100000 {i} pos : {tmp_test.postal_code} test : {neg_df.postal_code}')
#         tmp_test = pd.concat([tmp_test ,neg_df ])
        
    else:
        # create negative 
        neg_df = pd.DataFrame()
        cnt = 0 

        for j in range(len(postal_df)):
            if cnt > 20 :
                break
            if postal_df.postal_code[j] in postal_codes_list and \
            abs(max_postal - int(postal_df.postal_code[j])) <= 500:
                cnt+=1
                new = pd.DataFrame(tmp.iloc[0]).T.reset_index(drop=True)
                new = new.drop(columns=['density', 'entropy','area_pop', 'accessibility', 'complementary'])
                new['postal_code'] = postal_df.postal_code[j]
                postal_codes_list.remove(postal_df.postal_code[j])
                new = pd.DataFrame(new.merge(postal_df, on='postal_code', how='left'))
                new['relevance'] = 0
                # add competitiveness
                new['competitiveness']=''
                place = all_df[all_df.postal_code == postal_df.postal_code[j]].reset_index(drop=True)
                new['competitiveness'] = -(len(Counter(place[place.categories ==category].name))/len(Counter(place.name)))

                # TO-DO add review 
                neg_df = pd.concat([neg_df ,new ])
        
        print(f' below 10000 {i} pos : {tmp.postal_code}  : {neg_df.postal_code}')

        if len(neg_df)<3:
            print(f'Something is wrong with the shape of the neg sample for {i}')
            break
        
        # train test split
        tmp_train , tmp_test = train_test_split(tmp, test_size=0.33, shuffle= True,random_state=RANDOM_STATE)
        neg_train , neg_test = train_test_split(neg_df, test_size=0.33, shuffle= True,random_state=RANDOM_STATE)
        # merge with neg
        tmp_train = pd.concat([tmp_train,neg_train])
        tmp_test = pd.concat([tmp_test,neg_test])

#     train_df = pd.concat([train_df,tmp_train])
#     test_df = pd.concat([test_df,tmp_test])
# print(f'Finished constructing....  train res cnt  : {len(Counter(train_df.name))} test res cnt : {len(Counter(test_df.name))}')
# Out:
# /home/adam/.local/lib/python3.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#  below 10000 On The Border Mexican Grill & Cantina pos : 0    46250
# 1    46142
# 2    46123
# 3    19341
# 4    19020
# 5    08054
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46140
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# 0    46201
# 0    46202
# Name: postal_code, dtype: object
#  below 10000 China Kitchen pos : 0    89523
# 1    70056
# 2    34609
# 3    33701
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 Landry's Seafood House pos : 0    70130
# 1    70124
# 2    63103
# Name: postal_code, dtype: object  : 0    89431
# 0    89432
# 0    89433
# 0    89434
# 0    89436
# 0    89439
# 0    89440
# 0    89441
# 0    89501
# 0    89502
# 0    89503
# 0    89506
# 0    89508
# 0    89509
# 0    89511
# 0    89512
# 0    89519
# 0    89521
# 0    89523
# 0    89595
# Name: postal_code, dtype: object
#  below 10000 Mariscos Chihuahua pos : 0    85745
# 1    85741
# 2    85713
# Name: postal_code, dtype: object  : 0    70001
# 0    70002
# 0    70003
# 0    70005
# 0    70006
# 0    70032
# 0    70037
# 0    70043
# 0    70053
# 0    70056
# 0    70058
# 0    70062
# 0    70065
# 0    70070
# 0    70072
# 0    70075
# 0    70087
# 0    70092
# 0    70094
# 0    70112
# 0    70113
# Name: postal_code, dtype: object
#  below 10000 Burger Republic pos : 0    37211
# 1    37203
# 2    37122
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85713
# 0    85714
# 0    85715
# 0    85716
# 0    85718
# 0    85719
# Name: postal_code, dtype: object
#  below 10000 Tandoor & Tikka pos : 0    46268
# 1    46250
# 2    46202
# Name: postal_code, dtype: object  : 0    37012
# 0    37013
# 0    37015
# 0    37024
# 0    37027
# 0    37043
# 0    37064
# 0    37066
# 0    37067
# 0    37069
# 0    37072
# 0    37073
# 0    37075
# 0    37076
# 0    37080
# 0    37082
# 0    37086
# 0    37090
# 0    37115
# 0    37122
# 0    37135
# Name: postal_code, dtype: object
#  below 10000 Giordano's pos : 0    46250
# 1    46227
# 2    46204
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 Pizzeria Vetri pos : 0    19406
# 1    19130
# 2    19103
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  over 100000 Johnny Rocketspos : 0    89595
# Name: postal_code, dtype: object  train : 0    37012
# 0    37013
# 0    33503
# 0    33510
# Name: postal_code, dtype: object
#  over 100000 Johnny Rockets pos : 0    89595
# Name: postal_code, dtype: object test : 0    89431
# 0    89432
# Name: postal_code, dtype: object
#  below 10000 HipCityVeg pos : 0    19107
# 1    19103
# 2    19003
# Name: postal_code, dtype: object  : 0    89431
# 0    89432
# 0    89433
# 0    89434
# 0    89436
# 0    89439
# 0    89440
# 0    89441
# 0    89501
# 0    89502
# 0    89503
# 0    89506
# 0    89508
# 0    89509
# 0    89511
# 0    89512
# 0    89519
# 0    89521
# 0    89523
# 0    89595
# Name: postal_code, dtype: object
#  below 10000 Ekta Indian Cuisine pos : 0    19125
# 1    19104
# 2    19010
# Name: postal_code, dtype: object  : 0    18901
# 0    18902
# 0    18912
# 0    18913
# 0    18914
# 0    18915
# 0    18917
# 0    18928
# 0    18929
# 0    18931
# 0    18932
# 0    18936
# 0    18938
# 0    18940
# 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# Name: postal_code, dtype: object
#  below 10000 Firebirds Wood Fired Grill pos : 0    85718
# 1    63303
# 2    37027
# 3    19713
# 4    19454
# 5    19426
# 6    19317
# 7    08057
# Name: postal_code, dtype: object  : 0    18901
# 0    18902
# 0    18912
# 0    18913
# 0    18914
# 0    18915
# 0    18917
# 0    18928
# 0    18929
# 0    18931
# 0    18932
# 0    18936
# 0    18938
# 0    18940
# 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# Name: postal_code, dtype: object
#  below 10000 Dave & Buster's pos : 0     85713
# 1     83704
# 2     70113
# 3     63043
# 4     46250
# 5     46142
# 6     37214
# 7     33619
# 8     19462
# 9     19154
# 10    19106
# 11    08012
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85714
# 0    85715
# 0    85716
# 0    85718
# 0    85719
# 0    85730
# Name: postal_code, dtype: object
#  below 10000 Noble Crust pos : 0    33702
# 1    33618
# 2    33543
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85713
# 0    85714
# 0    85715
# 0    85716
# 0    85718
# 0    85719
# Name: postal_code, dtype: object
#  below 10000 The Hungry Greek pos : 0    33626
# 1    33618
# 2    33558
# 3    33544
# Name: postal_code, dtype: object  : 0    33503
# 0    33510
# 0    33511
# 0    33534
# 0    33541
# 0    33542
# 0    33543
# 0    33545
# 0    33547
# 0    33548
# 0    33549
# 0    33556
# 0    33559
# 0    33563
# 0    33565
# 0    33566
# 0    33568
# 0    33569
# 0    33570
# 0    33572
# 0    33573
# Name: postal_code, dtype: object
#  below 10000 Sauce on the Side pos : 0    63303
# 1    63110
# 2    63105
# 3    63101
# 4    46204
# 5    46032
# Name: postal_code, dtype: object  : 0    33503
# 0    33510
# 0    33511
# 0    33534
# 0    33541
# 0    33542
# 0    33543
# 0    33544
# 0    33545
# 0    33547
# 0    33548
# 0    33549
# 0    33556
# 0    33558
# 0    33559
# 0    33563
# 0    33565
# 0    33566
# 0    33568
# 0    33569
# 0    33570
# Name: postal_code, dtype: object
#  below 10000 Carmelita's Mexican Restaurant pos : 0    33781
# 1    33771
# 2    33709
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  below 10000 Han Dynasty pos : 0    19468
# 1    19341
# 2    19127
# 3    19106
# 4    19104
# 5    08034
# Name: postal_code, dtype: object  : 0    33503
# 0    33510
# 0    33511
# 0    33534
# 0    33541
# 0    33542
# 0    33543
# 0    33544
# 0    33545
# 0    33547
# 0    33548
# 0    33549
# 0    33556
# 0    33558
# 0    33559
# 0    33563
# 0    33565
# 0    33566
# 0    33568
# 0    33569
# 0    33570
# Name: postal_code, dtype: object
#  below 10000 Joe's Crab Shack pos : 0    83706
# 1    37201
# 2    33759
# 3    08096
# Name: postal_code, dtype: object  : 0    18969
# 0    18974
# 0    18976
# 0    18977
# 0    18984
# 0    19001
# 0    19002
# 0    19003
# 0    19004
# 0    19006
# 0    19007
# 0    19008
# 0    19010
# 0    19012
# 0    19013
# 0    19014
# 0    19015
# 0    19018
# 0    19020
# 0    19021
# 0    19022
# Name: postal_code, dtype: object
#  below 10000 Mamas Kitchen pos : 0    33772
# 1    33612
# 2    33611
# Name: postal_code, dtype: object  : 0    83616
# 0    83634
# 0    83642
# 0    83646
# 0    83702
# 0    83703
# 0    83704
# 0    83705
# 0    83706
# 0    83707
# 0    83709
# 0    83712
# 0    83713
# 0    83714
# 0    83716
# Name: postal_code, dtype: object
#  below 10000 Fellini Cafe pos : 0    19380
# 1    19073
# 2    19010
# Name: postal_code, dtype: object  : 0    33503
# 0    33510
# 0    33511
# 0    33534
# 0    33541
# 0    33542
# 0    33543
# 0    33544
# 0    33545
# 0    33547
# 0    33548
# 0    33549
# 0    33556
# 0    33558
# 0    33559
# 0    33563
# 0    33565
# 0    33566
# 0    33568
# 0    33569
# 0    33570
# Name: postal_code, dtype: object
#  below 10000 Earl of Sandwich pos : 0    83646
# 1    33703
# 2    33635
# 3    33607
# 4    19153
# Name: postal_code, dtype: object  : 0    18901
# 0    18902
# 0    18912
# 0    18913
# 0    18914
# 0    18915
# 0    18917
# 0    18928
# 0    18929
# 0    18931
# 0    18932
# 0    18936
# 0    18938
# 0    18940
# 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# Name: postal_code, dtype: object
#  below 10000 sweetgreen pos : 0    19406
# 1    19107
# 2    19104
# 3    19103
# 4    19003
# Name: postal_code, dtype: object  : 0    83616
# 0    83634
# 0    83642
# 0    83646
# 0    83702
# 0    83703
# 0    83704
# 0    83705
# 0    83706
# 0    83707
# 0    83709
# 0    83712
# 0    83713
# 0    83714
# 0    83716
# Name: postal_code, dtype: object
#  below 10000 honeygrow pos : 0     19803
# 1     19702
# 2     19406
# 3     19122
# 4     19107
# 5     19104
# 6     19102
# 7     19087
# 8     19004
# 9     08053
# 10    08034
# Name: postal_code, dtype: object  : 0    18912
# 0    18913
# 0    18914
# 0    18915
# 0    18917
# 0    18928
# 0    18929
# 0    18931
# 0    18932
# 0    18936
# 0    18938
# 0    18940
# 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# 0    18964
# 0    18966
# Name: postal_code, dtype: object
#  below 10000 Las Palmas Mexican Restaurant pos : 0    63132
# 1    37211
# 2    37209
# 3    37204
# 4    37203
# 5    37076
# 6    37072
# 7    37027
# Name: postal_code, dtype: object  : 0    19311
# 0    19312
# 0    19317
# 0    19320
# 0    19331
# 0    19333
# 0    19335
# 0    19341
# 0    19342
# 0    19343
# 0    19348
# 0    19353
# 0    19355
# 0    19357
# 0    19372
# 0    19374
# 0    19375
# 0    19380
# 0    19382
# 0    19395
# 0    19401
# Name: postal_code, dtype: object
#  below 10000 BJ's Restaurant & Brewhouse pos : 0    89511
# 1    89434
# 2    85711
# 3    85705
# 4    46142
# 5    46123
# 6    33781
# 7    33761
# 8    33625
# 9    33559
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  below 10000 The Pasta House pos : 0    63141
# 1    63124
# 2    63123
# 3    63074
# 4    63033
# 5    63011
# 6    62025
# Name: postal_code, dtype: object  : 0    89431
# 0    89432
# 0    89433
# 0    89434
# 0    89436
# 0    89439
# 0    89440
# 0    89441
# 0    89501
# 0    89502
# 0    89503
# 0    89506
# 0    89508
# 0    89509
# 0    89511
# 0    89512
# 0    89519
# 0    89521
# 0    89523
# 0    89595
# Name: postal_code, dtype: object
#  below 10000 Louis Pappas Fresh Greek pos : 0    33761
# 1    33629
# 2    33626
# 3    33607
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  below 10000 Tokyo Mandarin pos : 0    08096
# 1    08085
# 2    08028
# Name: postal_code, dtype: object  : 0    33503
# 0    33510
# 0    33511
# 0    33534
# 0    33541
# 0    33542
# 0    33543
# 0    33544
# 0    33545
# 0    33547
# 0    33548
# 0    33549
# 0    33556
# 0    33558
# 0    33559
# 0    33563
# 0    33565
# 0    33566
# 0    33568
# 0    33569
# 0    33570
# Name: postal_code, dtype: object
#  below 10000 Cheddar's Scratch Kitchen pos : 0     85716
# 1     62208
# 2     46237
# 3     46123
# 4     37167
# 5     37122
# 6     37075
# 7     37027
# 8     33781
# 9     33760
# 10    33618
# 11    33559
# Name: postal_code, dtype: object  : 0    08002
# 0    08003
# 0    08004
# 0    08007
# 0    08009
# 0    08010
# 0    08012
# 0    08016
# 0    08020
# 0    08021
# 0    08022
# 0    08026
# 0    08028
# 0    08029
# 0    08030
# 0    08031
# 0    08033
# 0    08034
# 0    08035
# 0    08036
# 0    08037
# Name: postal_code, dtype: object
#  below 10000 Gyro Shack pos : 0    83709
# 1    83703
# 2    83646
# 3    83642
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85713
# 0    85714
# 0    85715
# 0    85716
# 0    85718
# 0    85719
# Name: postal_code, dtype: object
#  below 10000 Joey's New York Pizza and Italian Restaurant pos : 0    34684
# 1    34654
# 2    34652
# Name: postal_code, dtype: object  : 0    83616
# 0    83634
# 0    83642
# 0    83646
# 0    83702
# 0    83703
# 0    83704
# 0    83705
# 0    83706
# 0    83707
# 0    83709
# 0    83712
# 0    83713
# 0    83714
# 0    83716
# Name: postal_code, dtype: object
#  over 100000 Granite City Food & Brewerypos : 0    63141
# Name: postal_code, dtype: object  train : 0    46032
# 0    46033
# 0    37012
# 0    37013
# Name: postal_code, dtype: object
#  over 100000 Granite City Food & Brewery pos : 0    63141
# Name: postal_code, dtype: object test : 0    62201
# 0    62203
# Name: postal_code, dtype: object
#  below 10000 Another Broken Egg Cafe pos : 0    70124
# 1    70115
# 2    46260
# 3    46250
# 4    46038
# 5    37209
# 6    37201
# 7    33767
# 8    33761
# 9    33611
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  below 10000 Wayback Burgers pos : 0     89502
# 1     37209
# 2     33563
# 3     33547
# 4     19468
# 5     19460
# 6     19382
# 7     19372
# 8     19348
# 9     18914
# 10    08043
# Name: postal_code, dtype: object  : 0    70001
# 0    70002
# 0    70003
# 0    70005
# 0    70006
# 0    70032
# 0    70037
# 0    70043
# 0    70053
# 0    70056
# 0    70058
# 0    70062
# 0    70065
# 0    70070
# 0    70072
# 0    70075
# 0    70087
# 0    70092
# 0    70094
# 0    70112
# 0    70113
# Name: postal_code, dtype: object
#  below 10000 El Charro Cafe pos : 0    85750
# 1    85704
# 2    85701
# Name: postal_code, dtype: object  : 0    89431
# 0    89432
# 0    89433
# 0    89434
# 0    89436
# 0    89439
# 0    89440
# 0    89441
# 0    89501
# 0    89502
# 0    89503
# 0    89506
# 0    89508
# 0    89509
# 0    89511
# 0    89512
# 0    89519
# 0    89521
# 0    89523
# 0    89595
# Name: postal_code, dtype: object
#  below 10000 Fleming’s Prime Steakhouse & Wine Bar pos : 0    85718
# 1    70002
# 2    63131
# 3    37203
# 4    33607
# 5    19087
# 6    08053
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85713
# 0    85714
# 0    85715
# 0    85716
# 0    85719
# 0    85730
# Name: postal_code, dtype: object
#  below 10000 Le Peep pos : 0    83646
# 1    46077
# 2    37205
# 3    33635
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85713
# 0    85714
# 0    85715
# 0    85716
# 0    85718
# 0    85719
# Name: postal_code, dtype: object
#  below 10000 Asian Kitchen pos : 0    34684
# 1    33606
# 2    33594
# Name: postal_code, dtype: object  : 0    83616
# 0    83634
# 0    83642
# 0    83646
# 0    83702
# 0    83703
# 0    83704
# 0    83705
# 0    83706
# 0    83707
# 0    83709
# 0    83712
# 0    83713
# 0    83714
# 0    83716
# Name: postal_code, dtype: object
#  below 10000 Jimboy's Tacos pos : 0    89506
# 1    89502
# 2    89436
# 3    89431
# Name: postal_code, dtype: object  : 0    34221
# 0    34604
# 0    34606
# 0    34607
# 0    34608
# 0    34609
# 0    34610
# 0    34619
# 0    34638
# 0    34639
# 0    34652
# 0    34653
# 0    34654
# 0    34655
# 0    34667
# 0    34668
# 0    34669
# 0    34677
# 0    34683
# 0    34684
# 0    34685
# Name: postal_code, dtype: object
#  below 10000 Sabrina's Café pos : 0    19130
# 1    19104
# 2    19096
# 3    08108
# Name: postal_code, dtype: object  : 0    89431
# 0    89432
# 0    89433
# 0    89434
# 0    89436
# 0    89439
# 0    89440
# 0    89441
# 0    89501
# 0    89502
# 0    89503
# 0    89506
# 0    89508
# 0    89509
# 0    89511
# 0    89512
# 0    89519
# 0    89521
# 0    89523
# 0    89595
# Name: postal_code, dtype: object
#  below 10000 Logan's Roadhouse pos : 0    46168
# 1    37214
# 2    37204
# 3    37167
# 4    37066
# Name: postal_code, dtype: object  : 0    18901
# 0    18902
# 0    18912
# 0    18913
# 0    18914
# 0    18915
# 0    18917
# 0    18928
# 0    18929
# 0    18931
# 0    18932
# 0    18936
# 0    18938
# 0    18940
# 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# Name: postal_code, dtype: object
#  below 10000 Naf Naf Grill pos : 0    46202
# 1    46032
# 2    19355
# 3    19103
# 4    08053
# Name: postal_code, dtype: object  : 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# 0    46201
# Name: postal_code, dtype: object
#  below 10000 New China pos : 0    70130
# 1    63109
# 2    33710
# 3    33709
# 4    33706
# 5    33614
# 6    33578
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 Zeko's Mediterranean Grill pos : 0    33714
# 1    33612
# 2    33604
# Name: postal_code, dtype: object  : 0    70001
# 0    70002
# 0    70003
# 0    70005
# 0    70006
# 0    70032
# 0    70037
# 0    70043
# 0    70053
# 0    70056
# 0    70058
# 0    70062
# 0    70065
# 0    70070
# 0    70072
# 0    70075
# 0    70087
# 0    70092
# 0    70094
# 0    70112
# 0    70113
# Name: postal_code, dtype: object
#  below 10000 Chuck E. Cheese pos : 0    89502
# 1    85712
# 2    46250
# 3    33544
# 4    19064
# Name: postal_code, dtype: object  : 0    33503
# 0    33510
# 0    33511
# 0    33534
# 0    33541
# 0    33542
# 0    33543
# 0    33545
# 0    33547
# 0    33548
# 0    33549
# 0    33556
# 0    33558
# 0    33559
# 0    33563
# 0    33565
# 0    33566
# 0    33568
# 0    33569
# 0    33570
# 0    33572
# Name: postal_code, dtype: object
#  over 100000 Sakurapos : 0    85715
# Name: postal_code, dtype: object  train : 0    08002
# 0    08003
# 0    08004
# 0    08007
# Name: postal_code, dtype: object
#  over 100000 Sakura pos : 0    85715
# Name: postal_code, dtype: object test : 0    85614
# 0    85619
# Name: postal_code, dtype: object
#  below 10000 Blake's Lotaburger pos : 0    85750
# 1    85746
# 2    85716
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85713
# 0    85714
# 0    85715
# 0    85718
# 0    85719
# 0    85730
# Name: postal_code, dtype: object
#  below 10000 Fulin's Asian Cuisine pos : 0    37122
# 1    37075
# 2    37027
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85713
# 0    85714
# 0    85715
# 0    85716
# 0    85718
# 0    85719
# Name: postal_code, dtype: object
#  below 10000 Federal Donuts pos : 0    19147
# 1    19123
# 2    19107
# 3    19104
# Name: postal_code, dtype: object  : 0    37012
# 0    37013
# 0    37015
# 0    37024
# 0    37027
# 0    37043
# 0    37064
# 0    37066
# 0    37067
# 0    37069
# 0    37072
# 0    37073
# 0    37075
# 0    37076
# 0    37080
# 0    37082
# 0    37086
# 0    37090
# 0    37115
# 0    37122
# 0    37135
# Name: postal_code, dtype: object
#  below 10000 In-N-Out Burger pos : 0    93111
# 1    89511
# 2    89431
# 3    85755
# 4    85743
# 5    85716
# 6    85713
# 7    85710
# 8    85705
# Name: postal_code, dtype: object  : 0    18901
# 0    18902
# 0    18912
# 0    18913
# 0    18914
# 0    18915
# 0    18917
# 0    18928
# 0    18929
# 0    18931
# 0    18932
# 0    18936
# 0    18938
# 0    18940
# 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# Name: postal_code, dtype: object
#  below 10000 Village Inn pos : 0    85748
# 1    34639
# 2    33774
# 3    33708
# 4    33702
# 5    33578
# 6    33542
# 7    33511
# Name: postal_code, dtype: object  : 0    93013
# 0    93067
# 0    93101
# 0    93103
# 0    93105
# 0    93108
# 0    93109
# 0    93110
# 0    93111
# 0    93117
# 0    93190
# Name: postal_code, dtype: object
#  below 10000 Little Caesars pos : 0    93117
# 1    89512
# 2    89509
# 3    89506
# 4    89503
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85713
# 0    85714
# 0    85715
# 0    85716
# 0    85718
# 0    85719
# Name: postal_code, dtype: object
#  below 10000 Chickie's & Pete's pos : 0    19403
# 1    19153
# 2    19145
# 3    19135
# 4    19026
# 5    19020
# 6    18976
# 7    08505
# 8    08053
# 9    08028
# Name: postal_code, dtype: object  : 0    93013
# 0    93067
# 0    93101
# 0    93103
# 0    93105
# 0    93108
# 0    93109
# 0    93110
# 0    93111
# 0    93117
# 0    93190
# Name: postal_code, dtype: object
#  below 10000 Pho Street pos : 0    19107
# 1    19103
# 2    19010
# Name: postal_code, dtype: object  : 0    18912
# 0    18913
# 0    18914
# 0    18915
# 0    18917
# 0    18928
# 0    18929
# 0    18931
# 0    18932
# 0    18936
# 0    18938
# 0    18940
# 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# 0    18964
# 0    18966
# Name: postal_code, dtype: object
#  below 10000 Backyard Bowls pos : 0    93117
# 1    93105
# 2    93101
# Name: postal_code, dtype: object  : 0    18901
# 0    18902
# 0    18912
# 0    18913
# 0    18914
# 0    18915
# 0    18917
# 0    18928
# 0    18929
# 0    18931
# 0    18932
# 0    18936
# 0    18938
# 0    18940
# 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# Name: postal_code, dtype: object
#  below 10000 Anthony's Coal Fired Pizza pos : 0     33761
# 1     33629
# 2     33618
# 3     33511
# 4     19808
# 5     19803
# 6     19422
# 7     19341
# 8     19096
# 9     19087
# 10    19044
# 11    08054
# Name: postal_code, dtype: object  : 0    93013
# 0    93067
# 0    93101
# 0    93103
# 0    93105
# 0    93108
# 0    93109
# 0    93110
# 0    93111
# 0    93117
# 0    93190
# Name: postal_code, dtype: object
#  below 10000 World of Beer pos : 0    46204
# 1    33612
# 2    33607
# 3    33511
# 4    19341
# Name: postal_code, dtype: object  : 0    33503
# 0    33510
# 0    33534
# 0    33541
# 0    33542
# 0    33543
# 0    33544
# 0    33545
# 0    33547
# 0    33548
# 0    33549
# 0    33556
# 0    33558
# 0    33559
# 0    33563
# 0    33565
# 0    33566
# 0    33568
# 0    33569
# 0    33570
# 0    33572
# Name: postal_code, dtype: object
#  below 10000 Duck Donuts pos : 0    83646
# 1    37027
# 2    19426
# 3    19382
# 4    19056
# 5    08053
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 Port of Subs pos : 0    89521
# 1    89512
# 2    89511
# 3    89506
# 4    89503
# 5    89441
# 6    89436
# 7    89434
# Name: postal_code, dtype: object  : 0    83616
# 0    83634
# 0    83642
# 0    83646
# 0    83702
# 0    83703
# 0    83704
# 0    83705
# 0    83706
# 0    83707
# 0    83709
# 0    83712
# 0    83713
# 0    83714
# 0    83716
# Name: postal_code, dtype: object
#  below 10000 Dewey's Pizza pos : 0    63303
# 1    63130
# 2    63122
# 3    63119
# 4    62269
# 5    62025
# Name: postal_code, dtype: object  : 0    89431
# 0    89432
# 0    89433
# 0    89434
# 0    89436
# 0    89439
# 0    89440
# 0    89441
# 0    89501
# 0    89502
# 0    89503
# 0    89506
# 0    89508
# 0    89509
# 0    89511
# 0    89512
# 0    89519
# 0    89521
# 0    89523
# 0    89595
# Name: postal_code, dtype: object
#  over 100000 Romano's Macaroni Grillpos : 0    89502
# Name: postal_code, dtype: object  train : 0    37012
# 0    37013
# 0    33503
# 0    33510
# Name: postal_code, dtype: object
#  over 100000 Romano's Macaroni Grill pos : 0    89502
# Name: postal_code, dtype: object test : 0    89431
# 0    89432
# Name: postal_code, dtype: object
#  below 10000 Raising Cane's Chicken Fingers pos : 0     89503
# 1     89502
# 2     89431
# 3     85705
# 4     70130
# 5     70125
# 6     70118
# 7     63301
# 8     63143
# 9     63131
# 10    63122
# 11    63074
# Name: postal_code, dtype: object  : 0    89432
# 0    89433
# 0    89434
# 0    89436
# 0    89439
# 0    89440
# 0    89441
# 0    89501
# 0    89506
# 0    89508
# 0    89509
# 0    89511
# 0    89512
# 0    89519
# 0    89521
# 0    89523
# 0    89595
# Name: postal_code, dtype: object
#  below 10000 Brio Italian Grille pos : 0    63131
# 1    33607
# 2    19702
# 3    08053
# 4    08002
# Name: postal_code, dtype: object  : 0    89431
# 0    89432
# 0    89433
# 0    89434
# 0    89436
# 0    89439
# 0    89440
# 0    89441
# 0    89501
# 0    89502
# 0    89503
# 0    89506
# 0    89508
# 0    89509
# 0    89511
# 0    89512
# 0    89519
# 0    89521
# 0    89523
# 0    89595
# Name: postal_code, dtype: object
#  over 100000 Oriental Pearl Restaurantpos : 0    19380
# Name: postal_code, dtype: object  train : 0    18073
# 0    18901
# 0    08002
# 0    08003
# Name: postal_code, dtype: object
#  over 100000 Oriental Pearl Restaurant pos : 0    19380
# Name: postal_code, dtype: object test : 0    18902
# 0    18912
# Name: postal_code, dtype: object
#  below 10000 Uno Pizzeria & Grill pos : 0    46237
# 1    19456
# 2    19428
# 3    19341
# 4    19073
# 5    19020
# 6    18976
# 7    08096
# 8    08052
# Name: postal_code, dtype: object  : 0    18901
# 0    18902
# 0    18912
# 0    18913
# 0    18914
# 0    18915
# 0    18917
# 0    18928
# 0    18929
# 0    18931
# 0    18932
# 0    18936
# 0    18938
# 0    18940
# 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# Name: postal_code, dtype: object
#  below 10000 Glory Days Grill pos : 0    34684
# 1    33709
# 2    33702
# 3    33647
# 4    33618
# 5    33578
# 6    33558
# 7    33543
# 8    33511
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 Keke's Breakfast Cafe pos : 0    33778
# 1    33707
# 2    33629
# 3    33625
# 4    33618
# 5    33612
# 6    33569
# 7    33549
# 8    33543
# 9    33511
# Name: postal_code, dtype: object  : 0    34221
# 0    34604
# 0    34606
# 0    34607
# 0    34608
# 0    34609
# 0    34610
# 0    34619
# 0    34638
# 0    34639
# 0    34652
# 0    34653
# 0    34654
# 0    34655
# 0    34667
# 0    34668
# 0    34669
# 0    34677
# 0    34683
# 0    34684
# 0    34685
# Name: postal_code, dtype: object
#  below 10000 Iron Hill Brewery & Restaurant pos : 0     19801
# 1     19460
# 2     19454
# 3     19380
# 4     19118
# 5     19107
# 6     19063
# 7     19006
# 8     19003
# 9     18940
# 10    08052
# 11    08043
# Name: postal_code, dtype: object  : 0    33503
# 0    33510
# 0    33511
# 0    33534
# 0    33541
# 0    33542
# 0    33543
# 0    33544
# 0    33545
# 0    33547
# 0    33548
# 0    33549
# 0    33556
# 0    33558
# 0    33559
# 0    33563
# 0    33565
# 0    33566
# 0    33568
# 0    33569
# 0    33570
# Name: postal_code, dtype: object
#  below 10000 HotBox Pizza pos : 0    46278
# 1    46250
# 2    46237
# 3    46220
# 4    46204
# 5    46123
# 6    46032
# Name: postal_code, dtype: object  : 0    19301
# 0    19311
# 0    19312
# 0    19317
# 0    19320
# 0    19331
# 0    19333
# 0    19335
# 0    19341
# 0    19342
# 0    19343
# 0    19348
# 0    19353
# 0    19355
# 0    19357
# 0    19372
# 0    19374
# 0    19375
# 0    19380
# 0    19382
# 0    19395
# Name: postal_code, dtype: object
#  below 10000 City Barbeque pos : 0    46234
# 1    46227
# 2    46202
# 3    46075
# 4    46038
# 5    46032
# Name: postal_code, dtype: object  : 0    46033
# 0    46037
# 0    46040
# 0    46055
# 0    46060
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# 0    46201
# 0    46203
# 0    46204
# Name: postal_code, dtype: object
#  below 10000 Bully's Sports Bar & Grill pos : 0    89523
# 1    89511
# 2    89441
# 3    89434
# 4    89431
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 Fuzzy's Taco Shop pos : 0    63301
# 1    63146
# 2    63119
# 3    63021
# 4    33617
# 5    33578
# 6    33511
# Name: postal_code, dtype: object  : 0    89431
# 0    89432
# 0    89433
# 0    89434
# 0    89436
# 0    89439
# 0    89440
# 0    89441
# 0    89501
# 0    89502
# 0    89503
# 0    89506
# 0    89508
# 0    89509
# 0    89511
# 0    89512
# 0    89519
# 0    89521
# 0    89523
# 0    89595
# Name: postal_code, dtype: object
#  below 10000 Casita Taqueria pos : 0    33713
# 1    33710
# 2    33704
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  below 10000 Del Taco pos : 0    89521
# 1    89512
# 2    89503
# 3    89502
# 4    89434
# 5    89431
# 6    85719
# 7    83706
# 8    83705
# Name: postal_code, dtype: object  : 0    33503
# 0    33510
# 0    33511
# 0    33534
# 0    33541
# 0    33542
# 0    33543
# 0    33544
# 0    33545
# 0    33547
# 0    33548
# 0    33549
# 0    33556
# 0    33558
# 0    33559
# 0    33563
# 0    33565
# 0    33566
# 0    33568
# 0    33569
# 0    33570
# Name: postal_code, dtype: object
#  below 10000 City Greens pos : 0    70115
# 1    70112
# 2    70005
# Name: postal_code, dtype: object  : 0    89431
# 0    89432
# 0    89433
# 0    89434
# 0    89436
# 0    89439
# 0    89440
# 0    89441
# 0    89501
# 0    89502
# 0    89503
# 0    89506
# 0    89508
# 0    89509
# 0    89511
# 0    89512
# 0    89519
# 0    89521
# 0    89523
# 0    89595
# Name: postal_code, dtype: object
#  below 10000 El Maguey pos : 0    63119
# 1    63109
# 2    63044
# 3    63021
# 4    63017
# 5    62025
# 6    46254
# Name: postal_code, dtype: object  : 0    70001
# 0    70002
# 0    70003
# 0    70005
# 0    70006
# 0    70032
# 0    70037
# 0    70043
# 0    70053
# 0    70056
# 0    70058
# 0    70062
# 0    70065
# 0    70070
# 0    70072
# 0    70075
# 0    70087
# 0    70092
# 0    70094
# 0    70112
# 0    70113
# Name: postal_code, dtype: object
#  below 10000 Gryphon Cafe pos : 0    19380
# 1    19122
# 2    19087
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  below 10000 Pollo Tropical pos : 0    34677
# 1    33781
# 2    33765
# 3    33634
# 4    33618
# 5    33617
# 6    33614
# 7    33559
# 8    33511
# Name: postal_code, dtype: object  : 0    18901
# 0    18902
# 0    18912
# 0    18913
# 0    18914
# 0    18915
# 0    18917
# 0    18928
# 0    18929
# 0    18931
# 0    18932
# 0    18936
# 0    18938
# 0    18940
# 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# Name: postal_code, dtype: object
#  below 10000 Fazoli's pos : 0    63303
# 1    63044
# 2    46250
# 3    46219
# 4    46203
# 5    46123
# Name: postal_code, dtype: object  : 0    34221
# 0    34604
# 0    34606
# 0    34607
# 0    34608
# 0    34609
# 0    34610
# 0    34619
# 0    34638
# 0    34639
# 0    34652
# 0    34653
# 0    34654
# 0    34655
# 0    34667
# 0    34668
# 0    34669
# 0    34677
# 0    34683
# 0    34684
# 0    34685
# Name: postal_code, dtype: object
#  over 100000 Thai Orchidpos : 0    46250
# Name: postal_code, dtype: object  train : 0    46032
# 0    46033
# 0    18901
# 0    18902
# Name: postal_code, dtype: object
#  over 100000 Thai Orchid pos : 0    46250
# Name: postal_code, dtype: object test : 0    46037
# 0    46038
# Name: postal_code, dtype: object
#  below 10000 Sushi Ai pos : 0    93117
# 1    63303
# 2    63105
# 3    63101
# 4    63043
# 5    63011
# 6    63010
# 7    62269
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 Café Zupas pos : 0    83704
# 1    83702
# 2    83646
# Name: postal_code, dtype: object  : 0    93013
# 0    93067
# 0    93101
# 0    93103
# 0    93105
# 0    93108
# 0    93109
# 0    93110
# 0    93111
# 0    93117
# 0    93190
# Name: postal_code, dtype: object
#  below 10000 SoFresh pos : 0    33626
# 1    33612
# 2    33606
# 3    33602
# Name: postal_code, dtype: object  : 0    83616
# 0    83634
# 0    83642
# 0    83646
# 0    83702
# 0    83703
# 0    83704
# 0    83705
# 0    83706
# 0    83707
# 0    83709
# 0    83712
# 0    83713
# 0    83714
# 0    83716
# Name: postal_code, dtype: object
#  below 10000 The Original Pancake House pos : 0    83704
# 1    63124
# 2    46260
# 3    46038
# Name: postal_code, dtype: object  : 0    33503
# 0    33510
# 0    33511
# 0    33534
# 0    33541
# 0    33542
# 0    33543
# 0    33544
# 0    33545
# 0    33547
# 0    33548
# 0    33549
# 0    33556
# 0    33558
# 0    33559
# 0    33563
# 0    33565
# 0    33566
# 0    33568
# 0    33569
# 0    33570
# Name: postal_code, dtype: object
#  below 10000 Imo's Pizza pos : 0     63301
# 1     63141
# 2     63139
# 3     63122
# 4     63118
# 5     63116
# 6     63109
# 7     63108
# 8     63103
# 9     63102
# 10    63074
# 11    63043
# Name: postal_code, dtype: object  : 0    83616
# 0    83634
# 0    83642
# 0    83646
# 0    83702
# 0    83703
# 0    83704
# 0    83705
# 0    83706
# 0    83707
# 0    83709
# 0    83712
# 0    83713
# 0    83714
# 0    83716
# Name: postal_code, dtype: object
#  below 10000 The Urban Juicer pos : 0    37212
# 1    37209
# 2    37206
# 3    37204
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  over 100000 Benihanapos : 0    46240
# Name: postal_code, dtype: object  train : 0    18901
# 0    18902
# 0    08002
# 0    08003
# Name: postal_code, dtype: object
#  over 100000 Benihana pos : 0    46240
# Name: postal_code, dtype: object test : 0    46032
# 0    46033
# Name: postal_code, dtype: object
#  below 10000 Chimi's Fresh-Mex pos : 0    63114
# 1    63044
# 2    63017
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 California Tortilla pos : 0    19468
# 1    19460
# 2    19342
# 3    19341
# 4    19116
# 5    19056
# 6    08081
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  below 10000 Boston Market pos : 0    89502
# 1    46250
# 2    33772
# 3    33702
# 4    33511
# 5    19104
# 6    19047
# 7    19001
# Name: postal_code, dtype: object  : 0    18969
# 0    18974
# 0    18976
# 0    18977
# 0    18984
# 0    19002
# 0    19003
# 0    19004
# 0    19006
# 0    19007
# 0    19008
# 0    19010
# 0    19012
# 0    19013
# 0    19014
# 0    19015
# 0    19018
# 0    19020
# 0    19021
# 0    19022
# 0    19023
# Name: postal_code, dtype: object
#  below 10000 Pancheros Mexican Grill pos : 0    19477
# 1    19063
# 2    08054
# 3    08043
# 4    08028
# Name: postal_code, dtype: object  : 0    89431
# 0    89432
# 0    89433
# 0    89434
# 0    89436
# 0    89439
# 0    89440
# 0    89441
# 0    89501
# 0    89502
# 0    89503
# 0    89506
# 0    89508
# 0    89509
# 0    89511
# 0    89512
# 0    89519
# 0    89521
# 0    89523
# 0    89595
# Name: postal_code, dtype: object
#  below 10000 Corner Bakery pos : 0    19406
# 1    19104
# 2    19103
# 3    19044
# 4    19004
# Name: postal_code, dtype: object  : 0    18977
# 0    18984
# 0    19001
# 0    19002
# 0    19003
# 0    19006
# 0    19007
# 0    19008
# 0    19010
# 0    19012
# 0    19013
# 0    19014
# 0    19015
# 0    19018
# 0    19020
# 0    19021
# 0    19022
# 0    19023
# 0    19025
# 0    19026
# 0    19027
# Name: postal_code, dtype: object
#  below 10000 eegee's pos : 0     85745
# 1     85743
# 2     85741
# 3     85730
# 4     85719
# 5     85716
# 6     85715
# 7     85713
# 8     85712
# 9     85710
# 10    85705
# 11    85704
# Name: postal_code, dtype: object  : 0    18912
# 0    18913
# 0    18914
# 0    18915
# 0    18917
# 0    18928
# 0    18929
# 0    18931
# 0    18932
# 0    18936
# 0    18938
# 0    18940
# 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# 0    18964
# 0    18966
# Name: postal_code, dtype: object
#  below 10000 CC's Coffee House pos : 0    70119
# 1    70116
# 2    70002
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85713
# 0    85714
# 0    85715
# 0    85716
# 0    85718
# 0    85719
# Name: postal_code, dtype: object
#  over 100000 New York Pizzapos : 0    85710
# Name: postal_code, dtype: object  train : 0    70001
# 0    70002
# 0    37012
# 0    37013
# Name: postal_code, dtype: object
#  over 100000 New York Pizza pos : 0    85710
# Name: postal_code, dtype: object test : 0    85614
# 0    85619
# Name: postal_code, dtype: object
#  below 10000 Newk's Eatery pos : 0    46143
# 1    37203
# 2    37067
# 3    33759
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85713
# 0    85714
# 0    85715
# 0    85716
# 0    85718
# 0    85719
# Name: postal_code, dtype: object
#  below 10000 Bellacino's Pizza & Grinders pos : 0    63301
# 1    63109
# 2    63010
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 Sakura Japanese Restaurant pos : 0    46240
# 1    37076
# 2    37064
# 3    19808
# 4    19020
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  below 10000 Slack's Hoagie Shack pos : 0    19064
# 1    19030
# 2    18976
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 Yats pos : 0    46278
# 1    46260
# 2    46220
# 3    46202
# 4    46142
# 5    46123
# 6    46037
# 7    46032
# 8    37067
# Name: postal_code, dtype: object  : 0    18901
# 0    18902
# 0    18912
# 0    18913
# 0    18914
# 0    18915
# 0    18917
# 0    18928
# 0    18929
# 0    18931
# 0    18932
# 0    18936
# 0    18938
# 0    18940
# 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# Name: postal_code, dtype: object
#  over 100000 The Old Spaghetti Factorypos : 0    63102
# Name: postal_code, dtype: object  train : 0    46033
# 0    46037
# 0    46038
# 0    46040
# Name: postal_code, dtype: object
#  over 100000 The Old Spaghetti Factory pos : 0    63102
# Name: postal_code, dtype: object test : 0    62201
# 0    62203
# Name: postal_code, dtype: object
#  below 10000 Ruby Tuesday pos : 0    63088
# 1    46227
# 2    34654
# 3    33578
# 4    19808
# 5    19462
# 6    19153
# 7    08054
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# 0    63106
# Name: postal_code, dtype: object
#  over 100000 Cicispos : 0    46227
# Name: postal_code, dtype: object  train : 0    33503
# 0    33510
# 0    33511
# 0    33534
# Name: postal_code, dtype: object
#  over 100000 Cicis pos : 0    46227
# Name: postal_code, dtype: object test : 0    46032
# 0    46033
# Name: postal_code, dtype: object
#  below 10000 Flying Pie Pizzaria pos : 0    83706
# 1    83704
# 2    83703
# 3    83642
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 Izzo's Illegal Burrito pos : 0    70115
# 1    70058
# 2    70006
# Name: postal_code, dtype: object  : 0    83616
# 0    83634
# 0    83642
# 0    83646
# 0    83702
# 0    83703
# 0    83704
# 0    83705
# 0    83706
# 0    83707
# 0    83709
# 0    83712
# 0    83713
# 0    83714
# 0    83716
# Name: postal_code, dtype: object
#  below 10000 El Pollo Loco pos : 0    89511
# 1    89503
# 2    89502
# 3    89431
# 4    85741
# 5    85711
# Name: postal_code, dtype: object  : 0    70001
# 0    70002
# 0    70003
# 0    70005
# 0    70006
# 0    70032
# 0    70037
# 0    70043
# 0    70053
# 0    70056
# 0    70058
# 0    70062
# 0    70065
# 0    70070
# 0    70072
# 0    70075
# 0    70087
# 0    70092
# 0    70094
# 0    70112
# 0    70113
# Name: postal_code, dtype: object
#  below 10000 Golden Corral Buffet & Grill pos : 0     85746
# 1     85741
# 2     85711
# 3     83704
# 4     70065
# 5     63123
# 6     62269
# 7     62234
# 8     46254
# 9     37076
# 10    33511
# 11    19020
# Name: postal_code, dtype: object  : 0    89431
# 0    89432
# 0    89433
# 0    89434
# 0    89436
# 0    89439
# 0    89440
# 0    89441
# 0    89501
# 0    89502
# 0    89503
# 0    89506
# 0    89508
# 0    89509
# 0    89511
# 0    89512
# 0    89519
# 0    89521
# 0    89523
# 0    89595
# Name: postal_code, dtype: object
#  below 10000 Joe Boccardi's Ristorante pos : 0    63119
# 1    63026
# 2    62236
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85713
# 0    85714
# 0    85715
# 0    85716
# 0    85718
# 0    85719
# Name: postal_code, dtype: object
#  below 10000 WingHouse Bar & Grill pos : 0    34684
# 1    33781
# 2    33771
# 3    33759
# 4    33615
# 5    33610
# 6    33607
# 7    33544
# 8    33511
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  over 100000 Thai Cuisinepos : 0    85704
# Name: postal_code, dtype: object  train : 0    83616
# 0    83634
# 0    33609
# 0    33610
# Name: postal_code, dtype: object
#  over 100000 Thai Cuisine pos : 0    85704
# Name: postal_code, dtype: object test : 0    85614
# 0    85619
# Name: postal_code, dtype: object
#  below 10000 PureBread Deli pos : 0    19807
# 1    19713
# 2    19342
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85713
# 0    85714
# 0    85715
# 0    85716
# 0    85718
# 0    85719
# Name: postal_code, dtype: object
#  below 10000 Portillo's Hot Dogs pos : 0    46227
# 1    46123
# 2    46037
# 3    33511
# Name: postal_code, dtype: object  : 0    19311
# 0    19312
# 0    19317
# 0    19320
# 0    19331
# 0    19333
# 0    19335
# 0    19341
# 0    19342
# 0    19343
# 0    19348
# 0    19353
# 0    19355
# 0    19357
# 0    19372
# 0    19374
# 0    19375
# 0    19380
# 0    19382
# 0    19395
# 0    19401
# Name: postal_code, dtype: object
#  below 10000 Nico's Taco Shop pos : 0    85743
# 1    85739
# 2    85737
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 Goldie pos : 0    19130
# 1    19104
# 2    19102
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85713
# 0    85714
# 0    85715
# 0    85716
# 0    85718
# 0    85719
# Name: postal_code, dtype: object
#  below 10000 La Parrilla Suiza pos : 0    85741
# 1    85712
# 2    85705
# Name: postal_code, dtype: object  : 0    18901
# 0    18902
# 0    18912
# 0    18913
# 0    18914
# 0    18915
# 0    18917
# 0    18928
# 0    18929
# 0    18931
# 0    18932
# 0    18936
# 0    18938
# 0    18940
# 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# Name: postal_code, dtype: object
#  over 100000 Morton's The Steakhousepos : 0    63102
# Name: postal_code, dtype: object  train : 0    37012
# 0    37013
# 0    18901
# 0    18902
# Name: postal_code, dtype: object
#  over 100000 Morton's The Steakhouse pos : 0    63102
# Name: postal_code, dtype: object test : 0    62201
# 0    62203
# Name: postal_code, dtype: object
#  below 10000 Super Wok pos : 0    63122
# 1    37076
# 2    19425
# 3    19063
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  below 10000 Green Eggs Cafe pos : 0    19147
# 1    19130
# 2    19125
# 3    19103
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  below 10000 Rusty's Pizza Parlor pos : 0    93117
# 1    93111
# 2    93105
# 3    93103
# 4    93101
# 5    93013
# Name: postal_code, dtype: object  : 0    18901
# 0    18902
# 0    18912
# 0    18913
# 0    18914
# 0    18915
# 0    18917
# 0    18928
# 0    18929
# 0    18931
# 0    18932
# 0    18936
# 0    18938
# 0    18940
# 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# Name: postal_code, dtype: object
#  below 10000 Manhattan Bagel pos : 0     19446
# 1     19425
# 2     19128
# 3     19103
# 4     19087
# 5     19083
# 6     19073
# 7     19047
# 8     19036
# 9     18914
# 10    08057
# 11    08034
# Name: postal_code, dtype: object  : 0    93013
# 0    93067
# 0    93101
# 0    93103
# 0    93105
# 0    93108
# 0    93109
# 0    93110
# 0    93111
# 0    93117
# 0    93190
# Name: postal_code, dtype: object
#  below 10000 Whataburger pos : 0    85745
# 1    85712
# 2    85710
# 3    85706
# 4    85704
# Name: postal_code, dtype: object  : 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# 0    18964
# 0    18966
# 0    18969
# 0    18974
# 0    18976
# 0    18977
# 0    18984
# 0    19001
# 0    19002
# 0    19003
# 0    19004
# 0    19006
# 0    19007
# 0    19008
# 0    19010
# Name: postal_code, dtype: object
#  below 10000 Mr and Mrs Crab pos : 0    33781
# 1    33765
# 2    33611
# 3    33511
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85713
# 0    85714
# 0    85715
# 0    85716
# 0    85718
# 0    85719
# Name: postal_code, dtype: object
#  over 100000 Bartacopos : 0    37204
# Name: postal_code, dtype: object  train : 0    33503
# 0    33510
# 0    18901
# 0    18902
# Name: postal_code, dtype: object
#  over 100000 Bartaco pos : 0    37204
# Name: postal_code, dtype: object test : 0    37012
# 0    37013
# Name: postal_code, dtype: object
#  over 100000 Pokeworkspos : 0    70002
# Name: postal_code, dtype: object  train : 0    33503
# 0    33510
# 0    33511
# 0    33534
# Name: postal_code, dtype: object
#  over 100000 Pokeworks pos : 0    70002
# Name: postal_code, dtype: object test : 0    70001
# 0    70003
# Name: postal_code, dtype: object
#  below 10000 Raley's pos : 0    89523
# 1    89519
# 2    89506
# 3    89503
# 4    89502
# 5    89501
# 6    89436
# 7    89431
# Name: postal_code, dtype: object  : 0    70001
# 0    70002
# 0    70003
# 0    70005
# ...
#  below 10000 The Griddle pos : 0    83706
# 1    83642
# 2    83616
# Name: postal_code, dtype: object  : 0    34221
# 0    34604
# 0    34606
# 0    34607
# 0    34608
# 0    34609
# 0    34610
# 0    34619
# 0    34638
# 0    34639
# 0    34652
# 0    34653
# 0    34654
# 0    34655
# 0    34667
# 0    34668
# 0    34669
# 0    34677
# 0    34683
# 0    34684
# 0    34685
# Name: postal_code, dtype: object
#  over 100000 Panda Gardenpos : 0    83705
# Name: postal_code, dtype: object  train : 0    18901
# 0    18902
# 0    18912
# 0    18913
# Name: postal_code, dtype: object
#  over 100000 Panda Garden pos : 0    83705
# Name: postal_code, dtype: object test : 0    83616
# 0    83634
# Name: postal_code, dtype: object
#  below 10000 Pizza Plus pos : 0    89523
# 1    89436
# 2    89431
# 3    19148
# Name: postal_code, dtype: object  : 0    83616
# 0    83634
# 0    83642
# 0    83646
# 0    83702
# 0    83703
# 0    83704
# 0    83705
# 0    83706
# 0    83707
# 0    83709
# 0    83712
# 0    83713
# 0    83714
# 0    83716
# Name: postal_code, dtype: object
#  below 10000 Zea Rotisserie & Bar pos : 0    70118
# 1    70065
# 2    70058
# 3    70006
# Name: postal_code, dtype: object  : 0    89431
# 0    89432
# 0    89433
# 0    89434
# 0    89436
# 0    89439
# 0    89440
# 0    89441
# 0    89501
# 0    89502
# 0    89503
# 0    89506
# 0    89508
# 0    89509
# 0    89511
# 0    89512
# 0    89519
# 0    89521
# 0    89523
# 0    89595
# Name: postal_code, dtype: object
#  over 100000 Great Wall Chinese Restaurantpos : 0    46227
# Name: postal_code, dtype: object  train : 0    33503
# 0    33510
# 0    18073
# 0    18901
# Name: postal_code, dtype: object
#  over 100000 Great Wall Chinese Restaurant pos : 0    46227
# Name: postal_code, dtype: object test : 0    46032
# 0    46033
# Name: postal_code, dtype: object
#  below 10000 Pizza King pos : 0    46229
# 1    46123
# 2    46055
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# 0    46201
# 0    46202
# Name: postal_code, dtype: object
#  below 10000 Fiesta Mexicana pos : 0    89506
# 1    89434
# 2    89431
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 Lee's Hoagie House pos : 0    19401
# 1    19152
# 2    19044
# 3    19001
# Name: postal_code, dtype: object  : 0    89431
# 0    89432
# 0    89433
# 0    89434
# 0    89436
# 0    89439
# 0    89440
# 0    89441
# 0    89501
# 0    89502
# 0    89503
# 0    89506
# 0    89508
# 0    89509
# 0    89511
# 0    89512
# 0    89519
# 0    89521
# 0    89523
# 0    89595
# Name: postal_code, dtype: object
#  below 10000 Sal's Famous Pizzeria pos : 0    46168
# 1    46158
# 2    46112
# Name: postal_code, dtype: object  : 0    18901
# 0    18902
# 0    18912
# 0    18913
# 0    18914
# 0    18915
# 0    18917
# 0    18928
# 0    18929
# 0    18931
# 0    18932
# 0    18936
# 0    18938
# 0    18940
# 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# Name: postal_code, dtype: object
#  below 10000 Salem's Fresh Eats pos : 0    33713
# 1    33619
# 2    33612
# 3    33511
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 China Taste pos : 0    34689
# 1    33770
# 2    33635
# 3    33611
# 4    33578
# Name: postal_code, dtype: object  : 0    33503
# 0    33510
# 0    33511
# 0    33534
# 0    33541
# 0    33542
# 0    33543
# 0    33544
# 0    33545
# 0    33547
# 0    33548
# 0    33549
# 0    33556
# 0    33558
# 0    33559
# 0    33563
# 0    33565
# 0    33566
# 0    33568
# 0    33569
# 0    33570
# Name: postal_code, dtype: object
#  over 100000 Jade Gardenpos : 0    85741
# Name: postal_code, dtype: object  train : 0    33503
# 0    33510
# 0    18073
# 0    18901
# Name: postal_code, dtype: object
#  over 100000 Jade Garden pos : 0    85741
# Name: postal_code, dtype: object test : 0    85614
# 0    85619
# Name: postal_code, dtype: object
#  below 10000 Helen's Hot Chicken pos : 0    37208
# 1    37203
# 2    37115
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85713
# 0    85714
# 0    85715
# 0    85716
# 0    85718
# 0    85719
# Name: postal_code, dtype: object
#  over 100000 Asian Wokpos : 0    89506
# Name: postal_code, dtype: object  train : 0    33503
# 0    33510
# 0    33511
# 0    33534
# Name: postal_code, dtype: object
#  over 100000 Asian Wok pos : 0    89506
# Name: postal_code, dtype: object test : 0    89431
# 0    89432
# Name: postal_code, dtype: object
#  below 10000 Crafty Crab pos : 0    33618
# 1    33511
# 2    19020
# 3    19001
# Name: postal_code, dtype: object  : 0    89431
# 0    89432
# 0    89433
# 0    89434
# 0    89436
# 0    89439
# 0    89440
# 0    89441
# 0    89501
# 0    89502
# 0    89503
# 0    89506
# 0    89508
# 0    89509
# 0    89511
# 0    89512
# 0    89519
# 0    89521
# 0    89523
# 0    89595
# Name: postal_code, dtype: object
#  over 100000 Slim Chickenspos : 0    63139
# Name: postal_code, dtype: object  train : 0    37012
# 0    37013
# 0    37015
# 0    37024
# Name: postal_code, dtype: object
#  over 100000 Slim Chickens pos : 0    63139
# Name: postal_code, dtype: object test : 0    62201
# 0    62203
# Name: postal_code, dtype: object
#  over 100000 CAVApos : 0    37215
# Name: postal_code, dtype: object  train : 0    18901
# 0    18902
# 0    18073
# 0    18912
# Name: postal_code, dtype: object
#  over 100000 CAVA pos : 0    37215
# Name: postal_code, dtype: object test : 0    37012
# 0    37013
# Name: postal_code, dtype: object
#  below 10000 Squeeze In pos : 0    89523
# 1    89511
# 2    89434
# 3    83616
# Name: postal_code, dtype: object  : 0    37012
# 0    37013
# 0    37015
# 0    37024
# 0    37027
# 0    37043
# 0    37064
# 0    37066
# 0    37067
# 0    37069
# 0    37072
# 0    37073
# 0    37075
# 0    37076
# 0    37080
# 0    37082
# 0    37086
# 0    37090
# 0    37115
# 0    37122
# 0    37135
# Name: postal_code, dtype: object
#  over 100000 Cheeburger Cheeburgerpos : 0    63131
# Name: postal_code, dtype: object  train : 0    18901
# 0    18902
# 0    18073
# 0    18912
# Name: postal_code, dtype: object
#  over 100000 Cheeburger Cheeburger pos : 0    63131
# Name: postal_code, dtype: object test : 0    62201
# 0    62203
# Name: postal_code, dtype: object
#  below 10000 Kung Fu Tea pos : 0    33781
# 1    33612
# 2    19107
# 3    19003
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  below 10000 China Star pos : 0    34698
# 1    33625
# 2    33617
# 3    19468
# 4    19422
# Name: postal_code, dtype: object  : 0    33503
# 0    33510
# 0    33511
# 0    33534
# 0    33541
# 0    33542
# 0    33543
# 0    33544
# 0    33545
# 0    33547
# 0    33548
# 0    33549
# 0    33556
# 0    33558
# 0    33559
# 0    33563
# 0    33565
# 0    33566
# 0    33568
# 0    33569
# 0    33570
# Name: postal_code, dtype: object
#  over 100000 Toastpos : 0    70119
# Name: postal_code, dtype: object  train : 0    70001
# 0    70002
# 0    33701
# 0    33702
# Name: postal_code, dtype: object
#  over 100000 Toast pos : 0    70119
# Name: postal_code, dtype: object test : 0    70003
# 0    70005
# Name: postal_code, dtype: object
#  below 10000 Seoul Taco pos : 0    63130
# 1    63110
# 2    63017
# Name: postal_code, dtype: object  : 0    70001
# 0    70002
# 0    70003
# 0    70005
# 0    70006
# 0    70032
# 0    70037
# 0    70043
# 0    70053
# 0    70056
# 0    70058
# 0    70062
# 0    70065
# 0    70070
# 0    70072
# 0    70075
# 0    70087
# 0    70092
# 0    70094
# 0    70112
# 0    70113
# Name: postal_code, dtype: object
#  below 10000 El Rodeo pos : 0    46239
# 1    46123
# 2    46032
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  below 10000 Jules Thin Crust pos : 0    19454
# 1    19046
# 2    19003
# 3    18901
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 Chuy's pos : 0    46237
# 1    46032
# 2    37214
# 3    37203
# 4    37067
# 5    33559
# Name: postal_code, dtype: object  : 0    18954
# 0    18960
# 0    18964
# 0    18966
# 0    18969
# 0    18974
# 0    18976
# 0    18977
# 0    18984
# 0    19001
# 0    19002
# 0    19003
# 0    19004
# 0    19006
# 0    19007
# 0    19008
# 0    19010
# 0    19012
# 0    19013
# 0    19014
# 0    19015
# Name: postal_code, dtype: object
#  below 10000 City View Pizza and Grill pos : 0    19141
# 1    19140
# 2    19130
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  over 100000 China Gourmetpos : 0    37064
# Name: postal_code, dtype: object  train : 0    33503
# 0    33510
# 0    18901
# 0    18902
# Name: postal_code, dtype: object
#  over 100000 China Gourmet pos : 0    37064
# Name: postal_code, dtype: object test : 0    37012
# 0    37013
# Name: postal_code, dtype: object
#  below 10000 Cody's Original Roadhouse pos : 0    34689
# 1    34606
# 2    33770
# 3    33635
# Name: postal_code, dtype: object  : 0    37012
# 0    37013
# 0    37015
# 0    37024
# 0    37027
# 0    37043
# 0    37064
# 0    37066
# 0    37067
# 0    37069
# 0    37072
# 0    37073
# 0    37075
# 0    37076
# 0    37080
# 0    37082
# 0    37086
# 0    37090
# 0    37115
# 0    37122
# 0    37135
# Name: postal_code, dtype: object
#  below 10000 From The Boot pos : 0    19444
# 1    19422
# 2    19002
# Name: postal_code, dtype: object  : 0    34221
# 0    34604
# 0    34606
# 0    34607
# 0    34608
# 0    34609
# 0    34610
# 0    34619
# 0    34638
# 0    34639
# 0    34652
# 0    34653
# 0    34654
# 0    34655
# 0    34667
# 0    34668
# 0    34669
# 0    34677
# 0    34683
# 0    34684
# 0    34685
# Name: postal_code, dtype: object
#  below 10000 Puccino's Coffee pos : 0    70123
# 1    70002
# 2    70001
# Name: postal_code, dtype: object  : 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# 0    18964
# 0    18966
# 0    18969
# 0    18974
# 0    18976
# 0    18977
# 0    18984
# 0    19001
# 0    19002
# 0    19003
# 0    19004
# 0    19006
# 0    19007
# 0    19008
# Name: postal_code, dtype: object
#  below 10000 The Blind Onion Pizza & Pub pos : 0    89511
# 1    89503
# 2    89436
# 3    89431
# Name: postal_code, dtype: object  : 0    70001
# 0    70002
# 0    70003
# 0    70005
# 0    70006
# 0    70032
# 0    70037
# 0    70043
# 0    70053
# 0    70056
# 0    70058
# 0    70062
# 0    70065
# 0    70070
# 0    70072
# 0    70075
# 0    70087
# 0    70092
# 0    70094
# 0    70112
# 0    70113
# Name: postal_code, dtype: object
#  below 10000 Cafe Patachou pos : 0    46240
# 1    46205
# 2    46204
# 3    46033
# 4    46032
# Name: postal_code, dtype: object  : 0    89431
# 0    89432
# 0    89433
# 0    89434
# 0    89436
# 0    89439
# 0    89440
# 0    89441
# 0    89501
# 0    89502
# 0    89503
# 0    89506
# 0    89508
# 0    89509
# 0    89511
# 0    89512
# 0    89519
# 0    89521
# 0    89523
# 0    89595
# Name: postal_code, dtype: object
#  below 10000 Magpies Gourmet Pizza pos : 0    85748
# 1    85705
# 2    85704
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 Little Greek Fresh Grill pos : 0    34654
# 1    33762
# 2    33578
# Name: postal_code, dtype: object  : 0    85614
# 0    85619
# 0    85629
# 0    85641
# 0    85653
# 0    85658
# 0    85701
# 0    85702
# 0    85704
# 0    85705
# 0    85706
# 0    85707
# 0    85710
# 0    85711
# 0    85712
# 0    85713
# 0    85714
# 0    85715
# 0    85716
# 0    85718
# 0    85719
# Name: postal_code, dtype: object
#  below 10000 White Castle pos : 0    63303
# 1    63134
# 2    63044
# 3    62234
# 4    37211
# 5    37203
# Name: postal_code, dtype: object  : 0    34221
# 0    34604
# 0    34606
# 0    34607
# 0    34608
# 0    34609
# 0    34610
# 0    34619
# 0    34638
# 0    34639
# 0    34652
# 0    34653
# 0    34654
# 0    34655
# 0    34667
# 0    34668
# 0    34669
# 0    34677
# 0    34683
# 0    34684
# 0    34685
# Name: postal_code, dtype: object
#  below 10000 Main Squeeze Juice Co. pos : 0    70130
# 1    70002
# 2    70001
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  over 100000 Studio Movie Grillpos : 0    46268
# Name: postal_code, dtype: object  train : 0    33503
# 0    33510
# 0    18901
# 0    18902
# Name: postal_code, dtype: object
#  over 100000 Studio Movie Grill pos : 0    46268
# Name: postal_code, dtype: object test : 0    46032
# 0    46033
# Name: postal_code, dtype: object
#  below 10000 El Guero Canelo pos : 0    85711
# 1    85706
# 2    85705
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  over 100000 Kolache Factorypos : 0    63144
# Name: postal_code, dtype: object  train : 0    46033
# 0    46037
# 0    46038
# 0    46040
# Name: postal_code, dtype: object
#  over 100000 Kolache Factory pos : 0    63144
# Name: postal_code, dtype: object test : 0    62201
# 0    62203
# Name: postal_code, dtype: object
#  below 10000 Sushi Club pos : 0    46237
# 1    46214
# 2    46038
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  below 10000 Chevys Fresh Mex pos : 0    63132
# 1    63128
# 2    62269
# Name: postal_code, dtype: object  : 0    46032
# 0    46033
# 0    46037
# 0    46038
# 0    46040
# 0    46055
# 0    46060
# 0    46075
# 0    46077
# 0    46107
# 0    46112
# 0    46113
# 0    46122
# 0    46123
# 0    46140
# 0    46142
# 0    46143
# 0    46158
# 0    46163
# 0    46168
# 0    46184
# Name: postal_code, dtype: object
#  below 10000 The Halal Guys pos : 0    19406
# 1    19114
# 2    19107
# 3    19104
# Name: postal_code, dtype: object  : 0    63010
# 0    63011
# 0    63017
# 0    63021
# 0    63026
# 0    63031
# 0    63033
# 0    63034
# 0    63042
# 0    63043
# 0    63044
# 0    63049
# 0    63052
# 0    63053
# 0    63074
# 0    63088
# 0    63101
# 0    63102
# 0    63103
# 0    63104
# 0    63105
# Name: postal_code, dtype: object
#  below 10000 Greek City Cafe pos : 0    34606
# 1    33771
# 2    33761
# Name: postal_code, dtype: object  : 0    18912
# 0    18913
# 0    18914
# 0    18915
# 0    18917
# 0    18928
# 0    18929
# 0    18931
# 0    18932
# 0    18936
# 0    18938
# 0    18940
# 0    18944
# 0    18946
# 0    18947
# 0    18949
# 0    18951
# 0    18954
# 0    18960
# 0    18964
# 0    18966
# Name: postal_code, dtype: object
#  below 10000 Juicy Seafood pos : 0    37216
# 1    37211
# 2    37076
# Name: postal_code, dtype: object  : 0    34221
# 0    34604
# 0    34606
# 0    34607
# 0    34608
# 0    34609
# 0    34610
# 0    34619
# 0    34638
# 0    34639
# 0    34652
# 0    34653
# 0    34654
# 0    34655
# 0    34667
# 0    34668
# 0    34669
# 0    34677
# 0    34683
# 0    34684
# 0    34685
# Name: postal_code, dtype: object

# %%
train_df.shape , test_df.shape

# %%
for i in ['density', 'entropy', 'competitiveness','area_pop', 'accessibility','complementary','relevance']:
    train_df[i] = train_df[i].astype('float')
    test_df[i] = test_df[i].astype('float')
train_df.to_pickle('/home/adam/Steph_C/my_thesis/data/Train_by_postoal_code_without_review_pointwise_v3_3.pkl')
test_df.to_pickle('/home/adam/Steph_C/my_thesis/data/Test_by_postoal_code_without_review_pointwise_v3_3.pkl')
