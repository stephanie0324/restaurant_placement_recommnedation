# %% [markdown]
# # 觀察資料分布
# * YELP
#     * 50 review above
#     * join business, check-in and tips

# %% [markdown]
# # Import

# %%
import pandas as pd
import json
import numpy as np
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle("../Data/yelp/restaurant_only.pkl")

# %%
df.shape
# Out:
# (2112553, 20)

# %%
df.columns
# Out:
# Index(['business_id', 'stars_x', 'useful', 'funny', 'cool', 'text', 'date',
#        'name', 'address', 'city', 'state', 'postal_code', 'latitude',
#        'longitude', 'stars_y', 'review_count', 'is_open', 'attributes',
#        'categories', 'hours'],
#       dtype='object')

# %% [markdown]
# # EDA

# %%
# evidence of there are same name for differenct restaurant
len(Counter(df.business_id)) ,len(Counter(df.name))
# Out:
# (20477, 15522)

# %%
# calculate the city number of each state
for i in Counter(df.state):
    tmp = df[df.state==i]
    print(f'State : {i} ,\
    city no. : {len(Counter(tmp.city))},\
    postal_code cnt : {len(Counter(tmp.postal_code))},\
    restaurant no. : {len(Counter(tmp.business_id))}')
# Out:
# State : PA ,    city no. : 216,    postal_code cnt : 198,    restaurant no. : 4655
# State : CA ,    city no. : 8,    postal_code cnt : 12,    restaurant no. : 552
# State : TN ,    city no. : 33,    postal_code cnt : 51,    restaurant no. : 1852
# State : LA ,    city no. : 22,    postal_code cnt : 42,    restaurant no. : 1494
# State : FL ,    city no. : 97,    postal_code cnt : 121,    restaurant no. : 3844
# State : IN ,    city no. : 27,    postal_code cnt : 60,    restaurant no. : 1689
# State : NJ ,    city no. : 134,    postal_code cnt : 89,    restaurant no. : 1112
# State : NV ,    city no. : 8,    postal_code cnt : 20,    restaurant no. : 890
# State : AB ,    city no. : 9,    postal_code cnt : 331,    restaurant no. : 406
# State : MO ,    city no. : 63,    postal_code cnt : 59,    restaurant no. : 1578
# State : AZ ,    city no. : 12,    postal_code cnt : 38,    restaurant no. : 1177
# State : ID ,    city no. : 6,    postal_code cnt : 16,    restaurant no. : 626
# State : DE ,    city no. : 13,    postal_code cnt : 18,    restaurant no. : 328
# State : IL ,    city no. : 31,    postal_code cnt : 26,    restaurant no. : 274

# %%
# Count the restaurant
cnt = 0

for state_name in Counter(df.state):
    plt.title(state_name)
    plt.xlabel('city')
    plt.ylabel('cnt')
    state = df[df.state == state_name]
    city_list = [c for c in Counter(state.city) ]
    restaurant_list = [ len(Counter(state[state.city == city_name].business_id)) for city_name in city_list]
    postal_code_list = [  len(Counter(state[state.city == city_name].postal_code)) for city_name in city_list]
    plt.plot(city_list, restaurant_list ,label = 'restaurant count')
    plt.plot(city_list, postal_code_list,label = 'postal code count')
    
    plt.show()

# %%
print(len(Counter(df.business_id)))
# Out:
# 20477

# %%
Counter(df.name)
# Out:
# Counter({'Turning Point of North Wales': 175,
#          'Portobello Cafe': 70,
#          'The Original Habit Burger Grill': 117,
#          'Milk and Honey Nashville': 1761,
#          'Cafe Beignet on Bourbon Street': 542,
#          'Termini Bros Bakery': 235,
#          "PizzaMan Dan's": 104,
#          'Harbor Seafood & Oyster Bar': 499,
#          'Ava': 265,
#          'Creole House Restaurant & Oyster Bar': 1272,
#          "Cerveza Jack's": 178,
#          'Deccan Spice': 280,
#          'Loews Philadelphia Hotel': 183,
#          'Limoncello Ristorante & Caterers': 230,
#          'Daddy Dawgs Hot Dogs & Ice Cream': 69,
#          "Dickey's Barbecue Pit": 868,
#          'Milktooth': 807,
#          'Lobster Haven': 254,
#          'Saki Endless Sushi & Hibachi Eatery': 305,
#          'The Pancake Pantry': 1003,
#          'Shishkabob House': 40,
#          'El Limon - Malvern': 125,
#          'On The Border Mexican Grill & Cantina': 463,
#          'Redwood Rotisserie + Grill': 492,
#          'Frontier Steakhouse': 46,
#          'Burritos Grill Mexican Fresh Cuisine': 39,
#          'Numchok Wilai': 20,
#          'San Jose Mexican Restaurant': 155,
#          'China Kitchen': 176,
#          "Landry's Seafood House": 688,
#          'Mariscos Chihuahua': 192,
#          'Misconduct Tavern': 168,
#          'Chick-fil-A': 5407,
#          "Beck's Cajun Cafe": 268,
#          'Panera Bread': 4000,
#          'In the Valley': 62,
#          "Captain Bill's Oyster Bar": 413,
#          "Maggie Mae's Sunrise Cafe": 282,
#          "Angelina's": 50,
#          'Bab Café - Reno': 498,
#          'Biscuit Love: Hillsboro Village': 580,
#          'Ichicoro Ane': 271,
#          "Tony's Donuts - McKelvey": 84,
#          'The Turnip Truck Urban Fare': 48,
#          'Burger Republic': 754,
#          'The Boiling House': 223,
#          'Sips Specialty Coffee House': 108,
#          "Mr. B's Bistro": 824,
#          'Tandoor & Tikka': 261,
#          'Blues City Deli': 431,
#          'Capitol Cellars': 129,
#          'Carisma Restaurante': 56,
#          'Kalamatas - Green Hills': 35,
#          'Trophy Fish': 170,
#          'Cake Life Bake Shop': 231,
#          'Butcher & Bee': 732,
#          'Starbucks': 1696,
#          'Masala Kitchen': 33,
#          'Rice Box': 47,
#          'BK Tacos': 448,
#          'Pacific Health Foods': 43,
#          'Sen Thai Asian Bistro': 182,
#          'Phat Bites': 233,
#          'Prep & Pastry': 1237,
#          'Helena Avenue Bakery': 387,
#          "Li'l Dizzy's Cafe": 378,
#          "St Mary's Mexican Food": 109,
#          "Lucy's Retired Surfers Bar & Restaurant": 284,
#          "Puckett's Grocery & Restaurant": 1945,
#          'Cafe Square One': 154,
#          'Chateau Cafe': 34,
#          'State Street Kitchen': 71,
#          "Harry's Blue Bell Taproom": 63,
#          'Petra Restaurant': 69,
#          'Casa Molina Del Norte': 60,
#          "Giordano's": 515,
#          'SPOT Gourmet Burgers': 196,
#          "Zaxby's Chicken Fingers & Buffalo Wings": 618,
#          "Surrey's Café & Juice Bar": 886,
#          'Provisions Coffee & Kitchen': 229,
#          'Grand Isle': 291,
#          'Crazy Sushi': 207,
#          'Tastee Restaurant': 115,
#          'Coffeebar': 402,
#          "Jesse's Steak and Seafood": 204,
#          "McDonald's": 8363,
#          "J B Dawson's Restaurant & Bar": 177,
#          'Buena Onda': 684,
#          "Anaya's Mexican Restaurant": 53,
#          'Fellini Cafe of Media': 299,
#          'Magasin Kitchen': 115,
#          'Nectar Urban Cantina': 408,
#          'Montesano Bros Trattoria & Catering': 69,
#          'Plaza Deli': 92,
#          'Pizzeria Vetri': 521,
#          'iPho Vietnamese Restaurant': 90,
#          'Jungle Prada Tavern': 79,
#          'Chatham Tap Fishers': 128,
#          'Steamboat Natchez': 417,
#          "Earl's New American": 121,
#          'Smiths Restaurant and Bar': 71,
#          'Mint Modern Vietnamese Bistro & Bar': 224,
#          'Gateway To India': 174,
#          'Johnny Rockets': 377,
#          'The Cuban Sandwich Shop': 279,
#          "Castrillo's Pizza of Inglewood": 39,
#          'Madre - Boutique Taqueria': 146,
#          'Vetri Cucina': 179,
#          'Ichiban': 138,
#          'Village Whiskey': 315,
#          "Mahony's Po-Boys & Seafood": 387,
#          'Santa Barbara Shellfish Company': 1291,
#          'Fair Grinds Coffee House': 47,
#          "Joe's Steaks + Soda Shop": 446,
#          'Red Owl Tavern': 264,
#          'Buena Vista Mexican Restaurant': 87,
#          'Red Hot & Blue Restaurant': 46,
#          'Hendricks BBQ': 296,
#          "Frabotta's Beach Kitchen": 193,
#          'Dawn Patrol': 557,
#          'HipCityVeg': 481,
#          'Loco Mexican Restaurant & Cantina': 280,
#          "Mena's Palace": 172,
#          'Basimo Beach Cafe': 199,
#          '51st Deli': 167,
#          'Ekta Indian Cuisine': 272,
#          'Tomo Sushi & Ramen': 199,
#          'Spasso Italian Grill': 327,
#          'American Social': 807,
#          'Firebirds Wood Fired Grill': 1949,
#          "Edley's Bar-B-Que - 12 South": 624,
#          'The Mad Crab': 187,
#          'The Fountain On Locust': 473,
#          'Delicia': 322,
#          'Top Hog': 92,
#          'The Rice House': 77,
#          'Street- Taco and Beer Co.': 676,
#          'Jazmine': 259,
#          'Eclipse Pizza Co.': 143,
#          'RumFish Grill': 367,
#          'Chipotle Mexican Grill': 5507,
#          'Please-U-Restaurant': 152,
#          "O'Charley's Restaurant & Bar": 576,
#          'Thai Legacy Restaurant': 214,
#          'Raijin Ramen': 620,
#          "Willie's Chicken Shack": 780,
#          'Cracker Barrel Old Country Store': 2630,
#          'Tavern': 554,
#          'The Pearl': 66,
#          'Blaze Pizza': 2289,
#          'Porcini': 76,
#          'Broad Ripple Brewpub': 147,
#          'Super Gyros': 46,
#          'The Three Coins Diner': 180,
#          "Dave & Buster's": 1862,
#          'KRĒM': 346,
#          "Cuenelli's Peruvian Restaurant": 92,
#          "Richard's": 125,
#          "Salty's Island Bar & Grille": 522,
#          'Yah Mon': 427,
#          'Three Muses': 355,
#          'Noble Crust': 1946,
#          'Sockeye Brewing': 159,
#          'Athens Restaurant': 39,
#          'Hibachi Steak House & Sushi Bar': 180,
#          'M.L.Rose Craft Beer & Burgers - Melrose': 217,
#          'Chinese Duck House': 118,
#          'The Roost': 72,
#          'Jack in the Box': 929,
#          'Top Tomato Bar & Pizza': 110,
#          'El Tequila': 21,
#          'Café Piazza': 170,
#          "Gullifty's Restaurant": 108,
#          'The Hungry Greek': 317,
#          'NY Pizza Grill': 37,
#          'The Gypsy Saloon': 95,
#          'Tria Cafe Wash West': 148,
#          'Brick & Mortar': 311,
#          'Vecchia Osteria': 208,
#          "Mac's Tavern": 138,
#          'Greko Greek Street Food': 274,
#          "Mazzaro's Italian Market": 945,
#          "Ron's Original Bar & Grille": 210,
#          'Cafe Soleil': 360,
#          'Pasta Vino': 38,
#          'Square 1682': 127,
#          'The Turning Point - Cherry Hill': 149,
#          'Cucina Zapata': 68,
#          'Fort Ben Pub': 31,
#          "Harry & Izzy's": 586,
#          'Pizzaville': 37,
#          'Padaro Beach Grill': 567,
#          'Yolk Iron Works': 283,
#          'Cafe Fleur De Lis': 1282,
#          "O'Fallon Brewery": 37,
#          'Bourbon & Branch': 230,
#          'Panda Express': 2438,
#          'Hong Kong City': 22,
#          'Trident Grill': 193,
#          'Sauce on the Side': 1062,
#          'Two Chicks Cafe': 639,
#          'Tako Japanese Restaurant': 58,
#          'Nooddi Thai Chef': 141,
#          'Copabanana': 212,
#          'Sushiya Express': 82,
#          'Flambo Caribbean Restaurant': 135,
#          "Katie's Restaurant & Bar": 756,
#          'Brunchies - Lutz': 280,
#          "Ken's Seafood Restaurant": 39,
#          'Williams Sub Shop': 63,
#          'Masami Japanese Steakhouse & Sushi Bar': 91,
#          "Barro's Pizza": 217,
#          'Slate Bleu Restaurant': 38,
#          'Sweet Soulfood': 393,
#          'Veekoo': 146,
#          'The Village Diner': 30,
#          'Prohibition Taproom': 182,
#          'Luke': 1803,
#          'Holmesburg Bakery': 41,
#          'The Love': 635,
#          'Hellas Restaurant': 867,
#          'San Antonio Taco Co': 140,
#          "Carmelita's Mexican Restaurant": 179,
#          'The C House': 388,
#          'Han Dynasty': 1207,
#          "Shephard's Beach Resort": 195,
#          "Muriel's Jackson Square": 936,
#          'Marrakesh': 285,
#          'Penang': 487,
#          'SF Kitchen': 231,
#          'Tuna Bar': 250,
#          'KFC': 712,
#          'Clear Sky on Cleveland': 358,
#          'Brooklyn Pizza & Cafe': 67,
#          'Zeppoli': 122,
#          'Germantown Pub': 144,
#          "Joe's Crab Shack": 396,
#          '6 North Cafe': 45,
#          "AJ's Fine Foods": 102,
#          'Crown & Bull': 475,
#          'The Depot Craft Brewery Distillery': 810,
#          'Mamas Kitchen': 304,
#          'Compère Lapin': 543,
#          'Rusty Pelican - Tampa': 505,
#          'La Colombe Coffee': 434,
#          'El Arado Mexican Grill': 88,
#          'Fellini Cafe': 168,
#          '4 Rivers Smokehouse': 478,
#          'Earl of Sandwich': 155,
#          'Kawa Japanese Cuisine': 133,
#          'Earnest Bar & Hideaway': 269,
#          'The Cake Bake Shop by Gwendolyn Rogers-Broad Ripple Village': 685,
#          'Five Star Pizza': 85,
#          'sweetgreen': 432,
#          'Aston Diner': 59,
#          'Chopstick House': 76,
#          'Donut Drive-In': 129,
#          'honeygrow': 1109,
#          'Fireside Pizza Cafe': 162,
#          'Las Palmas Mexican Restaurant': 318,
#          "BJ's Restaurant & Brewhouse": 2028,
#          'Persian Room Fine Dining': 268,
#          "Nico's Pizza": 25,
#          "P.F. Chang's": 2553,
#          "Applebee's Grill + Bar": 2969,
#          "Growler's Taphouse": 159,
#          'Berlins Doener': 178,
#          'The Pasta House': 380,
#          'Oregon Steaks': 104,
#          "World Famous N'awlins Cafe & Spice Emporium": 152,
#          'Zoes Kitchen': 864,
#          'Louis Pappas Fresh Greek': 188,
#          'Jjang Ga Nae': 25,
#          'Cafe Du Monde': 269,
#          "Yoichi's": 109,
#          'Le Rendez-vous': 115,
#          'Burger Up': 284,
#          'University Club of Santa Barbara': 32,
#          'Jasmine Rice - Rittenhouse': 105,
#          'Tokyo Mandarin': 77,
#          'Samurai Sushi': 135,
#          'The Block': 99,
#          "Lilly's Cafe": 373,
#          'Steak ’n Shake': 2822,
#          'Kei Sushi': 376,
#          "Jalapeño's 2": 80,
#          'Candlewyck Beef & Ale': 33,
#          "Cheddar's Scratch Kitchen": 1514,
#          "Jack Dempsey's Restaurant & Bar": 77,
#          'Los Jefes Tortilleria & Grill': 524,
#          "Mike's Ice Cream": 287,
#          'Persis Biryani Indian Grill': 172,
#          'The Little Lamb': 293,
#          'El Jefe Restaurant & Mexican Grill': 36,
#          'Zen Yai Thai Cuisine': 125,
#          'Schlafly Bottleworks': 182,
#          'The Nations Bar & Grill': 47,
#          'Margaritaville - Nashville': 339,
#          'Bittersweet Confections': 193,
#          'Gyro Shack': 186,
#          'La Tavola Ristorante Italiano': 96,
#          'District Donuts Sliders Brew': 1320,
#          "Verchio's Produce Outlet": 25,
#          'Grand Hyatt Tampa Bay': 109,
#          "Joey's New York Pizza and Italian Restaurant": 434,
#          'Marmont Steakhouse & Bar': 122,
#          "Andrea's Restaurant": 119,
#          'Fresco Pizzeria': 124,
#          'Granite City Food & Brewery': 424,
#          'Seminole Hard Rock Hotel & Casino Tampa': 396,
#          '101 Taiwanese Cuisine': 603,
#          'Livery - Indianapolis': 954,
#          'Sachiko Sushi': 308,
#          'Pita Kebob': 91,
#          'Aqui Con El Nene': 171,
#          'Ole Red': 634,
#          'Bistro Habanero': 124,
#          'Stefano Greek Italian Restaurant': 52,
#          'Cool Springs Brewery': 132,
#          'Yolklore': 212,
#          'Vitascope Hall': 64,
#          '312 Pizza Company': 269,
#          'Bangkokville Thai Cuisine': 266,
#          'Vela': 75,
#          'The Spot Sushi Burritos': 154,
#          "George's Wings": 24,
#          'Los Comparres': 199,
#          'Twin Peaks': 220,
#          'Besito Mexican Restaurant': 797,
#          'Another Broken Egg Cafe': 3336,
#          'Ralphs Italian Restaurant': 256,
#          'Wayback Burgers': 440,
#          "Giovanni's Pizzeria": 27,
#          "Blondie's Coffee and Wine Bar": 131,
#          'Temaki Sushi': 51,
#          'El Charro Cafe': 1427,
#          'India Sizzling II': 110,
#          'Sushi Bar': 152,
#          'Fleming’s Prime Steakhouse & Wine Bar': 1196,
#          'BAP': 91,
#          "Wendy's": 1670,
#          'Hooters': 1424,
#          "Trip's Diner": 399,
#          'Sushi Avenue': 86,
#          'Thai Phooket Smyrna': 41,
#          "Mei's World Pizza": 73,
#          'Le Peep': 352,
#          'The Cider Factory': 91,
#          'Indy Tacos': 162,
#          'Asian Pho': 89,
#          'Asian Kitchen': 104,
#          'Stoney River Steakhouse and Grill': 311,
#          'ABC Pizza House': 69,
#          'The Pint Room': 223,
#          'Urban Village Brewing Co': 231,
#          'Phamous Cafe': 156,
#          '365 Caffe Italiano': 47,
#          'The Hattery Stove & Still': 216,
#          "Tony's Restaurant & 3rd Street Cafe": 50,
#          'Sun Diner': 441,
#          'Suraya': 1157,
#          'Taqueria El Sol': 47,
#          '3 Sisters Café': 243,
#          'Ardmore Pizza': 63,
#          'Desire Oyster Bar': 494,
#          "Sal DeForte's Ristorante": 25,
#          'Karma Juice Bar & Eatery - Saint Petersburg': 165,
#          'Smyrna Cafe': 186,
#          "The Howlin' Wolf": 109,
#          "Jimboy's Tacos": 265,
#          'Golden Triangle': 104,
#          'Pi Pizzeria - Delmar Loop': 144,
#          'Embassy Suites by Hilton Tampa Airport Westshore': 70,
#          "Boostin' Bowls": 77,
#          'Tokai Sushi Hibachi Steakhouses': 89,
#          '1200 Chophouse': 286,
#          "Valentino's Ristorante": 92,
#          "Taziki's Mediterranean Cafe - Mt. Juliet": 46,
#          "Sabrina's Café": 1927,
#          'Mellow Mushroom - Brandon': 214,
#          "Logan's Roadhouse": 317,
#          'Peno': 142,
#          'Filomena Cucina Italiana': 36,
#          "Porter & Luke's": 60,
#          'Naf Naf Grill': 392,
#          'Sushi Tyme': 98,
#          'Olive Garden Italian Restaurant': 3012,
#          "Dong's China Buffet": 39,
#          "Ralph's on the Park": 142,
#          "Rollin' Oats Market": 54,
#          "Soco's Gyros": 40,
#          'Orchids Thai Restaurant': 90,
#          'KELP Sushi Joint': 265,
#          "Hendel's": 206,
#          'Stella Maris Restaurant & Hookah Lounge': 45,
#          "Lulu's Pizza": 53,
#          'Ooka Restaurant': 169,
#          'Pho Hoan Pasteur': 102,
#          'Cafe Napoli Restaurant & Pizzeria': 63,
#          'New China': 262,
#          "Pinocchio's Restaurant": 98,
#          'Chase Restaurant': 269,
#          'Taqueria Los 3 Toritos': 43,
#          'Cedar Park Cafe': 121,
#          'Chadds Ford Tavern': 150,
#          "Zeko's Mediterranean Grill": 295,
#          "Ted Peter's Famous Smoked Fish": 250,
#          'Cafe Con Leche': 103,
#          'Red Mesa Restaurant': 253,
#          'Holiday Inn Philadelphia-Cherry Hill': 51,
#          "Domino's Pizza": 1770,
#          'Sheraton Indianapolis Hotel at Keystone Crossing': 75,
#          'Soy Bistro': 242,
#          'Casino Del Sol': 177,
#          'Chuck E. Cheese': 123,
#          'Dugout Bar': 89,
#          'Gaylord Opryland Resort & Convention Center': 841,
#          "Chuck's BBQ": 36,
#          'Sakura': 186,
#          'Cafe Provencal': 51,
#          "Sam's Beach Bar": 374,
#          'Monon Coffee Company': 75,
#          "Marjie's Grill": 170,
#          "Blake's Lotaburger": 235,
#          "Honey's Sit-N-Eat": 306,
#          "Bruno's Pizza & Restaurant": 48,
#          'Ninja Sushi Japanese Grill': 42,
#          'Farmer Boy': 172,
#          "Al's Finger Licking Good Bar-B-Que": 226,
#          'Five Guys': 1342,
#          'The Blue Duck': 289,
#          'CD Roma Restaurant': 91,
#          'Three Brothers Coffee': 189,
#          'Taqueria Cuernavaca': 168,
#          "Inchin's Bamboo Garden": 159,
#          "Guru's Indian Cuisine": 268,
#          'West Ave Grille Jenkintown Restaurant and Food Truck ': 167,
#          'Old Times Kafe': 66,
#          'Mizu Sushi Bar': 86,
#          "TJ Smith's": 64,
#          "Sabrina's West Street Kitchen": 579,
#          'Cold Spring Tavern': 445,
#          "Morrow's": 856,
#          'Saigon Restaurant': 204,
#          'House of Blues Restaurant & Bar': 167,
#          "Zimmer's Seafood": 33,
#          'Bobby Hotel': 182,
#          "TJ's Italian Cafe": 119,
#          "Fulin's Asian Cuisine": 185,
#          'Ryan Christopher': 46,
#          'Logan Inn': 149,
#          'Bayou Bistro Louisiana Cuisine': 192,
#          'Federal Donuts': 580,
#          'Fox & Hound': 24,
#          'San Jose Mexican Restaurant Webster Groves': 47,
#          'Rembrandts': 268,
#          'Wildflower Cafe': 267,
#          "Herbie's Restaurant": 168,
#          "J's Seafood Dock": 199,
#          'Outback Steakhouse': 3467,
#          'Tacodelphia': 245,
#          'Berix Restaurant': 44,
#          "Scannicchio's": 84,
#          'Peggs Restaurant On the Boulevard': 41,
#          'In-N-Out Burger': 824,
#          'O! Wing Plus': 86,
#          'New Orleans Social House': 139,
#          'Tasty Tomato Italian Eatery': 23,
#          'Treme Coffeehouse': 90,
#          'Sea Turtle Restaurant': 192,
#          'Red Lobster': 2065,
#          'SharpShooter Indoor Shooting Range': 22,
#          'Three 12 Sport Bar and Lounge': 33,
#          "Jimmy John's": 625,
#          'Three Carrots Fountain Square': 256,
#          'Pikpon Thai': 128,
#          'Tzin Wine & Tapas': 43,
#          "Syberg's on Market": 51,
#          'Buffalo Bell': 36,
#          'The Cubby Hole': 153,
#          'Buckingham Pizza': 26,
#          'Village Inn': 323,
#          'Biscuits Cafe': 173,
#          'Vineyards Cafe': 118,
#          'Zaika': 68,
#          'Barrio Brewing': 267,
#          'Favela Chic': 90,
#          "Dagwood's Pub": 92,
#          'The Honu': 192,
#          "Johny's Original Pizza": 39,
#          'Texas Roadhouse': 3277,
#          "Tony's Luke": 93,
#          'Tampa Bay Brewing Company Westchase': 346,
#          'Charro Steak & Del Rey': 515,
#          'Little Caesars': 155,
#          'Suis Generis': 32,
#          "Chickie's & Pete's": 1086,
#          'Whistle Stop Gourmet Coffee Shop': 34,
#          'Pho Street': 318,
#          'Wawa': 409,
#          "Ghini's French Caffe": 181,
#          "Chili's": 3545,
#          'Backyard Bowls': 492,
#          'Western Village Inn and Casino': 142,
#          'Bagel Bin of Voorhees': 63,
#          'El Sitio': 59,
#          'Breakfast Boutique Chestnut Hill': 152,
#          "Jimmy Guana's": 106,
#          'Noodles & Company': 471,
#          'Moto Cucina + Enoteca': 237,
#          'El Camino Real': 275,
#          'Shere-E-Punjab': 107,
#          'Pho King': 24,
#          "Michael's Grill": 98,
#          'Wei Asian Cafe': 60,
#          "HORN'S EATERY": 345,
#          "Larry's Steaks": 141,
#          'Ants Pants Café': 185,
#          'Kuchi Sushi & Hibachi': 188,
#          'Copper Vine': 355,
#          "Raising Cane's Chicken Fingers- Arnold": 26,
#          'Hachi': 159,
#          'Fiamme Pizza': 387,
#          'Taj Mahal Homestyle Indian & Pakistani Cuisine': 138,
#          'Wasabi Sushi': 133,
#          "Jerzee's Sports Bar & Pizzeria": 30,
#          "Anthony's Coal Fired Pizza": 1118,
#          'Lazos Pizza & Grill': 71,
#          "Jack Patrick's Bar & Grill": 43,
#          'Waffle House': 1244,
#          'World of Beer': 943,
#          'Islands Restaurant': 211,
#          'Timpano Hyde Park': 195,
#          "Bernie's Restaurant & Bar - Hatboro": 211,
#          'Franklin Juice Co': 41,
#          'C J Muggs': 43,
#          "Finnegan's Pub": 45,
#          'Café at The Square': 135,
#          'Tomo Japanese Steakhouse and Sushi Bar': 115,
#          'Thai Place Restaurant': 75,
#          'Bar Louie - Carmel': 194,
#          "P J Whelihan's Pub & Restaurant - Oaks": 148,
#          'Dots Diner - Williams Blvd.': 148,
#          'Italian Kitchen & Cafe': 93,
#          'The Black Sheep Pub & Restaurant': 77,
#          'PJ Subs': 36,
#          'Duck Donuts': 297,
#          "Frank's Spaghetti House": 24,
#          'The Original Bagel': 44,
#          "Guido's Italian Restaurant": 73,
#          'Incredible Pizza Company - St. Louis': 49,
#          'Grace Meat + Three': 487,
#          'Fiesta Taqueria': 129,
#          'Maynards': 257,
#          "Zorba's Taverna": 209,
#          'The Food Liaison': 56,
#          'Florida Subs & Gyros': 41,
#          'Nordstrom Grill': 25,
#          "Alfredo's Pizza": 38,
#          'Blue Sage Vegetarian Grille': 238,
#          "T J Courtney's Restaurant and Catering": 69,
#          'Piccolina Toscana': 37,
#          'Oaks Italian Deli & Pizzeria': 36,
#          'Brick City Eatery': 117,
#          'Vientiane Café': 91,
#          'Chatham Tap Mass. Ave.': 147,
#          'Transcend Coffee - Ritchie Market': 33,
#          'TacoSon': 342,
#          "Frank's Pizza & Restaurant": 75,
#          'District Tavern': 178,
#          'StarLite Sapphire': 31,
#          'Sicilian Pasta Kitchen South': 40,
#          "Iguana's Mexican Restaurant": 162,
#          'Wishbone': 222,
#          'The Twisted Tail': 295,
#          'Hollywood Grill': 97,
#          'Rittenhouse Grill': 94,
#          'Boise Bistro Market': 24,
#          'Siam Elephant': 248,
#          "Hon's Wok": 59,
#          'Twistee Treat - Tarpon Springs': 41,
#          "Carmine's Steakhouse": 135,
#          'Brew Brothers': 291,
#          "Smiley's Cafe": 145,
#          'Port of Subs': 230,
#          'The Cheesecake Factory - Cool Springs': 178,
#          'Mirko Pasta': 196,
#          'Global Quesadilla Company': 59,
#          'Kauboi Izakaya': 261,
#          'México Lindo': 54,
#          'Red Pony': 182,
#          'Gold Coffee Pancake House': 98,
#          'The Bricks': 203,
#          "Chase's Hop Shop": 66,
#          'IHOP': 3317,
#          'Sake Cafe of Elmwood': 52,
#          "Dewey's Pizza": 640,
#          "Apollo's Family Pizzeria": 47,
#          'Bar Avalon': 64,
#          'Restaurant des Familles': 98,
#          'Remedy Cafe': 145,
#          'Hearth Kitchen': 105,
#          'Thai House': 60,
#          "J Gilbert's Wood-Fired Steaks & Seafood St Louis": 155,
#          'Kampai Sushi Bar': 127,
#          'Thai 5 Fast Food': 231,
#          'Meun Fan Thai Cafe': 233,
#          'Wimpys Original': 49,
#          "Miller's Ale House - Springfield": 123,
#          'Hilton Garden Inn Nashville Vanderbilt': 68,
#          'Organico Pizza': 107,
#          'Burger Up - Franklin': 148,
#          "Culver's": 1451,
#          'Chiang Mai Thai Noodle': 147,
#          "Big Woody's BBQ": 111,
#          'Burger Theory': 95,
#          'Bubba Gump Shrimp Co.': 136,
#          'Marathon': 203,
#          "Fray's Donut House": 117,
#          'Tennessee Brew Works': 315,
#          'St. Pete Bagel Co.': 181,
#          'DK Sushi': 32,
#          'Tortas El Guero': 161,
#          'Meadows Diner': 71,
#          "Baileys' Range": 600,
#          'LongHorn Steakhouse': 2343,
#          'Pearl Diver': 153,
#          "Brawley's Restaurant": 58,
#          "LaScala's Pronto - Mt. Laurel": 57,
#          'Home Plate Sports Pub': 30,
#          'Slices Pizza': 72,
#          'Ristorante Attilio': 25,
#          'No Label At The Table': 38,
#          'HipCityVeg - University City': 130,
#          'Freshii': 73,
#          'Mac Mart': 247,
#          'Hearthside': 165,
#          "Angie's Restaurant": 25,
#          'The Burger Joint': 28,
#          'Il Giardino': 43,
#          'La Mulita': 56,
#          'Lorenzo & Sons Pizza': 228,
#          "Romano's Macaroni Grill": 456,
#          'La Casona': 68,
#          'The Workshop Eatery': 107,
#          'Natural Cafe': 89,
#          'Circle S BBQ': 78,
#          'Stone Creek Zionsville': 126,
#          "Raising Cane's Chicken Fingers": 651,
#          "Felix's Restaurant & Oyster Bar": 2485,
#          'Cafe Reconcile': 55,
#          "Spatola's Pizza": 82,
#          'Brio Italian Grille': 791,
#          '30 Main': 59,
#          'Asian Harbor': 164,
#          'Tryst Gastro Lounge': 148,
#          'M.L.Rose Craft Beer & Burgers - Sylvan Park': 159,
#          "Punky's Bar and Grill": 86,
#          'Tasties': 122,
#          'Poseidon': 129,
#          'Golden Chopstick Chinese Restaurant': 73,
#          "Franci's Cafe": 21,
#          'Chicken and Watermelon': 89,
#          "The Captain's Boil": 66,
#          'Revolucion': 183,
#          'Oriental Pearl Restaurant': 111,
#          "Barbara's Home Cookin": 58,
#          'Uno Pizzeria & Grill': 469,
#          'Backspace Bar & Kitchen': 232,
#          'The Enerjuicer': 71,
#          'Penca': 204,
#          "Henry's Coffee Bistro": 67,
#          'Toyama Japanese Steak House': 56,
#          'Glory Days Grill': 1036,
#          'Wang Gang Asian': 110,
#          'La Guerrerita Mexican Food': 84,
#          "Sister Muhammad's Kitchen": 90,
#          'Brick House Tavern + Tap': 420,
#          "Bitar's": 62,
#          'Angelos Pizza': 76,
#          'Huong Sizzling Wok': 45,
#          'Gray Brothers Cafeteria': 169,
#          'Porterhouse': 48,
#          'Tokyo': 81,
#          'Sher-e-Punjab': 245,
#          'La Patisserie Chouquette': 120,
#          'Gourmet Wok': 37,
#          'Well Crafted Beer Company': 67,
#          'Summit Cakery & Cafe': 23,
#          'Sushi Ushi': 137,
#          'Public Service': 106,
#          'India Café': 165,
#          'Coffee': 29,
#          'Egg Platter': 25,
#          "River's Edge": 21,
#          "Brady's BBQ": 64,
#          'Mi Ranchito': 271,
#          'Las Cazuelas Restaurant BYOB': 102,
#          'Gourmet Pizza Company': 85,
#          'Pizza Guys': 142,
#          "Hungry Howie's Pizza": 53,
#          'Eet Gud Bakery': 47,
#          "Pica's Restaurant": 148,
#          'Lima Fusion': 33,
#          'Spice Finch': 334,
#          "Keke's Breakfast Cafe": 1300,
#          'Dots Diner': 103,
#          'Iron Hill Brewery & Restaurant': 1981,
#          'Cactus Restaurant & Bar': 133,
#          "Nephew's Ristorante": 46,
#          'HotBox Pizza': 203,
#          'Beach Hut Deli': 74,
#          'Taqueria Pico De Gallo': 143,
#          'Olio': 236,
#          "Jimmy B's Eatery & Pub": 26,
#          "Cayton's Burger Bistro": 65,
#          'Tsunami Sushi': 352,
#          'Big Island Poke': 134,
#          'Double Greeting Wonton House': 25,
#          'Keva Juice': 63,
#          'August Moon Chinese Restaurant': 33,
#          'Royal Sonesta New Orleans': 222,
#          'City Barbeque': 535,
#          'Kung Fu Noodle': 165,
#          'Smoke BBQ': 147,
#          'The Bakery House': 64,
#          'Express Cafe': 58,
#          "Murph's Bar": 237,
#          "Dominick's Pizzeria and Restaurant": 26,
#          'Fez Moroccon Restaurant': 39,
#          'QDOBA Mexican Eats': 1367,
#          "Josef's Vienna Bakery & Cafe": 222,
#          'The Freshworks of Port Richmond': 42,
#          'Skyway Cafe': 143,
#          "Bully's Sports Bar & Grill": 331,
#          'Newtown Bagel': 47,
#          'King Ribs Bar-B-Q': 64,
#          'Seoul Garden': 209,
#          'Tom Jones Family Restaurant': 30,
#          'Akira Hibachi & Sushi Bar': 61,
#          'The Blind Tiger Cafe - Ybor City': 221,
#          'Danny Boy Beer Works': 112,
#          'Cove Cay Golf Club': 28,
#          'Swagruha Indian Cuisine': 36,
#          'Queen of Sheba': 181,
#          "Fuzzy's Taco Shop": 917,
#          'ZigZag Scallop': 153,
#          'Umami': 238,
#          "Moon's Kitchen Cafe": 87,
#          "Bono's Pizzeria": 77,
#          'Pub & Kitchen': 119,
#          "Barrister's Bagels": 66,
#          'Petite 4': 127,
#          "Galatoire's 33 Bar & Steak": 131,
#          'Red Robin Gourmet Burgers and Brews': 2499,
#          'Mr.Wish KOP': 50,
#          'Convivio Italian Artisan Cuisine': 326,
#          'Suzy-Jo Donuts': 33,
#          "Michaelangelo's Pizza Restaurant": 31,
#          'Upland Carmel Tap House': 134,
#          'Tired Hands Fermentaria': 292,
#          'Hoang Tofu': 75,
#          "Eli's Bar B Que": 43,
#          'Red Hook Coffee & Tea': 60,
#          "Mom Mom's Kitchen and Polish Food Cart": 70,
#          'Biscuits Country Cafe': 87,
#          'Embassy Suites by Hilton Tampa Downtown Convention Center': 108,
#          'St. Louis Bread': 792,
#          'Annex': 46,
#          'Octopus Falafel Truck': 157,
#          'Eat-well Food Mart': 53,
#          'Zio Pizza Palace & Grill': 20,
#          'The Golden Eagle Diner and Restaurant': 93,
#          'Super China Buffet': 25,
#          'Cate Zone Chinese Cafe': 278,
#          'Good Karma Cafe': 135,
#          "Paola's Pizzeria": 79,
#          'Santa Fe': 102,
#          'Casita Taqueria': 486,
#          "Sculley's Waterfront Restaurant": 202,
#          "Philly's Best": 22,
#          'Fortunatos Pizza Station': 48,
#          'PrimoHoagies': 537,
#          'Double Decker Pizza - Media': 50,
#          'M3 Restaurant': 159,
#          'Solly Pizza': 25,
#          "Em J's Cafe": 78,
#          'Books & Brews - Zionsville': 55,
#          "Moxie's Spirits & Dining": 77,
#          'The Flying Bridge': 33,
#          'City Limits Bakery & Cafe': 51,
#          'Aldertos Fresh Mexican Food': 112,
#          'Kuba ': 232,
#          'Westmont Diner': 77,
#          'fat Rooster diner': 23,
#          'Cafe Envie & Espresso Bar': 140,
#          'Deja Brew Laugh A Latte': 120,
#          'Del Taco': 308,
#          'LUVI Restaurant': 166,
#          'Sushi Rose': 255,
#          'Villa Bistro': 20,
#          'Botto’s Italian Line Restaurant': 81,
#          'India Palace': 165,
#          'Yama-Taiyo Japanese Cuisine & Sushi Bar': 30,
#          'Four Green Fields': 34,
#          'El Fogón Latino': 21,
#          'Sonic Drive-In': 1166,
#          'Chill Restaurant & Bar': 251,
#          'Snellgroves Restaurant': 32,
#          'Khyber Pass Pub': 218,
#          "Ray's Subs": 20,
#          "Da Vinci's Brick Oven Pizzeria": 32,
#          'Hampton House Waffles & Eatery': 50,
#          'Andale Latino Grill': 152,
#          'Parada Maimon': 120,
#          'Upper Crust Pizza & Italian Restaurant': 25,
#          "Rode's Fireside Restaurant & Tavern": 45,
#          'City Greens': 127,
#          'First Watch': 6702,
#          'Albasha Greek & Lebanese Café': 68,
#          "Hudsons Canada's Pub": 23,
#          "Caruso's": 260,
#          "Beanie's Bar & Sports Grill": 42,
#          'Tre Lune': 153,
#          "Micha's": 59,
#          'Sicilian Trattoria': 36,
#          'El Merendero': 128,
#          'El Maguey': 184,
#          "Via Marconi's Pizza Pub": 71,
#          'Gryphon Cafe': 116,
#          'Chicago Paulies': 139,
#          'Los Rancheros': 49,
#          "C.I. Chu's Mongolian Barbeque": 89,
#          'Pollo Tropical': 570,
#          'Jong Ka Jib': 74,
#          'The Happy Mixer Gluten Free Bakery': 108,
#          'Asian Cafe': 38,
#          'Barbecue and Bourbon': 194,
#          'Trattoria Carina': 219,
#          'Siam Cafe': 54,
#          "Zydeco's": 186,
#          'Villagio Cinemas': 81,
#          'Taco Bell': 3072,
#          'The Smiling Elephant': 231,
#          'Lloyd Whiskey Bar': 68,
#          'Sakana Sushi Bar & Japanese': 103,
#          'Nirvana Indian Bistro': 155,
#          "Fazoli's": 143,
#          'D-Town Bar & Grill': 109,
#          'Woodbury Station Cafe': 61,
#          'Havana Dreamers Cafe': 117,
#          'Central Pizza': 30,
#          'Xochitl': 89,
#          'Super China Chinese Restaurant': 45,
#          "Oliver's": 321,
#          'Circle 7 Ranch': 517,
#          'Kopper Kitchen': 104,
#          'Boulevard Pizza': 110,
#          'The Silverspoon': 88,
#          'Simply Delicious - Country Market & Deli': 44,
#          'Chopt Creative Salad Co.': 182,
#          "Snarf's Sandwiches - Saint Louis": 53,
#          'Ninth Street Deli at Howards': 57,
#          'Trappixx Jamaican Restaurant': 57,
#          "Anthony's at Paxon Hollow": 23,
#          "Mrs Marty's Deli": 43,
#          'Tandoori Of India': 72,
#          'Superior Grill': 218,
#          'Mr X Pizza': 27,
#          'Terra Sur Cafe': 158,
#          'Tsunami Japanese Steakhouse': 108,
#          'Happy Italian Pizzeria': 62,
#          'Biryani Hut': 85,
#          'The Independent': 132,
#          'Phily Diner & Sports Bar': 111,
#          "Franny Lou's Porch": 51,
#          'Bubble Shack': 100,
#          'Thai Orchid': 281,
#          "McAlister's Deli": 1102,
#          'PokeDoke': 224,
#          'la Madeleine': 102,
#          "J'aime French Bakery": 321,
#          "Nick's Old Original Roast Beef": 138,
#          'Pho Voorhees': 141,
#          'Cinnaholic': 138,
#          'Koi Sushi & Thai': 196,
#          'Bonks Bar': 25,
#          "Dale's Family Restaurant": 93,
#          'Crust N Fire': 98,
#          'Casa Garcia Mexican Restaurant': 96,
#          "Jet's Pizza": 643,
#          'Sushi Ai': 795,
#          "Lamberti's Tutti Toscani": 80,
#          'Gran Agave': 229,
#          'Kabob House': 177,
#          'Poblanos Mexican Grill & Bar': 105,
#          'Bandit Coffee Co.': 216,
#          "Carrabba's Italian Grill": 1757,
#          'Southgate': 202,
#          'Café Zupas': 190,
#          'Vientiane Bistro': 70,
#          'Los Cantaritos': 38,
#          'Belleair Coffee Company': 77,
#          "Tin's House, Thai Cuisine & Sushi": 83,
#          'Coco Thai Bistro': 78,
#          'Wasabi2': 81,
#          'Mizu Asian Bistro': 95,
#          'America’s Deli': 20,
#          'La Bella Pizzeria & Ristorante Italiano': 24,
#          "Brenda's On the Causeway": 34,
#          'Sushi Nara': 96,
#          "Cyrano's": 138,
#          'Opry Backstage Grill': 90,
#          'Jaco Juice and Taco': 54,
#          'Pizzarella Grille': 28,
#          'Kien Giang': 94,
#          'Blackthorn Pub and Pizza': 204,
#          "Judge Bean's BBQ": 96,
#          "Franzone's Pizzeria & Restaurant": 136,
#          'Blueplate': 150,
#          "H & T's Homecooking": 85,
#          'SoFresh': 541,
#          'Winners Circle Pub': 28,
#          'Black Horse Diner & Restaurant': 62,
#          'Sushi Sho Rexley': 125,
#          'Nuevo Vallarta Authentic Mexican Food': 66,
#          'Westside Pizza': 37,
#          "Donnie Russell's Pic III Wings & Things": 23,
#          "Tasty Tom's": 34,
#          'Taqueria Guerrero': 102,
#          'Affton Diner': 53,
#          'Red Habanero': 96,
#          'Wild Garlic': 32,
#          'Turchettis Delicatessen': 118,
#          'Soup Dumplings STL': 172,
#          'Sansom Kabob House': 59,
#          'Ploy Thai': 78,
#          'Pho 36': 104,
#          "Yori's Church Street Bakery": 49,
#          "Pepo's Cuban Cafe": 82,
#          'Ninki': 113,
#          'Pho Bistro': 66,
#          'Sabor Latin Cuisine': 155,
#          'Tijuana Flats': 1143,
#          'Jersey Java and Tea': 53,
#          'Cafe Pontalba': 270,
#          "Godfather's Pizza": 36,
#          'Fulton Alley': 67,
#          'The Original Pancake House': 477,
#          'Rangoli: Vibrant Flavors of India': 40,
#          'The Creperie Cafe': 66,
#          'Top Shelf Sports Lounge': 99,
#          'Wei Hong Bakery & Restaurant': 44,
#          "Spiro's Restaurant": 137,
#          'HandleBar': 49,
#          "Skeeter's Pub": 46,
#          'The Daily Bread Bakery & Cafe': 61,
#          'Philly Diner': 44,
#          "Jiallo's": 62,
#          "Angela's Mexican Food": 37,
#          "Baggin's": 89,
#          'Pupuseria & Cafeteria Centroamericana': 77,
#          'Taquería La Juquilita': 64,
#          'Green Herb Thai Cuisine': 40,
#          'Silver Peak Grill & Taproom': 159,
#          'Asian Taste Inn': 33,
#          'Foundation Room': 27,
#          "Shorty's Breakfast & Gourmet Deli": 52,
#          'Parxgrill': 43,
#          'Ajo Cafe': 24,
#          "Coco's Cocina Tex Mex  Restaurant": 63,
#          'Spring Chinese Restaurant': 30,
#          'Mexico Lindo': 22,
#          'Taco Suave': 30,
#          'Mozzarella Pizzeria': 52,
#          'Corropolese Bakery & Deli': 158,
#          "Semenza's Pizzeria": 64,
#          'Rostizado - by Tres Carnales': 76,
#          'Groupers On The Gulf': 124,
#          'Simply Thai Restaurant': 34,
#          'No Anchovies': 127,
#          'Oakleys Bistro': 143,
#          "Maria's Ristorante on Summit": 44,
#          'Gachi Sushi and Noodle': 145,
#          "Imo's Pizza": 535,
#          'The Urban Juicer': 141,
#          'Aroma Indian Bistro': 107,
#          'La Fuente Mexican Grill': 82,
#          'Tampa Pizza Co - Westchase': 44,
#          'Bawarchi Indian Restaurant': 57,
#          'K-Bop STL': 57,
#          'Thai Country Cafe': 75,
#          'MOD Pizza': 2052,
#          'Maemax Market': 84,
#          'Sunset 44 Bistro': 42,
#          'Top China': 20,
#          'Benihana': 560,
#          'La Collina': 68,
#          'New Orleans Hamburger & Seafood Co.': 56,
#          'Sundial St. Pete': 27,
#          ...})

# %%
Counter(df[df.name=='Turning Point of North Wales'].postal_code)

# %%
# Count the restaurant's postal code
cnt = 0

restaurant_postal_count ={}
for i in Counter(df.business_id):
    tmp = df[df.business_id==i]
    print(tmp , tmp.postal_code)
    restaurant_postal_count[i]=len(Counter(df[df.business_id==i].postal_code))
    break
# Out:
#                 business_id  stars_x  useful  funny  cool  \
# 0    XQfwVwDr-v0ZS3_CbbE5Xw      3.0       0      0     0
# 1    XQfwVwDr-v0ZS3_CbbE5Xw      2.0       0      0     0
# 2    XQfwVwDr-v0ZS3_CbbE5Xw      4.0       2      0     1
# 3    XQfwVwDr-v0ZS3_CbbE5Xw      3.0       0      0     0
# 4    XQfwVwDr-v0ZS3_CbbE5Xw      2.0       0      0     0
# ..                      ...      ...     ...    ...   ...
# 170  XQfwVwDr-v0ZS3_CbbE5Xw      5.0       0      0     0
# 171  XQfwVwDr-v0ZS3_CbbE5Xw      3.0       0      0     0
# 172  XQfwVwDr-v0ZS3_CbbE5Xw      4.0       0      1     0
# 173  XQfwVwDr-v0ZS3_CbbE5Xw      4.0       0      0     0
# 174  XQfwVwDr-v0ZS3_CbbE5Xw      2.0       1      0     0
#
#                                                   text                date  \
# 0    If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1    This is the second time we tried turning point... 2017-05-13 17:06:55
# 2    The place is cute and the staff was very frien... 2017-08-08 00:58:18
# 3    We came on a Saturday morning after waiting a ... 2017-11-19 02:20:23
# 4    Mediocre at best. The decor is very nice, and ... 2017-09-09 17:49:47
# ..                                                 ...                 ...
# 170  Great service and friendly staff. Amazing food... 2021-12-05 17:18:28
# 171  Food was good and staff is nice but service is... 2018-01-07 16:41:56
# 172  "When I dip you dip we dip!"\n\n"You put yours... 2019-01-01 19:42:23
# 173  I came here on a Sunday around 11, hoping that... 2020-02-21 12:36:51
# 174  So I've been to Turning Point now three times ... 2019-03-23 18:36:29
#
#                              name              address         city state  \
# 0    Turning Point of North Wales  1460 Bethlehem Pike  North Wales    PA
# 1    Turning Point of North Wales  1460 Bethlehem Pike  North Wales    PA
# 2    Turning Point of North Wales  1460 Bethlehem Pike  North Wales    PA
# 3    Turning Point of North Wales  1460 Bethlehem Pike  North Wales    PA
# 4    Turning Point of North Wales  1460 Bethlehem Pike  North Wales    PA
# ..                            ...                  ...          ...   ...
# 170  Turning Point of North Wales  1460 Bethlehem Pike  North Wales    PA
# 171  Turning Point of North Wales  1460 Bethlehem Pike  North Wales    PA
# 172  Turning Point of North Wales  1460 Bethlehem Pike  North Wales    PA
# 173  Turning Point of North Wales  1460 Bethlehem Pike  North Wales    PA
# 174  Turning Point of North Wales  1460 Bethlehem Pike  North Wales    PA
#
#     postal_code   latitude  longitude  stars_y  review_count  is_open  \
# 0         19454  40.210196 -75.223639      3.0           169        1
# 1         19454  40.210196 -75.223639      3.0           169        1
# 2         19454  40.210196 -75.223639      3.0           169        1
# 3         19454  40.210196 -75.223639      3.0           169        1
# 4         19454  40.210196 -75.223639      3.0           169        1
# ..          ...        ...        ...      ...           ...      ...
# 170       19454  40.210196 -75.223639      3.0           169        1
# 171       19454  40.210196 -75.223639      3.0           169        1
# 172       19454  40.210196 -75.223639      3.0           169        1
# 173       19454  40.210196 -75.223639      3.0           169        1
# 174       19454  40.210196 -75.223639      3.0           169        1
#
#                                             attributes  \
# 0    {'NoiseLevel': 'u'average'', 'HasTV': 'False',...
# 1    {'NoiseLevel': 'u'average'', 'HasTV': 'False',...
# 2    {'NoiseLevel': 'u'average'', 'HasTV': 'False',...
# 3    {'NoiseLevel': 'u'average'', 'HasTV': 'False',...
# 4    {'NoiseLevel': 'u'average'', 'HasTV': 'False',...
# ..                                                 ...
# 170  {'NoiseLevel': 'u'average'', 'HasTV': 'False',...
# 171  {'NoiseLevel': 'u'average'', 'HasTV': 'False',...
# 172  {'NoiseLevel': 'u'average'', 'HasTV': 'False',...
# 173  {'NoiseLevel': 'u'average'', 'HasTV': 'False',...
# 174  {'NoiseLevel': 'u'average'', 'HasTV': 'False',...
#
#                                             categories  \
# 0    Restaurants, Breakfast & Brunch, Food, Juice B...
# 1    Restaurants, Breakfast & Brunch, Food, Juice B...
# 2    Restaurants, Breakfast & Brunch, Food, Juice B...
# 3    Restaurants, Breakfast & Brunch, Food, Juice B...
# 4    Restaurants, Breakfast & Brunch, Food, Juice B...
# ..                                                 ...
# 170  Restaurants, Breakfast & Brunch, Food, Juice B...
# 171  Restaurants, Breakfast & Brunch, Food, Juice B...
# 172  Restaurants, Breakfast & Brunch, Food, Juice B...
# 173  Restaurants, Breakfast & Brunch, Food, Juice B...
# 174  Restaurants, Breakfast & Brunch, Food, Juice B...
#
#                                                  hours
# 0    {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
# 1    {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
# 2    {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
# 3    {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
# 4    {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
# ..                                                 ...
# 170  {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
# 171  {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
# 172  {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
# 173  {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
# 174  {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
#
# [175 rows x 20 columns] 0      19454
# 1      19454
# 2      19454
# 3      19454
# 4      19454
#        ...
# 170    19454
# 171    19454
# 172    19454
# 173    19454
# 174    19454
# Name: postal_code, Length: 175, dtype: object

# %%
pd.DataFrame(restaurant_postal_count , index=[0]).T
# Out:
#                         0
# XQfwVwDr-v0ZS3_CbbE5Xw  1

# %%
pd.DataFrame(Counter(restaurant_postal_count.values()), columns=['branch count','No. of Restaurant'])
# Out:
# Empty DataFrame
# Columns: [branch count, No. of Restaurant]
# Index: []

# %%
data = list(Counter(restaurant_postal_count).values())
c = Counter(data)
c = sorted(c.items())
months_num = [i[0] for i in c]
# month_names = [months[i[0]-1] for i in c]
freq = [i[1] for i in c]

# print(c)
# print(months)
# print(freq)


plt.bar(months_num, freq)
plt.title("Postal Code number per Restaurant")
plt.xlabel("No. of postal codes")
plt.ylabel("Count")

plt.show()

# %%
diff_list = []
for i in Counter(df.name):
    tmp = df[df.name==i]
    postal_code_list = [int(i) for i in Counter(tmp.postal_code) if i.isdigit()]
    if len(postal_code_list)>1:
        diff_list.append( max(postal_code_list)-min(postal_code_list))

# %%
c = Counter(diff_list)
c = sorted(c.items())
diff = [i[0] for i in c]
freq = [i[1] for i in c]


plt.bar(diff, freq)

# %%
c

# %% [markdown]
# # By State
# * Use FL for starters , only 7 seven cities

# %%
df = df[df.state == 'FL']

# %%
df.shape

# %%
for_lda_df = df.copy()

# %%
for_lda_df.shape

# %%
# get the restaurants that has branches in at least 3 different cities
for j in Counter(df.name):
    tmp = df[df.name==j]
    if len(Counter(tmp.city))<3:
        df = df.drop(tmp.index)
        df.reset_index()

# %%
df.shape

# %%
for_lda_df[~for_lda_df.name.isin(df.name)]

# %%
brand = Counter(df.name)
plt.bar(brand.keys(), brand.values())

# %%
df.to_pickle("../Data/yelp/FL_only.pkl")  
for_lda_df.to_pickle("../Data/yelp/LDA_training.pkl")

# %% [markdown]
# ## Observe the Ratings by Brand

# %%
# # count the cities by one brand 
# for i in Counter(df.name):
#     tmp = df[df.name==i]
#     print(Counter(tmp.city))

# %%
tmp = df[df.name=='Turning Point of North Wales']

# %%
Counter(tmp.business_id)

# %%
# Count the overall std for each brand
l_= []
for i in Counter(df.name):
    tmp = df[df.name==i]
    dict_ = tmp.stars_x.describe().to_dict()
    dict_['name']=i
    l_.append(dict_)
b = pd.DataFrame(l_)
b

# %%
# Count the std for each brand by city 
l_= []
for i in Counter(df.name):
    tmp = df[df.name==i]
    dict_ = tmp.stars_x.describe().to_dict()
    dict_['name']=i
    l_.append(dict_)
b = pd.DataFrame(l_)
b

# %% [markdown]
# ## Obeserve the postal code

# %%
len(Counter(df.postal_code))

# %%
# count the restaurant of an post code
cnt = 0

postal_restaurant_count ={}
for i in Counter(df.postal_code):
    tmp = df[df.postal_code==i]
    postal_restaurant_count[i]=len(Counter(tmp.name))

# %%
lists = sorted(postal_restaurant_count.items(),key=lambda x:x[1], reverse=True) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)

# %%
dict(sorted(postal_restaurant_count.items(),key=lambda x:x[1], reverse=True))
