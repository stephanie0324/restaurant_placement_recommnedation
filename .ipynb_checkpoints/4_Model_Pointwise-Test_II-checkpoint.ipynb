# %% [markdown]
# # Pointwise
# * predict the relevance scores

# %% [markdown]
# # Import

# %%
from collections import Counter
import numpy as np  
import pandas as pd 
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt 
from sklearn.preprocessing import scale 
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler 
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.linear_model import LogisticRegression
from sklearn.utils import shuffle

# models
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from lightgbm import LGBMRanker

import warnings
warnings.filterwarnings("ignore")

# %%
RANDOM_STATE = 24

# %%
# 導入資料
train_df = pd.read_pickle('/home/adam/Steph_C/my_thesis/data/Train_by_postoal_code_without_review_pointwise_v2_2.pkl')
test_df = pd.read_pickle('/home/adam/Steph_C/my_thesis/data/Test_by_postoal_code_without_review_pointwise_v2_2.pkl')

# %%
train_df = train_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

# %%
len(Counter(train_df.name))
# Out:
# 1053

# %%
train_df.shape
# Out:
# (15636, 27)

# %%
test_df.shape
# Out:
# (8391, 27)

# %%
# # expr. 1 change relevance score to binary
# # change_rel_score = lambda df: 1 if df['relevance']>0 else 0
# def change_rel_score(df):
#     for i in range(len(df)):
#         if df.relevance[i] > 0 :
#             df.relevance[i]=1
#         else:
#             pass
    
#     return df
# train_df = change_rel_score(train_df)
# test_df = change_rel_score(test_df)

# %% [markdown]
# # Models

# %%
def _precision(predictions , actuals, k = None):
    
    """
    Calculate the precision at k
    
    Returns: a list of precisions
    """
    
    precisions =[]

    
    for i in range(len(predictions)):
        
        prediction = predictions[i]

        if  k != None:
            prediction =  predictions[i][:k]
#             print(f"prediction: {prediction}")
        
#         print(f"actuals: {actuals}")
        score = 0
        for j in prediction:
            if j in actuals[i]:
                score+=1
        
        print(f"Score(分子):{score}")
        print(f"len(prediction)(分母):{len(prediction)}")
        
        p_score = score/len(prediction) if len(prediction)!=0 else 0
        precisions.append(p_score)
    return precisions
    

def _recall(predictions , actuals, k = None):
    
    """
    Calculate the precision at k
    
    Returns: a list of recalls
    """
    recalls =[]
    
    for i in range(len(predictions)):
        
        prediction =  predictions[i]
        
        if  k != None:
            prediction =  predictions[i][:k]
        
        score = 0
        for j in range(len(prediction)):
            if prediction[j] in actuals[i]:
                score+=1
        recalls.append(score/len(actuals[i]))
    
    return recalls

# %%
def calculate_mrr(predictions, actuals):
    """
    Calculate the mean reciprocal rank (MRR) for a set of predictions and actual values.
    
    Parameters:
    predictions (list of lists): A list of predicted rankings sorted by probability.
    actual (list of lists): A list of actual rankings sorted by relevance.
    
    Returns:    
    float: A list of MRR scores.
    """
    mrr_list = []
    for i in range(len(predictions)):
        reciprocal_rank = 0
        if actuals[i][0] in predictions[i]:
            reciprocal_rank = 1/(predictions[i].index(actuals[i][0]) + 1)
        mrr_list.append(reciprocal_rank)
    return mrr_list

# %%
def calculate_map( predictions , actuals, k=None):
    """
    Calculate the mean average precision (MAP) for a set of queries.

    Parameters:
    actual (list of sets or lists): A list of sets or lists of the actual relevant items for each query.
    predicted (list of lists): A list of lists of predicted items for each query.
    k (int): The maximum number of predicted items to consider for each query.

    Returns:
    float: A list of MAP scores.
    """
    
    map_list = []
    

    for i in range(len(predictions)):
        
        ap_list = []
        hit = 0 
        cnt = 0 
        
        prediction =  predictions[i]
        
        if k != None:
            prediction =  predictions[i][:k]
        
        
        for j in prediction:
            if j in actuals[i]:
                hit+=1
                cnt+=1
                ap_list.append(hit/cnt)
            else:
                cnt+=1
        map_list.append(np.mean(ap_list))
    
    return map_list

# %%
def calculate_dcg_ndcg( predictions , actuals, rel ,k=None):
    """
    Calculate the DCG@k , NDCG@k for a set of queries.

    Parameters:
    actual (list of sets or lists): A list of sets or lists of the actual relevant items for each query.
    predicted (list of lists): A list of lists of predicted items for each query.
    k (int): The maximum number of predicted items to consider for each query.

    Returns:
    float: A list of DCG , NDCG scores.
    """
    dcg_list = []
    ndcg_list = []
    
    for i in range(len(predictions)):
        dcg =0
        idcg =0
        
        prediction = predictions[i]
        
        if k != None:
            prediction = predictions[i][:k]
        
        for j in range(len(actuals[i])):
            if actuals[i][j] in prediction:
                rank = prediction.index(actuals[i][j]) + 1
                dcg += np.divide(float(rel[i][j]),np.log2(rank+1))
                idcg += np.divide(float(rel[i][j]),np.log2((j+1)+1))
        dcg_list.append(dcg)
        if np.divide(dcg,idcg) > 1:
            print(rel[i], prediction,actuals[i]  )
            print(i,dcg,idcg  , 'Wrong !!!')
        ndcg_list.append(np.divide(dcg,idcg))
        
    return dcg_list , ndcg_list

# %%
# create list of list for query ranking
def get_ranking(df ):
    
    """
    Turn the probability array into a list of lists for calculation.
    
    Parameters:
    df(DataFrame): the test dataframe
    
    Returns:
    prediction (list of lists): A list of predicted rankings for each query.
    actual (list of lists): A list of actual rankings for each query.
    """
 
    pred_list = []
    pred_rel = []
    true_list = []
    
    
    for res in Counter(df.business_id):
        
        tmp = df[df.business_id == res]
        a_sorted = tmp.sort_values(by=['relevance'],ascending=[False])
        print(f"a_sorted:\n {a_sorted.business_id}")
        p_sorted = tmp.sort_values(by=['predictions'],ascending=[False])
        print(f"p_sorted:\n {p_sorted.business_id}")

        true_list.append(list(a_sorted[a_sorted.relevance!=0].postal_code))
        pred_list.append(list(p_sorted.postal_code))
        pred_rel.append(list(a_sorted[a_sorted.relevance!=0].relevance))
        
    return pred_list, pred_rel , true_list

# %% [markdown]
# # Model

# %%
# models
LR = LogisticRegression(random_state=RANDOM_STATE)
RF = RandomForestClassifier(random_state=RANDOM_STATE)
DTC = DecisionTreeClassifier(random_state=RANDOM_STATE)
KNC = KNeighborsClassifier()
SVC = svm.SVC(random_state=RANDOM_STATE)
GNB = GaussianNB()
LGBM = LGBMRanker(objective="lambdarank",random_state=RANDOM_STATE)

train_features=['density', 'entropy', 'competitiveness','area_pop', 'accessibility','complementary']

get_group_size = lambda df: df.reset_index().groupby("name")['name'].count()

train_groups = get_group_size(train_df).to_numpy()
test_groups = get_group_size(test_df).to_numpy()

print(sum(train_groups) , sum(test_groups))
# Out:
# 15636 8391

# %%
counts = train_df[['relevance']].value_counts()
counts
# Out:
# relevance
# 0.0          13852
# 11.0           588
# 12.0           556
# 10.0           251
# 9.0            125
# 8.0             87
# 7.0             55
# 6.0             34
# 5.0             31
# 4.0             23
# 2.0             14
# 3.0             13
# 1.0              7
# dtype: int64

# %%
log_model = LogisticRegression(solver='lbfgs', max_iter=1000)

# %%
train_df = shuffle(train_df, random_state=RANDOM_STATE)
test_df = shuffle(test_df, random_state=RANDOM_STATE)

models = [LR, RF, DTC, KNC, SVC, GNB]
model_name =['LR', 'RF', 'DTC', 'KNC', 'SVC', 'GNB']
score_dict = {}

for i in range(len(models)):
    score_dict[model_name[i]]={}
    model = models[i]
    # Train
    if model_name[i] != 'LGBMRanker':
        model.fit(train_df[train_features].values, train_df[['relevance']].values.ravel())
    else:
        model.fit(train_df[train_features].values, train_df[['relevance']].values.ravel(), group=train_groups)
    
    # Predict
#     print("前：", test_df.head(10))
    predict = model.predict(test_df[train_features].values)
#     print(f"predict:{predict[:20]}")
#     print(f"actual:{test_df[['relevance']].values.ravel()[:20]}")
    test_df['predictions'] = predict
#     print("-"*20)
#     print("後：", test_df.head(10))
    pred_list, pred_rel , true_list = get_ranking(test_df)

    # Evaluation
#     mrr_list = calculate_mrr(pred_list , true_list)
#     map_list = calculate_map(pred_list , true_list)
#     dcg_list , ndcg_list = calculate_dcg_ndcg(pred_list , true_list,pred_rel)
    precision_list_1 = _precision(pred_list , true_list, k=1)
    recall_list_1 = _recall(pred_list , true_list, k=1)
#     precision_list_3 = _precision(pred_list , true_list, k=3)
#     recall_list_3 = _recall(pred_list , true_list,k=3)
#     precision_list = _precision(pred_list , true_list)
#     recall_list = _recall(pred_list , true_list)

    score_dict[model_name[i]]['precision @ 1'] = np.mean(precision_list_1)
    score_dict[model_name[i]]['recall @ 1'] = np.mean(recall_list_1)
#     score_dict[model_name[i]]['precision @ 3 '] = np.mean(precision_list_3)
#     score_dict[model_name[i]]['recall @ 3'] = np.mean(recall_list_3)
#     score_dict[model_name[i]]['precision'] = np.mean(precision_list)
#     score_dict[model_name[i]]['recall'] = np.mean(recall_list)
#     score_dict[model_name[i]]['mrr'] = np.mean(mrr_list)
#     score_dict[model_name[i]]['map'] = np.mean(map_list)
#     score_dict[model_name[i]]['dcg'] = np.mean(dcg_list)
#     score_dict[model_name[i]]['ndcg'] = np.mean(ndcg_list)
# Out:
# a_sorted:
#  1545    H2jXjqiq7MkhZHg8H6nc1Q
# 1548    H2jXjqiq7MkhZHg8H6nc1Q
# 1550    H2jXjqiq7MkhZHg8H6nc1Q
# 1544    H2jXjqiq7MkhZHg8H6nc1Q
# 1547    H2jXjqiq7MkhZHg8H6nc1Q
# 1549    H2jXjqiq7MkhZHg8H6nc1Q
# 1546    H2jXjqiq7MkhZHg8H6nc1Q
# Name: business_id, dtype: object
# p_sorted:
#  1545    H2jXjqiq7MkhZHg8H6nc1Q
# 1548    H2jXjqiq7MkhZHg8H6nc1Q
# 1550    H2jXjqiq7MkhZHg8H6nc1Q
# 1544    H2jXjqiq7MkhZHg8H6nc1Q
# 1547    H2jXjqiq7MkhZHg8H6nc1Q
# 1549    H2jXjqiq7MkhZHg8H6nc1Q
# 1546    H2jXjqiq7MkhZHg8H6nc1Q
# Name: business_id, dtype: object
# a_sorted:
#  3428    3zfXupWFqA809Cez3oQbSw
# 3429    3zfXupWFqA809Cez3oQbSw
# 3430    3zfXupWFqA809Cez3oQbSw
# 3431    3zfXupWFqA809Cez3oQbSw
# 3427    3zfXupWFqA809Cez3oQbSw
# 3426    3zfXupWFqA809Cez3oQbSw
# 3425    3zfXupWFqA809Cez3oQbSw
# Name: business_id, dtype: object
# p_sorted:
#  3428    3zfXupWFqA809Cez3oQbSw
# 3429    3zfXupWFqA809Cez3oQbSw
# 3430    3zfXupWFqA809Cez3oQbSw
# 3431    3zfXupWFqA809Cez3oQbSw
# 3427    3zfXupWFqA809Cez3oQbSw
# 3426    3zfXupWFqA809Cez3oQbSw
# 3425    3zfXupWFqA809Cez3oQbSw
# Name: business_id, dtype: object
# a_sorted:
#  1823    ZJC0ONdxmIlwidXd8E0fXg
# 1821    ZJC0ONdxmIlwidXd8E0fXg
# 1826    ZJC0ONdxmIlwidXd8E0fXg
# 1822    ZJC0ONdxmIlwidXd8E0fXg
# 1827    ZJC0ONdxmIlwidXd8E0fXg
# 1825    ZJC0ONdxmIlwidXd8E0fXg
# 1824    ZJC0ONdxmIlwidXd8E0fXg
# Name: business_id, dtype: object
# p_sorted:
#  1823    ZJC0ONdxmIlwidXd8E0fXg
# 1821    ZJC0ONdxmIlwidXd8E0fXg
# 1826    ZJC0ONdxmIlwidXd8E0fXg
# 1822    ZJC0ONdxmIlwidXd8E0fXg
# 1827    ZJC0ONdxmIlwidXd8E0fXg
# 1825    ZJC0ONdxmIlwidXd8E0fXg
# 1824    ZJC0ONdxmIlwidXd8E0fXg
# Name: business_id, dtype: object
# a_sorted:
#  5760    mDTJ6OVTQhBk6b_wK32YfA
# 5757    mDTJ6OVTQhBk6b_wK32YfA
# 5759    mDTJ6OVTQhBk6b_wK32YfA
# 5762    mDTJ6OVTQhBk6b_wK32YfA
# 5758    mDTJ6OVTQhBk6b_wK32YfA
# 5756    mDTJ6OVTQhBk6b_wK32YfA
# 5761    mDTJ6OVTQhBk6b_wK32YfA
# Name: business_id, dtype: object
# p_sorted:
#  5760    mDTJ6OVTQhBk6b_wK32YfA
# 5757    mDTJ6OVTQhBk6b_wK32YfA
# 5759    mDTJ6OVTQhBk6b_wK32YfA
# 5762    mDTJ6OVTQhBk6b_wK32YfA
# 5758    mDTJ6OVTQhBk6b_wK32YfA
# 5756    mDTJ6OVTQhBk6b_wK32YfA
# 5761    mDTJ6OVTQhBk6b_wK32YfA
# Name: business_id, dtype: object
# a_sorted:
#  6048    P-a6WMxnBncXP4ZnFXeYww
# 6051    P-a6WMxnBncXP4ZnFXeYww
# 6052    P-a6WMxnBncXP4ZnFXeYww
# 6049    P-a6WMxnBncXP4ZnFXeYww
# 6053    P-a6WMxnBncXP4ZnFXeYww
# 6050    P-a6WMxnBncXP4ZnFXeYww
# 6047    P-a6WMxnBncXP4ZnFXeYww
# Name: business_id, dtype: object
# p_sorted:
#  6048    P-a6WMxnBncXP4ZnFXeYww
# 6051    P-a6WMxnBncXP4ZnFXeYww
# 6052    P-a6WMxnBncXP4ZnFXeYww
# 6049    P-a6WMxnBncXP4ZnFXeYww
# 6053    P-a6WMxnBncXP4ZnFXeYww
# 6050    P-a6WMxnBncXP4ZnFXeYww
# 6047    P-a6WMxnBncXP4ZnFXeYww
# Name: business_id, dtype: object
# a_sorted:
#  7002    434A83c2ig6QxsZjrjclpQ
# 7001    434A83c2ig6QxsZjrjclpQ
# 7000    434A83c2ig6QxsZjrjclpQ
# 7003    434A83c2ig6QxsZjrjclpQ
# 6998    434A83c2ig6QxsZjrjclpQ
# 6999    434A83c2ig6QxsZjrjclpQ
# 6997    434A83c2ig6QxsZjrjclpQ
# Name: business_id, dtype: object
# p_sorted:
#  7002    434A83c2ig6QxsZjrjclpQ
# 7001    434A83c2ig6QxsZjrjclpQ
# 7000    434A83c2ig6QxsZjrjclpQ
# 7003    434A83c2ig6QxsZjrjclpQ
# 6998    434A83c2ig6QxsZjrjclpQ
# 6999    434A83c2ig6QxsZjrjclpQ
# 6997    434A83c2ig6QxsZjrjclpQ
# Name: business_id, dtype: object
# a_sorted:
#  104    oIH5YWPy_g61YXM6R900Wg
# 100    oIH5YWPy_g61YXM6R900Wg
# 105    oIH5YWPy_g61YXM6R900Wg
# 103    oIH5YWPy_g61YXM6R900Wg
# 99     oIH5YWPy_g61YXM6R900Wg
# 101    oIH5YWPy_g61YXM6R900Wg
# 102    oIH5YWPy_g61YXM6R900Wg
# Name: business_id, dtype: object
# p_sorted:
#  104    oIH5YWPy_g61YXM6R900Wg
# 100    oIH5YWPy_g61YXM6R900Wg
# 105    oIH5YWPy_g61YXM6R900Wg
# 103    oIH5YWPy_g61YXM6R900Wg
# 99     oIH5YWPy_g61YXM6R900Wg
# 101    oIH5YWPy_g61YXM6R900Wg
# 102    oIH5YWPy_g61YXM6R900Wg
# Name: business_id, dtype: object
# a_sorted:
#  3400    _0u1MwrTyXx7bLWuVW1XwQ
# 3399    _0u1MwrTyXx7bLWuVW1XwQ
# 3405    _0u1MwrTyXx7bLWuVW1XwQ
# 3402    _0u1MwrTyXx7bLWuVW1XwQ
# 3404    _0u1MwrTyXx7bLWuVW1XwQ
# 3403    _0u1MwrTyXx7bLWuVW1XwQ
# 3401    _0u1MwrTyXx7bLWuVW1XwQ
# Name: business_id, dtype: object
# p_sorted:
#  3400    _0u1MwrTyXx7bLWuVW1XwQ
# 3399    _0u1MwrTyXx7bLWuVW1XwQ
# 3405    _0u1MwrTyXx7bLWuVW1XwQ
# 3402    _0u1MwrTyXx7bLWuVW1XwQ
# 3404    _0u1MwrTyXx7bLWuVW1XwQ
# 3403    _0u1MwrTyXx7bLWuVW1XwQ
# 3401    _0u1MwrTyXx7bLWuVW1XwQ
# Name: business_id, dtype: object
# a_sorted:
#  3092    kcOWQgF8gnehRd1UVmBkAw
# 3097    kcOWQgF8gnehRd1UVmBkAw
# 3096    kcOWQgF8gnehRd1UVmBkAw
# 3093    kcOWQgF8gnehRd1UVmBkAw
# 3099    kcOWQgF8gnehRd1UVmBkAw
# 3095    kcOWQgF8gnehRd1UVmBkAw
# 3098    kcOWQgF8gnehRd1UVmBkAw
# 3094    kcOWQgF8gnehRd1UVmBkAw
# Name: business_id, dtype: object
# p_sorted:
#  3093    kcOWQgF8gnehRd1UVmBkAw
# 3097    kcOWQgF8gnehRd1UVmBkAw
# 3096    kcOWQgF8gnehRd1UVmBkAw
# 3092    kcOWQgF8gnehRd1UVmBkAw
# 3099    kcOWQgF8gnehRd1UVmBkAw
# 3095    kcOWQgF8gnehRd1UVmBkAw
# 3098    kcOWQgF8gnehRd1UVmBkAw
# 3094    kcOWQgF8gnehRd1UVmBkAw
# Name: business_id, dtype: object
# a_sorted:
#  3460    enXvNN8pFfz76KT1PZFlPQ
# 3455    enXvNN8pFfz76KT1PZFlPQ
# 3459    enXvNN8pFfz76KT1PZFlPQ
# 3458    enXvNN8pFfz76KT1PZFlPQ
# 3461    enXvNN8pFfz76KT1PZFlPQ
# 3457    enXvNN8pFfz76KT1PZFlPQ
# 3456    enXvNN8pFfz76KT1PZFlPQ
# Name: business_id, dtype: object
# p_sorted:
#  3460    enXvNN8pFfz76KT1PZFlPQ
# 3455    enXvNN8pFfz76KT1PZFlPQ
# 3459    enXvNN8pFfz76KT1PZFlPQ
# 3458    enXvNN8pFfz76KT1PZFlPQ
# 3461    enXvNN8pFfz76KT1PZFlPQ
# 3457    enXvNN8pFfz76KT1PZFlPQ
# 3456    enXvNN8pFfz76KT1PZFlPQ
# Name: business_id, dtype: object
# a_sorted:
#  1144    STtVemevd30WoiZWn_taiQ
# 1147    STtVemevd30WoiZWn_taiQ
# 1146    STtVemevd30WoiZWn_taiQ
# 1148    STtVemevd30WoiZWn_taiQ
# 1149    STtVemevd30WoiZWn_taiQ
# 1150    STtVemevd30WoiZWn_taiQ
# 1145    STtVemevd30WoiZWn_taiQ
# Name: business_id, dtype: object
# p_sorted:
#  1144    STtVemevd30WoiZWn_taiQ
# 1147    STtVemevd30WoiZWn_taiQ
# 1146    STtVemevd30WoiZWn_taiQ
# 1148    STtVemevd30WoiZWn_taiQ
# 1149    STtVemevd30WoiZWn_taiQ
# 1150    STtVemevd30WoiZWn_taiQ
# 1145    STtVemevd30WoiZWn_taiQ
# Name: business_id, dtype: object
# a_sorted:
#  7164    eLqHSAK0bXcEy6Q8pBYR0w
# 7163    eLqHSAK0bXcEy6Q8pBYR0w
# 7160    eLqHSAK0bXcEy6Q8pBYR0w
# 7161    eLqHSAK0bXcEy6Q8pBYR0w
# 7165    eLqHSAK0bXcEy6Q8pBYR0w
# 7162    eLqHSAK0bXcEy6Q8pBYR0w
# 7166    eLqHSAK0bXcEy6Q8pBYR0w
# Name: business_id, dtype: object
# p_sorted:
#  7166    eLqHSAK0bXcEy6Q8pBYR0w
# 7164    eLqHSAK0bXcEy6Q8pBYR0w
# 7163    eLqHSAK0bXcEy6Q8pBYR0w
# 7160    eLqHSAK0bXcEy6Q8pBYR0w
# 7161    eLqHSAK0bXcEy6Q8pBYR0w
# 7165    eLqHSAK0bXcEy6Q8pBYR0w
# 7162    eLqHSAK0bXcEy6Q8pBYR0w
# Name: business_id, dtype: object
# a_sorted:
#  7370    FAmVbvlu58BbpVuJlAUuVw
# 7373    FAmVbvlu58BbpVuJlAUuVw
# 7372    FAmVbvlu58BbpVuJlAUuVw
# 7369    FAmVbvlu58BbpVuJlAUuVw
# 7371    FAmVbvlu58BbpVuJlAUuVw
# 7368    FAmVbvlu58BbpVuJlAUuVw
# 7367    FAmVbvlu58BbpVuJlAUuVw
# Name: business_id, dtype: object
# p_sorted:
#  7370    FAmVbvlu58BbpVuJlAUuVw
# 7373    FAmVbvlu58BbpVuJlAUuVw
# 7372    FAmVbvlu58BbpVuJlAUuVw
# 7369    FAmVbvlu58BbpVuJlAUuVw
# 7371    FAmVbvlu58BbpVuJlAUuVw
# 7368    FAmVbvlu58BbpVuJlAUuVw
# 7367    FAmVbvlu58BbpVuJlAUuVw
# Name: business_id, dtype: object
# a_sorted:
#  5714    95d60_mjUg2kLy-bhDLC6w
# Name: business_id, dtype: object
# p_sorted:
#  5714    95d60_mjUg2kLy-bhDLC6w
# Name: business_id, dtype: object
# a_sorted:
#  7374    oKvzmVhA1dKf-UARX4EpzQ
# 7376    oKvzmVhA1dKf-UARX4EpzQ
# 7377    oKvzmVhA1dKf-UARX4EpzQ
# 7378    oKvzmVhA1dKf-UARX4EpzQ
# 7381    oKvzmVhA1dKf-UARX4EpzQ
# 7379    oKvzmVhA1dKf-UARX4EpzQ
# 7380    oKvzmVhA1dKf-UARX4EpzQ
# 7375    oKvzmVhA1dKf-UARX4EpzQ
# Name: business_id, dtype: object
# p_sorted:
#  7377    oKvzmVhA1dKf-UARX4EpzQ
# 7376    oKvzmVhA1dKf-UARX4EpzQ
# 7374    oKvzmVhA1dKf-UARX4EpzQ
# 7378    oKvzmVhA1dKf-UARX4EpzQ
# 7381    oKvzmVhA1dKf-UARX4EpzQ
# 7379    oKvzmVhA1dKf-UARX4EpzQ
# 7380    oKvzmVhA1dKf-UARX4EpzQ
# 7375    oKvzmVhA1dKf-UARX4EpzQ
# Name: business_id, dtype: object
# a_sorted:
#  6241    kFwYrDiiVuaEuw1WIV260w
# 6240    kFwYrDiiVuaEuw1WIV260w
# 6239    kFwYrDiiVuaEuw1WIV260w
# 6242    kFwYrDiiVuaEuw1WIV260w
# 6243    kFwYrDiiVuaEuw1WIV260w
# 6238    kFwYrDiiVuaEuw1WIV260w
# 6244    kFwYrDiiVuaEuw1WIV260w
# Name: business_id, dtype: object
# p_sorted:
#  6241    kFwYrDiiVuaEuw1WIV260w
# 6240    kFwYrDiiVuaEuw1WIV260w
# 6239    kFwYrDiiVuaEuw1WIV260w
# 6242    kFwYrDiiVuaEuw1WIV260w
# 6243    kFwYrDiiVuaEuw1WIV260w
# 6238    kFwYrDiiVuaEuw1WIV260w
# 6244    kFwYrDiiVuaEuw1WIV260w
# Name: business_id, dtype: object
# a_sorted:
#  8353    I1jkXzkuNXkeuFUPOGUdoA
# 8357    I1jkXzkuNXkeuFUPOGUdoA
# 8359    I1jkXzkuNXkeuFUPOGUdoA
# 8360    I1jkXzkuNXkeuFUPOGUdoA
# 8355    I1jkXzkuNXkeuFUPOGUdoA
# 8354    I1jkXzkuNXkeuFUPOGUdoA
# 8356    I1jkXzkuNXkeuFUPOGUdoA
# 8358    I1jkXzkuNXkeuFUPOGUdoA
# Name: business_id, dtype: object
# p_sorted:
#  8357    I1jkXzkuNXkeuFUPOGUdoA
# 8359    I1jkXzkuNXkeuFUPOGUdoA
# 8353    I1jkXzkuNXkeuFUPOGUdoA
# 8360    I1jkXzkuNXkeuFUPOGUdoA
# 8355    I1jkXzkuNXkeuFUPOGUdoA
# 8354    I1jkXzkuNXkeuFUPOGUdoA
# 8356    I1jkXzkuNXkeuFUPOGUdoA
# 8358    I1jkXzkuNXkeuFUPOGUdoA
# Name: business_id, dtype: object
# a_sorted:
#  4784    3Wyjm5SA7BxwJK3RBpkqcg
# 4790    3Wyjm5SA7BxwJK3RBpkqcg
# 4788    3Wyjm5SA7BxwJK3RBpkqcg
# 4785    3Wyjm5SA7BxwJK3RBpkqcg
# 4787    3Wyjm5SA7BxwJK3RBpkqcg
# 4786    3Wyjm5SA7BxwJK3RBpkqcg
# 4789    3Wyjm5SA7BxwJK3RBpkqcg
# Name: business_id, dtype: object
# p_sorted:
#  4784    3Wyjm5SA7BxwJK3RBpkqcg
# 4790    3Wyjm5SA7BxwJK3RBpkqcg
# 4788    3Wyjm5SA7BxwJK3RBpkqcg
# 4785    3Wyjm5SA7BxwJK3RBpkqcg
# 4787    3Wyjm5SA7BxwJK3RBpkqcg
# 4786    3Wyjm5SA7BxwJK3RBpkqcg
# 4789    3Wyjm5SA7BxwJK3RBpkqcg
# Name: business_id, dtype: object
# a_sorted:
#  2295    d-cajJNm80ee4YyGARtbUg
# Name: business_id, dtype: object
# p_sorted:
#  2295    d-cajJNm80ee4YyGARtbUg
# Name: business_id, dtype: object
# a_sorted:
#  2517    h4mVi5rnwnVrBX0dSEzFbQ
# 2512    h4mVi5rnwnVrBX0dSEzFbQ
# 2513    h4mVi5rnwnVrBX0dSEzFbQ
# 2516    h4mVi5rnwnVrBX0dSEzFbQ
# 2511    h4mVi5rnwnVrBX0dSEzFbQ
# 2514    h4mVi5rnwnVrBX0dSEzFbQ
# 2515    h4mVi5rnwnVrBX0dSEzFbQ
# Name: business_id, dtype: object
# p_sorted:
#  2517    h4mVi5rnwnVrBX0dSEzFbQ
# 2512    h4mVi5rnwnVrBX0dSEzFbQ
# 2513    h4mVi5rnwnVrBX0dSEzFbQ
# 2516    h4mVi5rnwnVrBX0dSEzFbQ
# 2511    h4mVi5rnwnVrBX0dSEzFbQ
# 2514    h4mVi5rnwnVrBX0dSEzFbQ
# 2515    h4mVi5rnwnVrBX0dSEzFbQ
# Name: business_id, dtype: object
# a_sorted:
#  7022    yUndy-LC5huRJs75s0X1IA
# 7027    yUndy-LC5huRJs75s0X1IA
# 7024    yUndy-LC5huRJs75s0X1IA
# 7021    yUndy-LC5huRJs75s0X1IA
# 7025    yUndy-LC5huRJs75s0X1IA
# 7026    yUndy-LC5huRJs75s0X1IA
# 7023    yUndy-LC5huRJs75s0X1IA
# Name: business_id, dtype: object
# p_sorted:
#  7022    yUndy-LC5huRJs75s0X1IA
# 7027    yUndy-LC5huRJs75s0X1IA
# 7024    yUndy-LC5huRJs75s0X1IA
# 7021    yUndy-LC5huRJs75s0X1IA
# 7025    yUndy-LC5huRJs75s0X1IA
# 7026    yUndy-LC5huRJs75s0X1IA
# 7023    yUndy-LC5huRJs75s0X1IA
# Name: business_id, dtype: object
# a_sorted:
#  567    gzln_L7ch8z-Ob6autmumw
# 570    gzln_L7ch8z-Ob6autmumw
# 568    gzln_L7ch8z-Ob6autmumw
# 573    gzln_L7ch8z-Ob6autmumw
# 569    gzln_L7ch8z-Ob6autmumw
# 572    gzln_L7ch8z-Ob6autmumw
# 571    gzln_L7ch8z-Ob6autmumw
# Name: business_id, dtype: object
# p_sorted:
#  567    gzln_L7ch8z-Ob6autmumw
# 570    gzln_L7ch8z-Ob6autmumw
# 568    gzln_L7ch8z-Ob6autmumw
# 573    gzln_L7ch8z-Ob6autmumw
# 569    gzln_L7ch8z-Ob6autmumw
# 572    gzln_L7ch8z-Ob6autmumw
# 571    gzln_L7ch8z-Ob6autmumw
# Name: business_id, dtype: object
# a_sorted:
#  5419    eT69uFkxdxdFOEsX-gbUCQ
# 5426    eT69uFkxdxdFOEsX-gbUCQ
# 5420    eT69uFkxdxdFOEsX-gbUCQ
# 5422    eT69uFkxdxdFOEsX-gbUCQ
# 5424    eT69uFkxdxdFOEsX-gbUCQ
# 5423    eT69uFkxdxdFOEsX-gbUCQ
# 5421    eT69uFkxdxdFOEsX-gbUCQ
# 5425    eT69uFkxdxdFOEsX-gbUCQ
# Name: business_id, dtype: object
# p_sorted:
#  5426    eT69uFkxdxdFOEsX-gbUCQ
# 5420    eT69uFkxdxdFOEsX-gbUCQ
# 5422    eT69uFkxdxdFOEsX-gbUCQ
# 5424    eT69uFkxdxdFOEsX-gbUCQ
# 5419    eT69uFkxdxdFOEsX-gbUCQ
# 5423    eT69uFkxdxdFOEsX-gbUCQ
# 5421    eT69uFkxdxdFOEsX-gbUCQ
# 5425    eT69uFkxdxdFOEsX-gbUCQ
# Name: business_id, dtype: object
# a_sorted:
#  2424    CCgn9tqrqojxs6knwwANMw
# 2431    CCgn9tqrqojxs6knwwANMw
# 2428    CCgn9tqrqojxs6knwwANMw
# 2425    CCgn9tqrqojxs6knwwANMw
# 2427    CCgn9tqrqojxs6knwwANMw
# 2430    CCgn9tqrqojxs6knwwANMw
# 2426    CCgn9tqrqojxs6knwwANMw
# 2429    CCgn9tqrqojxs6knwwANMw
# Name: business_id, dtype: object
# p_sorted:
#  2431    CCgn9tqrqojxs6knwwANMw
# 2428    CCgn9tqrqojxs6knwwANMw
# 2425    CCgn9tqrqojxs6knwwANMw
# 2424    CCgn9tqrqojxs6knwwANMw
# 2427    CCgn9tqrqojxs6knwwANMw
# 2430    CCgn9tqrqojxs6knwwANMw
# 2426    CCgn9tqrqojxs6knwwANMw
# 2429    CCgn9tqrqojxs6knwwANMw
# Name: business_id, dtype: object
# a_sorted:
#  6144    imGqMr4h8AJRfL0bxL8cCQ
# 6150    imGqMr4h8AJRfL0bxL8cCQ
# 6149    imGqMr4h8AJRfL0bxL8cCQ
# 6146    imGqMr4h8AJRfL0bxL8cCQ
# 6148    imGqMr4h8AJRfL0bxL8cCQ
# 6147    imGqMr4h8AJRfL0bxL8cCQ
# 6145    imGqMr4h8AJRfL0bxL8cCQ
# Name: business_id, dtype: object
# p_sorted:
#  6144    imGqMr4h8AJRfL0bxL8cCQ
# 6150    imGqMr4h8AJRfL0bxL8cCQ
# 6149    imGqMr4h8AJRfL0bxL8cCQ
# 6146    imGqMr4h8AJRfL0bxL8cCQ
# 6148    imGqMr4h8AJRfL0bxL8cCQ
# 6147    imGqMr4h8AJRfL0bxL8cCQ
# 6145    imGqMr4h8AJRfL0bxL8cCQ
# Name: business_id, dtype: object
# a_sorted:
#  2953    T8gJyppKf9GWogFTkead-A
# 2954    T8gJyppKf9GWogFTkead-A
# 2955    T8gJyppKf9GWogFTkead-A
# 2956    T8gJyppKf9GWogFTkead-A
# 2957    T8gJyppKf9GWogFTkead-A
# 2958    T8gJyppKf9GWogFTkead-A
# 2952    T8gJyppKf9GWogFTkead-A
# Name: business_id, dtype: object
# p_sorted:
#  2953    T8gJyppKf9GWogFTkead-A
# 2954    T8gJyppKf9GWogFTkead-A
# 2955    T8gJyppKf9GWogFTkead-A
# 2956    T8gJyppKf9GWogFTkead-A
# 2957    T8gJyppKf9GWogFTkead-A
# 2958    T8gJyppKf9GWogFTkead-A
# 2952    T8gJyppKf9GWogFTkead-A
# Name: business_id, dtype: object
# a_sorted:
#  249    0d1dpaZqcm7litFOJl7atA
# 255    0d1dpaZqcm7litFOJl7atA
# 251    0d1dpaZqcm7litFOJl7atA
# 256    0d1dpaZqcm7litFOJl7atA
# 250    0d1dpaZqcm7litFOJl7atA
# 252    0d1dpaZqcm7litFOJl7atA
# 254    0d1dpaZqcm7litFOJl7atA
# 253    0d1dpaZqcm7litFOJl7atA
# Name: business_id, dtype: object
# p_sorted:
#  255    0d1dpaZqcm7litFOJl7atA
# 251    0d1dpaZqcm7litFOJl7atA
# 256    0d1dpaZqcm7litFOJl7atA
# 250    0d1dpaZqcm7litFOJl7atA
# 249    0d1dpaZqcm7litFOJl7atA
# 252    0d1dpaZqcm7litFOJl7atA
# 254    0d1dpaZqcm7litFOJl7atA
# 253    0d1dpaZqcm7litFOJl7atA
# Name: business_id, dtype: object
# a_sorted:
#  5099    3rfFXpIQvFmYwtXj0aQ8nQ
# 5097    3rfFXpIQvFmYwtXj0aQ8nQ
# 5098    3rfFXpIQvFmYwtXj0aQ8nQ
# 5095    3rfFXpIQvFmYwtXj0aQ8nQ
# 5096    3rfFXpIQvFmYwtXj0aQ8nQ
# 5100    3rfFXpIQvFmYwtXj0aQ8nQ
# 5094    3rfFXpIQvFmYwtXj0aQ8nQ
# Name: business_id, dtype: object
# p_sorted:
#  5099    3rfFXpIQvFmYwtXj0aQ8nQ
# 5097    3rfFXpIQvFmYwtXj0aQ8nQ
# 5098    3rfFXpIQvFmYwtXj0aQ8nQ
# 5095    3rfFXpIQvFmYwtXj0aQ8nQ
# 5096    3rfFXpIQvFmYwtXj0aQ8nQ
# 5100    3rfFXpIQvFmYwtXj0aQ8nQ
# 5094    3rfFXpIQvFmYwtXj0aQ8nQ
# Name: business_id, dtype: object
# a_sorted:
#  6363    lkQP24RF-W7Hvb2WOPJWAw
# 6362    lkQP24RF-W7Hvb2WOPJWAw
# 6361    lkQP24RF-W7Hvb2WOPJWAw
# 6358    lkQP24RF-W7Hvb2WOPJWAw
# 6359    lkQP24RF-W7Hvb2WOPJWAw
# 6360    lkQP24RF-W7Hvb2WOPJWAw
# 6364    lkQP24RF-W7Hvb2WOPJWAw
# Name: business_id, dtype: object
# p_sorted:
#  6363    lkQP24RF-W7Hvb2WOPJWAw
# 6362    lkQP24RF-W7Hvb2WOPJWAw
# 6361    lkQP24RF-W7Hvb2WOPJWAw
# 6358    lkQP24RF-W7Hvb2WOPJWAw
# 6359    lkQP24RF-W7Hvb2WOPJWAw
# 6360    lkQP24RF-W7Hvb2WOPJWAw
# 6364    lkQP24RF-W7Hvb2WOPJWAw
# Name: business_id, dtype: object
# a_sorted:
#  7459    -t29rrypP0eQdTeQ3YErdg
# 7457    -t29rrypP0eQdTeQ3YErdg
# 7460    -t29rrypP0eQdTeQ3YErdg
# 7461    -t29rrypP0eQdTeQ3YErdg
# 7456    -t29rrypP0eQdTeQ3YErdg
# 7458    -t29rrypP0eQdTeQ3YErdg
# Name: business_id, dtype: object
# p_sorted:
#  7459    -t29rrypP0eQdTeQ3YErdg
# 7457    -t29rrypP0eQdTeQ3YErdg
# 7460    -t29rrypP0eQdTeQ3YErdg
# 7461    -t29rrypP0eQdTeQ3YErdg
# 7456    -t29rrypP0eQdTeQ3YErdg
# 7458    -t29rrypP0eQdTeQ3YErdg
# Name: business_id, dtype: object
# a_sorted:
#  5730    eLjXnfYwkr8zz0VhwMhOGw
# Name: business_id, dtype: object
# p_sorted:
#  5730    eLjXnfYwkr8zz0VhwMhOGw
# Name: business_id, dtype: object
# a_sorted:
#  4376    -3xX_IfttKjPJ792BOBJ-Q
# 4380    -3xX_IfttKjPJ792BOBJ-Q
# 4377    -3xX_IfttKjPJ792BOBJ-Q
# 4378    -3xX_IfttKjPJ792BOBJ-Q
# 4381    -3xX_IfttKjPJ792BOBJ-Q
# 4382    -3xX_IfttKjPJ792BOBJ-Q
# 4379    -3xX_IfttKjPJ792BOBJ-Q
# Name: business_id, dtype: object
# p_sorted:
#  4382    -3xX_IfttKjPJ792BOBJ-Q
# 4380    -3xX_IfttKjPJ792BOBJ-Q
# 4377    -3xX_IfttKjPJ792BOBJ-Q
# 4378    -3xX_IfttKjPJ792BOBJ-Q
# 4381    -3xX_IfttKjPJ792BOBJ-Q
# 4376    -3xX_IfttKjPJ792BOBJ-Q
# 4379    -3xX_IfttKjPJ792BOBJ-Q
# Name: business_id, dtype: object
# a_sorted:
#  2596    Wp9D-r8Ap1Fv0IIM0zGfoQ
# Name: business_id, dtype: object
# p_sorted:
#  2596    Wp9D-r8Ap1Fv0IIM0zGfoQ
# Name: business_id, dtype: object
# a_sorted:
#  313    cp3pRJJuQo0urJZm2inr_A
# 314    cp3pRJJuQo0urJZm2inr_A
# 311    cp3pRJJuQo0urJZm2inr_A
# 312    cp3pRJJuQo0urJZm2inr_A
# 310    cp3pRJJuQo0urJZm2inr_A
# 308    cp3pRJJuQo0urJZm2inr_A
# 309    cp3pRJJuQo0urJZm2inr_A
# Name: business_id, dtype: object
# p_sorted:
#  313    cp3pRJJuQo0urJZm2inr_A
# 314    cp3pRJJuQo0urJZm2inr_A
# 311    cp3pRJJuQo0urJZm2inr_A
# 312    cp3pRJJuQo0urJZm2inr_A
# 310    cp3pRJJuQo0urJZm2inr_A
# 308    cp3pRJJuQo0urJZm2inr_A
# 309    cp3pRJJuQo0urJZm2inr_A
# Name: business_id, dtype: object
# a_sorted:
#  6287    1LUZupYFJ6CxSKU37qDSXw
# 6285    1LUZupYFJ6CxSKU37qDSXw
# 6288    1LUZupYFJ6CxSKU37qDSXw
# 6282    1LUZupYFJ6CxSKU37qDSXw
# 6283    1LUZupYFJ6CxSKU37qDSXw
# 6286    1LUZupYFJ6CxSKU37qDSXw
# 6284    1LUZupYFJ6CxSKU37qDSXw
# Name: business_id, dtype: object
# p_sorted:
#  6287    1LUZupYFJ6CxSKU37qDSXw
# 6285    1LUZupYFJ6CxSKU37qDSXw
# 6288    1LUZupYFJ6CxSKU37qDSXw
# 6282    1LUZupYFJ6CxSKU37qDSXw
# 6283    1LUZupYFJ6CxSKU37qDSXw
# 6286    1LUZupYFJ6CxSKU37qDSXw
# 6284    1LUZupYFJ6CxSKU37qDSXw
# Name: business_id, dtype: object
# a_sorted:
#  315    rU139D5Zl5928RYoXYSURA
# 322    rU139D5Zl5928RYoXYSURA
# 318    rU139D5Zl5928RYoXYSURA
# 317    rU139D5Zl5928RYoXYSURA
# 320    rU139D5Zl5928RYoXYSURA
# 321    rU139D5Zl5928RYoXYSURA
# 319    rU139D5Zl5928RYoXYSURA
# 316    rU139D5Zl5928RYoXYSURA
# Name: business_id, dtype: object
# p_sorted:
#  322    rU139D5Zl5928RYoXYSURA
# 318    rU139D5Zl5928RYoXYSURA
# 317    rU139D5Zl5928RYoXYSURA
# 320    rU139D5Zl5928RYoXYSURA
# 315    rU139D5Zl5928RYoXYSURA
# 321    rU139D5Zl5928RYoXYSURA
# 319    rU139D5Zl5928RYoXYSURA
# 316    rU139D5Zl5928RYoXYSURA
# Name: business_id, dtype: object
# a_sorted:
#  1006    7IU6885SDuzEA9JfrP--uQ
# 1002    7IU6885SDuzEA9JfrP--uQ
# 1004    7IU6885SDuzEA9JfrP--uQ
# 1007    7IU6885SDuzEA9JfrP--uQ
# 1005    7IU6885SDuzEA9JfrP--uQ
# 1001    7IU6885SDuzEA9JfrP--uQ
# 1003    7IU6885SDuzEA9JfrP--uQ
# Name: business_id, dtype: object
# p_sorted:
#  1006    7IU6885SDuzEA9JfrP--uQ
# 1002    7IU6885SDuzEA9JfrP--uQ
# 1004    7IU6885SDuzEA9JfrP--uQ
# 1007    7IU6885SDuzEA9JfrP--uQ
# 1005    7IU6885SDuzEA9JfrP--uQ
# 1001    7IU6885SDuzEA9JfrP--uQ
# 1003    7IU6885SDuzEA9JfrP--uQ
# Name: business_id, dtype: object
# a_sorted:
#  5351    vH0AmDSAd99qrdEEq5EHag
# 5356    vH0AmDSAd99qrdEEq5EHag
# 5353    vH0AmDSAd99qrdEEq5EHag
# 5357    vH0AmDSAd99qrdEEq5EHag
# 5354    vH0AmDSAd99qrdEEq5EHag
# 5355    vH0AmDSAd99qrdEEq5EHag
# 5352    vH0AmDSAd99qrdEEq5EHag
# Name: business_id, dtype: object
# p_sorted:
#  5351    vH0AmDSAd99qrdEEq5EHag
# 5356    vH0AmDSAd99qrdEEq5EHag
# 5353    vH0AmDSAd99qrdEEq5EHag
# 5357    vH0AmDSAd99qrdEEq5EHag
# 5354    vH0AmDSAd99qrdEEq5EHag
# 5355    vH0AmDSAd99qrdEEq5EHag
# 5352    vH0AmDSAd99qrdEEq5EHag
# Name: business_id, dtype: object
# a_sorted:
#  3740    3lbhIJ8i-dHzMNtC-FW8tA
# 3741    3lbhIJ8i-dHzMNtC-FW8tA
# 3737    3lbhIJ8i-dHzMNtC-FW8tA
# 3735    3lbhIJ8i-dHzMNtC-FW8tA
# 3736    3lbhIJ8i-dHzMNtC-FW8tA
# 3739    3lbhIJ8i-dHzMNtC-FW8tA
# 3738    3lbhIJ8i-dHzMNtC-FW8tA
# Name: business_id, dtype: object
# p_sorted:
#  3740    3lbhIJ8i-dHzMNtC-FW8tA
# 3741    3lbhIJ8i-dHzMNtC-FW8tA
# 3737    3lbhIJ8i-dHzMNtC-FW8tA
# 3735    3lbhIJ8i-dHzMNtC-FW8tA
# 3736    3lbhIJ8i-dHzMNtC-FW8tA
# 3739    3lbhIJ8i-dHzMNtC-FW8tA
# 3738    3lbhIJ8i-dHzMNtC-FW8tA
# Name: business_id, dtype: object
# a_sorted:
#  166    C4lZdhasjZVQyDlOiXY1sA
# 169    C4lZdhasjZVQyDlOiXY1sA
# 170    C4lZdhasjZVQyDlOiXY1sA
# 168    C4lZdhasjZVQyDlOiXY1sA
# 171    C4lZdhasjZVQyDlOiXY1sA
# 167    C4lZdhasjZVQyDlOiXY1sA
# 165    C4lZdhasjZVQyDlOiXY1sA
# Name: business_id, dtype: object
# p_sorted:
#  166    C4lZdhasjZVQyDlOiXY1sA
# 169    C4lZdhasjZVQyDlOiXY1sA
# 170    C4lZdhasjZVQyDlOiXY1sA
# 168    C4lZdhasjZVQyDlOiXY1sA
# 171    C4lZdhasjZVQyDlOiXY1sA
# 167    C4lZdhasjZVQyDlOiXY1sA
# 165    C4lZdhasjZVQyDlOiXY1sA
# Name: business_id, dtype: object
# a_sorted:
#  8067    hodLyDkWXAosXLSTKDL06Q
# 8073    hodLyDkWXAosXLSTKDL06Q
# 8072    hodLyDkWXAosXLSTKDL06Q
# 8070    hodLyDkWXAosXLSTKDL06Q
# 8069    hodLyDkWXAosXLSTKDL06Q
# 8068    hodLyDkWXAosXLSTKDL06Q
# 8071    hodLyDkWXAosXLSTKDL06Q
# Name: business_id, dtype: object
# p_sorted:
#  8067    hodLyDkWXAosXLSTKDL06Q
# 8073    hodLyDkWXAosXLSTKDL06Q
# 8072    hodLyDkWXAosXLSTKDL06Q
# 8070    hodLyDkWXAosXLSTKDL06Q
# 8069    hodLyDkWXAosXLSTKDL06Q
# 8068    hodLyDkWXAosXLSTKDL06Q
# 8071    hodLyDkWXAosXLSTKDL06Q
# Name: business_id, dtype: object
# a_sorted:
#  153    kZtl_NJjUnlIQgzFrBhXyQ
# 155    kZtl_NJjUnlIQgzFrBhXyQ
# 154    kZtl_NJjUnlIQgzFrBhXyQ
# 152    kZtl_NJjUnlIQgzFrBhXyQ
# Name: business_id, dtype: object
# p_sorted:
#  153    kZtl_NJjUnlIQgzFrBhXyQ
# 155    kZtl_NJjUnlIQgzFrBhXyQ
# 154    kZtl_NJjUnlIQgzFrBhXyQ
# 152    kZtl_NJjUnlIQgzFrBhXyQ
# Name: business_id, dtype: object
# a_sorted:
#  7927    T9cUZsa-mAAxnkNoFIYgKg
# 7926    T9cUZsa-mAAxnkNoFIYgKg
# 7925    T9cUZsa-mAAxnkNoFIYgKg
# 7924    T9cUZsa-mAAxnkNoFIYgKg
# 7929    T9cUZsa-mAAxnkNoFIYgKg
# 7928    T9cUZsa-mAAxnkNoFIYgKg
# 7923    T9cUZsa-mAAxnkNoFIYgKg
# Name: business_id, dtype: object
# p_sorted:
#  7927    T9cUZsa-mAAxnkNoFIYgKg
# 7926    T9cUZsa-mAAxnkNoFIYgKg
# 7925    T9cUZsa-mAAxnkNoFIYgKg
# 7924    T9cUZsa-mAAxnkNoFIYgKg
# 7929    T9cUZsa-mAAxnkNoFIYgKg
# 7928    T9cUZsa-mAAxnkNoFIYgKg
# 7923    T9cUZsa-mAAxnkNoFIYgKg
# Name: business_id, dtype: object
# a_sorted:
#  5270    qTicP3qlsW6zqLV7P1Uz_g
# Name: business_id, dtype: object
# p_sorted:
#  5270    qTicP3qlsW6zqLV7P1Uz_g
# Name: business_id, dtype: object
# a_sorted:
#  3772    eR44gUajtqCnVECnjh7Ynw
# 3774    eR44gUajtqCnVECnjh7Ynw
# 3769    eR44gUajtqCnVECnjh7Ynw
# 3768    eR44gUajtqCnVECnjh7Ynw
# 3773    eR44gUajtqCnVECnjh7Ynw
# 3771    eR44gUajtqCnVECnjh7Ynw
# 3770    eR44gUajtqCnVECnjh7Ynw
# Name: business_id, dtype: object
# p_sorted:
#  3772    eR44gUajtqCnVECnjh7Ynw
# 3774    eR44gUajtqCnVECnjh7Ynw
# 3769    eR44gUajtqCnVECnjh7Ynw
# 3768    eR44gUajtqCnVECnjh7Ynw
# 3773    eR44gUajtqCnVECnjh7Ynw
# 3771    eR44gUajtqCnVECnjh7Ynw
# 3770    eR44gUajtqCnVECnjh7Ynw
# Name: business_id, dtype: object
# a_sorted:
#  282    tdx972CXnZ1bC80t26s0Mw
# 281    tdx972CXnZ1bC80t26s0Mw
# 280    tdx972CXnZ1bC80t26s0Mw
# 278    tdx972CXnZ1bC80t26s0Mw
# 276    tdx972CXnZ1bC80t26s0Mw
# 279    tdx972CXnZ1bC80t26s0Mw
# 277    tdx972CXnZ1bC80t26s0Mw
# Name: business_id, dtype: object
# p_sorted:
#  282    tdx972CXnZ1bC80t26s0Mw
# 281    tdx972CXnZ1bC80t26s0Mw
# 280    tdx972CXnZ1bC80t26s0Mw
# 278    tdx972CXnZ1bC80t26s0Mw
# 276    tdx972CXnZ1bC80t26s0Mw
# 279    tdx972CXnZ1bC80t26s0Mw
# 277    tdx972CXnZ1bC80t26s0Mw
# Name: business_id, dtype: object
# a_sorted:
#  1271    t7EhJThUl-MCOmst4NcTpg
# 1272    t7EhJThUl-MCOmst4NcTpg
# 1269    t7EhJThUl-MCOmst4NcTpg
# 1268    t7EhJThUl-MCOmst4NcTpg
# 1270    t7EhJThUl-MCOmst4NcTpg
# 1273    t7EhJThUl-MCOmst4NcTpg
# 1274    t7EhJThUl-MCOmst4NcTpg
# Name: business_id, dtype: object
# p_sorted:
#  1271    t7EhJThUl-MCOmst4NcTpg
# 1272    t7EhJThUl-MCOmst4NcTpg
# 1269    t7EhJThUl-MCOmst4NcTpg
# 1268    t7EhJThUl-MCOmst4NcTpg
# 1270    t7EhJThUl-MCOmst4NcTpg
# 1273    t7EhJThUl-MCOmst4NcTpg
# 1274    t7EhJThUl-MCOmst4NcTpg
# Name: business_id, dtype: object
# a_sorted:
#  8386    IbpTkANgK_6LgJ_DaS94YA
# 8389    IbpTkANgK_6LgJ_DaS94YA
# 8387    IbpTkANgK_6LgJ_DaS94YA
# 8390    IbpTkANgK_6LgJ_DaS94YA
# 8384    IbpTkANgK_6LgJ_DaS94YA
# 8385    IbpTkANgK_6LgJ_DaS94YA
# 8388    IbpTkANgK_6LgJ_DaS94YA
# Name: business_id, dtype: object
# p_sorted:
#  8386    IbpTkANgK_6LgJ_DaS94YA
# 8389    IbpTkANgK_6LgJ_DaS94YA
# 8387    IbpTkANgK_6LgJ_DaS94YA
# 8390    IbpTkANgK_6LgJ_DaS94YA
# 8384    IbpTkANgK_6LgJ_DaS94YA
# 8385    IbpTkANgK_6LgJ_DaS94YA
# 8388    IbpTkANgK_6LgJ_DaS94YA
# Name: business_id, dtype: object
# a_sorted:
#  7615    YMbv9x8yL9X4nEReU0gPIA
# 7612    YMbv9x8yL9X4nEReU0gPIA
# 7616    YMbv9x8yL9X4nEReU0gPIA
# 7613    YMbv9x8yL9X4nEReU0gPIA
# 7614    YMbv9x8yL9X4nEReU0gPIA
# Name: business_id, dtype: object
# p_sorted:
#  7615    YMbv9x8yL9X4nEReU0gPIA
# 7612    YMbv9x8yL9X4nEReU0gPIA
# 7616    YMbv9x8yL9X4nEReU0gPIA
# 7613    YMbv9x8yL9X4nEReU0gPIA
# 7614    YMbv9x8yL9X4nEReU0gPIA
# Name: business_id, dtype: object
# a_sorted:
#  7991    jwpZzqoPFLuHE-FwLp41cQ
# 7989    jwpZzqoPFLuHE-FwLp41cQ
# 7987    jwpZzqoPFLuHE-FwLp41cQ
# 7992    jwpZzqoPFLuHE-FwLp41cQ
# 7990    jwpZzqoPFLuHE-FwLp41cQ
# 7988    jwpZzqoPFLuHE-FwLp41cQ
# 7993    jwpZzqoPFLuHE-FwLp41cQ
# Name: business_id, dtype: object
# p_sorted:
#  7991    jwpZzqoPFLuHE-FwLp41cQ
# 7989    jwpZzqoPFLuHE-FwLp41cQ
# 7987    jwpZzqoPFLuHE-FwLp41cQ
# 7992    jwpZzqoPFLuHE-FwLp41cQ
# 7990    jwpZzqoPFLuHE-FwLp41cQ
# 7988    jwpZzqoPFLuHE-FwLp41cQ
# 7993    jwpZzqoPFLuHE-FwLp41cQ
# Name: business_id, dtype: object
# a_sorted:
#  3677    G15tUaO6G0nS41zY8g8Yow
# Name: business_id, dtype: object
# p_sorted:
#  3677    G15tUaO6G0nS41zY8g8Yow
# Name: business_id, dtype: object
# a_sorted:
#  7772    ObkVEcYUuf3efg-0V_WYfQ
# 7775    ObkVEcYUuf3efg-0V_WYfQ
# 7774    ObkVEcYUuf3efg-0V_WYfQ
# 7773    ObkVEcYUuf3efg-0V_WYfQ
# 7770    ObkVEcYUuf3efg-0V_WYfQ
# 7771    ObkVEcYUuf3efg-0V_WYfQ
# Name: business_id, dtype: object
# p_sorted:
#  7772    ObkVEcYUuf3efg-0V_WYfQ
# 7775    ObkVEcYUuf3efg-0V_WYfQ
# 7774    ObkVEcYUuf3efg-0V_WYfQ
# 7773    ObkVEcYUuf3efg-0V_WYfQ
# 7770    ObkVEcYUuf3efg-0V_WYfQ
# 7771    ObkVEcYUuf3efg-0V_WYfQ
# Name: business_id, dtype: object
# a_sorted:
#  3281    nB0dV8yPv29F3-CFMPG8cw
# 3282    nB0dV8yPv29F3-CFMPG8cw
# 3280    nB0dV8yPv29F3-CFMPG8cw
# 3279    nB0dV8yPv29F3-CFMPG8cw
# Name: business_id, dtype: object
# p_sorted:
#  3281    nB0dV8yPv29F3-CFMPG8cw
# 3282    nB0dV8yPv29F3-CFMPG8cw
# 3280    nB0dV8yPv29F3-CFMPG8cw
# 3279    nB0dV8yPv29F3-CFMPG8cw
# Name: business_id, dtype: object
# a_sorted:
#  4391    adu5voMt1rln1nilzZh9uA
# 4398    adu5voMt1rln1nilzZh9uA
# 4397    adu5voMt1rln1nilzZh9uA
# 4392    adu5voMt1rln1nilzZh9uA
# 4396    adu5voMt1rln1nilzZh9uA
# 4395    adu5voMt1rln1nilzZh9uA
# 4394    adu5voMt1rln1nilzZh9uA
# 4393    adu5voMt1rln1nilzZh9uA
# Name: business_id, dtype: object
# p_sorted:
#  4398    adu5voMt1rln1nilzZh9uA
# 4397    adu5voMt1rln1nilzZh9uA
# 4392    adu5voMt1rln1nilzZh9uA
# 4391    adu5voMt1rln1nilzZh9uA
# 4396    adu5voMt1rln1nilzZh9uA
# 4395    adu5voMt1rln1nilzZh9uA
# 4394    adu5voMt1rln1nilzZh9uA
# 4393    adu5voMt1rln1nilzZh9uA
# Name: business_id, dtype: object
# a_sorted:
#  6983    myg9wV_3IgHGa-pVKVjijA
# 6986    myg9wV_3IgHGa-pVKVjijA
# 6984    myg9wV_3IgHGa-pVKVjijA
# 6981    myg9wV_3IgHGa-pVKVjijA
# 6987    myg9wV_3IgHGa-pVKVjijA
# 6982    myg9wV_3IgHGa-pVKVjijA
# 6985    myg9wV_3IgHGa-pVKVjijA
# Name: business_id, dtype: object
# p_sorted:
#  6983    myg9wV_3IgHGa-pVKVjijA
# 6986    myg9wV_3IgHGa-pVKVjijA
# 6984    myg9wV_3IgHGa-pVKVjijA
# 6981    myg9wV_3IgHGa-pVKVjijA
# 6987    myg9wV_3IgHGa-pVKVjijA
# 6982    myg9wV_3IgHGa-pVKVjijA
# 6985    myg9wV_3IgHGa-pVKVjijA
# Name: business_id, dtype: object
# a_sorted:
#  672    JbasD9GrfJ7SeiiucoizTA
# 671    JbasD9GrfJ7SeiiucoizTA
# 670    JbasD9GrfJ7SeiiucoizTA
# 673    JbasD9GrfJ7SeiiucoizTA
# 668    JbasD9GrfJ7SeiiucoizTA
# 674    JbasD9GrfJ7SeiiucoizTA
# 669    JbasD9GrfJ7SeiiucoizTA
# Name: business_id, dtype: object
# p_sorted:
#  668    JbasD9GrfJ7SeiiucoizTA
# 672    JbasD9GrfJ7SeiiucoizTA
# 671    JbasD9GrfJ7SeiiucoizTA
# 670    JbasD9GrfJ7SeiiucoizTA
# 673    JbasD9GrfJ7SeiiucoizTA
# 674    JbasD9GrfJ7SeiiucoizTA
# 669    JbasD9GrfJ7SeiiucoizTA
# Name: business_id, dtype: object
# a_sorted:
#  1374    KMGGcG4AX83-PQlW6hHvTA
# 1371    KMGGcG4AX83-PQlW6hHvTA
# 1372    KMGGcG4AX83-PQlW6hHvTA
# 1370    KMGGcG4AX83-PQlW6hHvTA
# 1375    KMGGcG4AX83-PQlW6hHvTA
# 1373    KMGGcG4AX83-PQlW6hHvTA
# 1376    KMGGcG4AX83-PQlW6hHvTA
# Name: business_id, dtype: object
# p_sorted:
#  1370    KMGGcG4AX83-PQlW6hHvTA
# 1374    KMGGcG4AX83-PQlW6hHvTA
# 1371    KMGGcG4AX83-PQlW6hHvTA
# 1372    KMGGcG4AX83-PQlW6hHvTA
# 1375    KMGGcG4AX83-PQlW6hHvTA
# 1373    KMGGcG4AX83-PQlW6hHvTA
# 1376    KMGGcG4AX83-PQlW6hHvTA
# Name: business_id, dtype: object
# a_sorted:
#  2374    X0vPZIkbUj22afBQz5-neA
# Name: business_id, dtype: object
# p_sorted:
#  2374    X0vPZIkbUj22afBQz5-neA
# Name: business_id, dtype: object
# a_sorted:
#  6111    t-RHwZzlTAZeTcgrrbRtqg
# 6112    t-RHwZzlTAZeTcgrrbRtqg
# 6116    t-RHwZzlTAZeTcgrrbRtqg
# 6114    t-RHwZzlTAZeTcgrrbRtqg
# 6115    t-RHwZzlTAZeTcgrrbRtqg
# 6118    t-RHwZzlTAZeTcgrrbRtqg
# 6113    t-RHwZzlTAZeTcgrrbRtqg
# 6117    t-RHwZzlTAZeTcgrrbRtqg
# Name: business_id, dtype: object
# p_sorted:
#  6112    t-RHwZzlTAZeTcgrrbRtqg
# 6116    t-RHwZzlTAZeTcgrrbRtqg
# 6114    t-RHwZzlTAZeTcgrrbRtqg
# 6115    t-RHwZzlTAZeTcgrrbRtqg
# 6118    t-RHwZzlTAZeTcgrrbRtqg
# 6113    t-RHwZzlTAZeTcgrrbRtqg
# 6111    t-RHwZzlTAZeTcgrrbRtqg
# 6117    t-RHwZzlTAZeTcgrrbRtqg
# Name: business_id, dtype: object
# a_sorted:
#  3960    K3gEiQ-_yCj47BaZZ150sg
# 3956    K3gEiQ-_yCj47BaZZ150sg
# 3961    K3gEiQ-_yCj47BaZZ150sg
# 3957    K3gEiQ-_yCj47BaZZ150sg
# 3959    K3gEiQ-_yCj47BaZZ150sg
# 3962    K3gEiQ-_yCj47BaZZ150sg
# 3958    K3gEiQ-_yCj47BaZZ150sg
# Name: business_id, dtype: object
# p_sorted:
#  3960    K3gEiQ-_yCj47BaZZ150sg
# 3956    K3gEiQ-_yCj47BaZZ150sg
# 3961    K3gEiQ-_yCj47BaZZ150sg
# 3957    K3gEiQ-_yCj47BaZZ150sg
# 3959    K3gEiQ-_yCj47BaZZ150sg
# 3962    K3gEiQ-_yCj47BaZZ150sg
# 3958    K3gEiQ-_yCj47BaZZ150sg
# Name: business_id, dtype: object
# a_sorted:
#  1590    zl69bXm0JFqWNjw9a9UHvQ
# 1586    zl69bXm0JFqWNjw9a9UHvQ
# 1587    zl69bXm0JFqWNjw9a9UHvQ
# 1585    zl69bXm0JFqWNjw9a9UHvQ
# 1589    zl69bXm0JFqWNjw9a9UHvQ
# 1588    zl69bXm0JFqWNjw9a9UHvQ
# 1591    zl69bXm0JFqWNjw9a9UHvQ
# Name: business_id, dtype: object
# p_sorted:
#  1590    zl69bXm0JFqWNjw9a9UHvQ
# 1586    zl69bXm0JFqWNjw9a9UHvQ
# 1587    zl69bXm0JFqWNjw9a9UHvQ
# 1585    zl69bXm0JFqWNjw9a9UHvQ
# 1589    zl69bXm0JFqWNjw9a9UHvQ
# 1588    zl69bXm0JFqWNjw9a9UHvQ
# 1591    zl69bXm0JFqWNjw9a9UHvQ
# Name: business_id, dtype: object
# a_sorted:
#  7545    QHWYlmVbLC3K6eglWoHVvA
# 7540    QHWYlmVbLC3K6eglWoHVvA
# 7542    QHWYlmVbLC3K6eglWoHVvA
# 7546    QHWYlmVbLC3K6eglWoHVvA
# 7543    QHWYlmVbLC3K6eglWoHVvA
# 7541    QHWYlmVbLC3K6eglWoHVvA
# 7544    QHWYlmVbLC3K6eglWoHVvA
# Name: business_id, dtype: object
# p_sorted:
#  7545    QHWYlmVbLC3K6eglWoHVvA
# 7540    QHWYlmVbLC3K6eglWoHVvA
# 7542    QHWYlmVbLC3K6eglWoHVvA
# 7546    QHWYlmVbLC3K6eglWoHVvA
# 7543    QHWYlmVbLC3K6eglWoHVvA
# 7541    QHWYlmVbLC3K6eglWoHVvA
# 7544    QHWYlmVbLC3K6eglWoHVvA
# Name: business_id, dtype: object
# a_sorted:
#  7978    oLOVznE7BzEqwVK3Yim_gQ
# Name: business_id, dtype: object
# p_sorted:
#  7978    oLOVznE7BzEqwVK3Yim_gQ
# Name: business_id, dtype: object
# a_sorted:
#  229    0QgAyxKXAHavVgG7BRlV9g
# 227    0QgAyxKXAHavVgG7BRlV9g
# 228    0QgAyxKXAHavVgG7BRlV9g
# 226    0QgAyxKXAHavVgG7BRlV9g
# 223    0QgAyxKXAHavVgG7BRlV9g
# 224    0QgAyxKXAHavVgG7BRlV9g
# 225    0QgAyxKXAHavVgG7BRlV9g
# Name: business_id, dtype: object
# p_sorted:
#  229    0QgAyxKXAHavVgG7BRlV9g
# 227    0QgAyxKXAHavVgG7BRlV9g
# 228    0QgAyxKXAHavVgG7BRlV9g
# 226    0QgAyxKXAHavVgG7BRlV9g
# 223    0QgAyxKXAHavVgG7BRlV9g
# 224    0QgAyxKXAHavVgG7BRlV9g
# 225    0QgAyxKXAHavVgG7BRlV9g
# Name: business_id, dtype: object
# a_sorted:
#  261    smkZq4G1AOm4V6p3id5sww
# 259    smkZq4G1AOm4V6p3id5sww
# 264    smkZq4G1AOm4V6p3id5sww
# 265    smkZq4G1AOm4V6p3id5sww
# 260    smkZq4G1AOm4V6p3id5sww
# 263    smkZq4G1AOm4V6p3id5sww
# 262    smkZq4G1AOm4V6p3id5sww
# Name: business_id, dtype: object
# p_sorted:
#  261    smkZq4G1AOm4V6p3id5sww
# 259    smkZq4G1AOm4V6p3id5sww
# 264    smkZq4G1AOm4V6p3id5sww
# 265    smkZq4G1AOm4V6p3id5sww
# 260    smkZq4G1AOm4V6p3id5sww
# 263    smkZq4G1AOm4V6p3id5sww
# 262    smkZq4G1AOm4V6p3id5sww
# Name: business_id, dtype: object
# a_sorted:
#  3863    Mfvk9uEEhdCqj8S2u7dWgQ
# Name: business_id, dtype: object
# p_sorted:
#  3863    Mfvk9uEEhdCqj8S2u7dWgQ
# Name: business_id, dtype: object
# a_sorted:
#  4258    VfpjD7k3RXz7wvULxORQjg
# 4256    VfpjD7k3RXz7wvULxORQjg
# 4252    VfpjD7k3RXz7wvULxORQjg
# 4253    VfpjD7k3RXz7wvULxORQjg
# 4255    VfpjD7k3RXz7wvULxORQjg
# 4257    VfpjD7k3RXz7wvULxORQjg
# 4254    VfpjD7k3RXz7wvULxORQjg
# Name: business_id, dtype: object
# p_sorted:
#  4258    VfpjD7k3RXz7wvULxORQjg
# 4256    VfpjD7k3RXz7wvULxORQjg
# 4252    VfpjD7k3RXz7wvULxORQjg
# 4253    VfpjD7k3RXz7wvULxORQjg
# 4255    VfpjD7k3RXz7wvULxORQjg
# 4257    VfpjD7k3RXz7wvULxORQjg
# 4254    VfpjD7k3RXz7wvULxORQjg
# Name: business_id, dtype: object
# a_sorted:
#  5238    5KTQ_OfaVRAl4BC13rxE3Q
# Name: business_id, dtype: object
# p_sorted:
#  5238    5KTQ_OfaVRAl4BC13rxE3Q
# Name: business_id, dtype: object
# a_sorted:
#  5722    DwEHeY-1Cs9GV-S97wzVhA
# 5723    DwEHeY-1Cs9GV-S97wzVhA
# 5727    DwEHeY-1Cs9GV-S97wzVhA
# 5726    DwEHeY-1Cs9GV-S97wzVhA
# 5725    DwEHeY-1Cs9GV-S97wzVhA
# 5729    DwEHeY-1Cs9GV-S97wzVhA
# 5728    DwEHeY-1Cs9GV-S97wzVhA
# 5724    DwEHeY-1Cs9GV-S97wzVhA
# Name: business_id, dtype: object
# p_sorted:
#  5723    DwEHeY-1Cs9GV-S97wzVhA
# 5727    DwEHeY-1Cs9GV-S97wzVhA
# 5722    DwEHeY-1Cs9GV-S97wzVhA
# 5726    DwEHeY-1Cs9GV-S97wzVhA
# 5725    DwEHeY-1Cs9GV-S97wzVhA
# 5729    DwEHeY-1Cs9GV-S97wzVhA
# 5728    DwEHeY-1Cs9GV-S97wzVhA
# 5724    DwEHeY-1Cs9GV-S97wzVhA
# Name: business_id, dtype: object
# a_sorted:
#  6229    WNfxAtgGAJbMxwAhUM8fQg
# Name: business_id, dtype: object
# p_sorted:
#  6229    WNfxAtgGAJbMxwAhUM8fQg
# Name: business_id, dtype: object
# a_sorted:
#  649    drjkRW6oC2Fulpr9KaYWEg
# 647    drjkRW6oC2Fulpr9KaYWEg
# 646    drjkRW6oC2Fulpr9KaYWEg
# 648    drjkRW6oC2Fulpr9KaYWEg
# 645    drjkRW6oC2Fulpr9KaYWEg
# 643    drjkRW6oC2Fulpr9KaYWEg
# 644    drjkRW6oC2Fulpr9KaYWEg
# Name: business_id, dtype: object
# p_sorted:
#  649    drjkRW6oC2Fulpr9KaYWEg
# 647    drjkRW6oC2Fulpr9KaYWEg
# 646    drjkRW6oC2Fulpr9KaYWEg
# 648    drjkRW6oC2Fulpr9KaYWEg
# 645    drjkRW6oC2Fulpr9KaYWEg
# 643    drjkRW6oC2Fulpr9KaYWEg
# 644    drjkRW6oC2Fulpr9KaYWEg
# Name: business_id, dtype: object
# a_sorted:
#  28    3M2zIKwVz2J63SlNiirgVA
# 32    3M2zIKwVz2J63SlNiirgVA
# 30    3M2zIKwVz2J63SlNiirgVA
# 31    3M2zIKwVz2J63SlNiirgVA
# 27    3M2zIKwVz2J63SlNiirgVA
# 29    3M2zIKwVz2J63SlNiirgVA
# 26    3M2zIKwVz2J63SlNiirgVA
# Name: business_id, dtype: object
# p_sorted:
#  28    3M2zIKwVz2J63SlNiirgVA
# 32    3M2zIKwVz2J63SlNiirgVA
# 30    3M2zIKwVz2J63SlNiirgVA
# 31    3M2zIKwVz2J63SlNiirgVA
# 27    3M2zIKwVz2J63SlNiirgVA
# 29    3M2zIKwVz2J63SlNiirgVA
# 26    3M2zIKwVz2J63SlNiirgVA
# Name: business_id, dtype: object
# a_sorted:
#  2152    bdteJqgoj0OaALhj9RFtmw
# 2147    bdteJqgoj0OaALhj9RFtmw
# 2148    bdteJqgoj0OaALhj9RFtmw
# 2151    bdteJqgoj0OaALhj9RFtmw
# 2146    bdteJqgoj0OaALhj9RFtmw
# 2149    bdteJqgoj0OaALhj9RFtmw
# 2150    bdteJqgoj0OaALhj9RFtmw
# Name: business_id, dtype: object
# p_sorted:
#  2152    bdteJqgoj0OaALhj9RFtmw
# 2147    bdteJqgoj0OaALhj9RFtmw
# 2148    bdteJqgoj0OaALhj9RFtmw
# 2151    bdteJqgoj0OaALhj9RFtmw
# 2146    bdteJqgoj0OaALhj9RFtmw
# 2149    bdteJqgoj0OaALhj9RFtmw
# 2150    bdteJqgoj0OaALhj9RFtmw
# Name: business_id, dtype: object
# a_sorted:
#  6498    31uu55dhOGzPHAJslZp7uA
# 6499    31uu55dhOGzPHAJslZp7uA
# 6501    31uu55dhOGzPHAJslZp7uA
# 6502    31uu55dhOGzPHAJslZp7uA
# 6500    31uu55dhOGzPHAJslZp7uA
# Name: business_id, dtype: object
# p_sorted:
#  6498    31uu55dhOGzPHAJslZp7uA
# 6499    31uu55dhOGzPHAJslZp7uA
# 6501    31uu55dhOGzPHAJslZp7uA
# 6502    31uu55dhOGzPHAJslZp7uA
# 6500    31uu55dhOGzPHAJslZp7uA
# Name: business_id, dtype: object
# a_sorted:
#  1738    c3_lkH7CAglbcIyyXthTcg
# 1734    c3_lkH7CAglbcIyyXthTcg
# 1736    c3_lkH7CAglbcIyyXthTcg
# 1737    c3_lkH7CAglbcIyyXthTcg
# 1733    c3_lkH7CAglbcIyyXthTcg
# 1739    c3_lkH7CAglbcIyyXthTcg
# 1735    c3_lkH7CAglbcIyyXthTcg
# Name: business_id, dtype: object
# p_sorted:
#  1738    c3_lkH7CAglbcIyyXthTcg
# 1734    c3_lkH7CAglbcIyyXthTcg
# 1736    c3_lkH7CAglbcIyyXthTcg
# 1737    c3_lkH7CAglbcIyyXthTcg
# 1733    c3_lkH7CAglbcIyyXthTcg
# 1739    c3_lkH7CAglbcIyyXthTcg
# 1735    c3_lkH7CAglbcIyyXthTcg
# Name: business_id, dtype: object
# a_sorted:
#  6845    _t5JZRB6-bvtX2XsLMidAg
# 6851    _t5JZRB6-bvtX2XsLMidAg
# 6850    _t5JZRB6-bvtX2XsLMidAg
# 6852    _t5JZRB6-bvtX2XsLMidAg
# 6848    _t5JZRB6-bvtX2XsLMidAg
# 6846    _t5JZRB6-bvtX2XsLMidAg
# 6849    _t5JZRB6-bvtX2XsLMidAg
# 6847    _t5JZRB6-bvtX2XsLMidAg
# Name: business_id, dtype: object
# p_sorted:
#  6846    _t5JZRB6-bvtX2XsLMidAg
# 6851    _t5JZRB6-bvtX2XsLMidAg
# 6850    _t5JZRB6-bvtX2XsLMidAg
# 6852    _t5JZRB6-bvtX2XsLMidAg
# 6845    _t5JZRB6-bvtX2XsLMidAg
# 6848    _t5JZRB6-bvtX2XsLMidAg
# 6849    _t5JZRB6-bvtX2XsLMidAg
# 6847    _t5JZRB6-bvtX2XsLMidAg
# Name: business_id, dtype: object
# a_sorted:
#  5849    DfYamqDQNS1RnzeWjOcGPg
# 5856    DfYamqDQNS1RnzeWjOcGPg
# 5854    DfYamqDQNS1RnzeWjOcGPg
# 5852    DfYamqDQNS1RnzeWjOcGPg
# 5853    DfYamqDQNS1RnzeWjOcGPg
# 5851    DfYamqDQNS1RnzeWjOcGPg
# 5855    DfYamqDQNS1RnzeWjOcGPg
# 5850    DfYamqDQNS1RnzeWjOcGPg
# Name: business_id, dtype: object
# p_sorted:
#  5856    DfYamqDQNS1RnzeWjOcGPg
# 5854    DfYamqDQNS1RnzeWjOcGPg
# 5852    DfYamqDQNS1RnzeWjOcGPg
# 5853    DfYamqDQNS1RnzeWjOcGPg
# 5851    DfYamqDQNS1RnzeWjOcGPg
# 5855    DfYamqDQNS1RnzeWjOcGPg
# 5849    DfYamqDQNS1RnzeWjOcGPg
# 5850    DfYamqDQNS1RnzeWjOcGPg
# Name: business_id, dtype: object
# a_sorted:
#  6253    8jXmNMrGJ2acUG1R-D5e6w
# Name: business_id, dtype: object
# p_sorted:
#  6253    8jXmNMrGJ2acUG1R-D5e6w
# Name: business_id, dtype: object
# a_sorted:
#  4157    FGGDERcsTDYt6uLHPWEKrw
# 4155    FGGDERcsTDYt6uLHPWEKrw
# 4156    FGGDERcsTDYt6uLHPWEKrw
# 4159    FGGDERcsTDYt6uLHPWEKrw
# 4160    FGGDERcsTDYt6uLHPWEKrw
# 4161    FGGDERcsTDYt6uLHPWEKrw
# 4158    FGGDERcsTDYt6uLHPWEKrw
# Name: business_id, dtype: object
# p_sorted:
#  4157    FGGDERcsTDYt6uLHPWEKrw
# 4155    FGGDERcsTDYt6uLHPWEKrw
# 4156    FGGDERcsTDYt6uLHPWEKrw
# 4159    FGGDERcsTDYt6uLHPWEKrw
# 4160    FGGDERcsTDYt6uLHPWEKrw
# 4161    FGGDERcsTDYt6uLHPWEKrw
# 4158    FGGDERcsTDYt6uLHPWEKrw
# Name: business_id, dtype: object
# a_sorted:
#  4885    Rm4q_X265Fzfyym1URfQ1w
# 4884    Rm4q_X265Fzfyym1URfQ1w
# 4888    Rm4q_X265Fzfyym1URfQ1w
# 4887    Rm4q_X265Fzfyym1URfQ1w
# 4889    Rm4q_X265Fzfyym1URfQ1w
# 4890    Rm4q_X265Fzfyym1URfQ1w
# 4886    Rm4q_X265Fzfyym1URfQ1w
# Name: business_id, dtype: object
# p_sorted:
#  4885    Rm4q_X265Fzfyym1URfQ1w
# 4884    Rm4q_X265Fzfyym1URfQ1w
# 4888    Rm4q_X265Fzfyym1URfQ1w
# 4887    Rm4q_X265Fzfyym1URfQ1w
# 4889    Rm4q_X265Fzfyym1URfQ1w
# 4890    Rm4q_X265Fzfyym1URfQ1w
# 4886    Rm4q_X265Fzfyym1URfQ1w
# Name: business_id, dtype: object
# a_sorted:
#  2131    rCOIoZ3WuA6pkgRltfEN1g
# 2133    rCOIoZ3WuA6pkgRltfEN1g
# 2135    rCOIoZ3WuA6pkgRltfEN1g
# 2134    rCOIoZ3WuA6pkgRltfEN1g
# 2136    rCOIoZ3WuA6pkgRltfEN1g
# 2132    rCOIoZ3WuA6pkgRltfEN1g
# 2130    rCOIoZ3WuA6pkgRltfEN1g
# Name: business_id, dtype: object
# p_sorted:
#  2131    rCOIoZ3WuA6pkgRltfEN1g
# 2133    rCOIoZ3WuA6pkgRltfEN1g
# 2135    rCOIoZ3WuA6pkgRltfEN1g
# 2134    rCOIoZ3WuA6pkgRltfEN1g
# 2136    rCOIoZ3WuA6pkgRltfEN1g
# 2132    rCOIoZ3WuA6pkgRltfEN1g
# 2130    rCOIoZ3WuA6pkgRltfEN1g
# Name: business_id, dtype: object
# a_sorted:
#  7342    J3g66wKek-2FTCotE7em5w
# Name: business_id, dtype: object
# p_sorted:
#  7342    J3g66wKek-2FTCotE7em5w
# Name: business_id, dtype: object
# a_sorted:
#  818    cq2zq3ItzUwvlzs_ugFpsQ
# 814    cq2zq3ItzUwvlzs_ugFpsQ
# 812    cq2zq3ItzUwvlzs_ugFpsQ
# 817    cq2zq3ItzUwvlzs_ugFpsQ
# 813    cq2zq3ItzUwvlzs_ugFpsQ
# 815    cq2zq3ItzUwvlzs_ugFpsQ
# 816    cq2zq3ItzUwvlzs_ugFpsQ
# Name: business_id, dtype: object
# p_sorted:
#  818    cq2zq3ItzUwvlzs_ugFpsQ
# 814    cq2zq3ItzUwvlzs_ugFpsQ
# 812    cq2zq3ItzUwvlzs_ugFpsQ
# 817    cq2zq3ItzUwvlzs_ugFpsQ
# 813    cq2zq3ItzUwvlzs_ugFpsQ
# 815    cq2zq3ItzUwvlzs_ugFpsQ
# 816    cq2zq3ItzUwvlzs_ugFpsQ
# Name: business_id, dtype: object
# a_sorted:
#  2223    CVJsqDS_XmI0CGbLC1EclQ
# Name: business_id, dtype: object
# p_sorted:
#  2223    CVJsqDS_XmI0CGbLC1EclQ
# Name: business_id, dtype: object
# a_sorted:
#  7691    TVX2a4bVuCE2VUIkiLdZrQ
# 7688    TVX2a4bVuCE2VUIkiLdZrQ
# 7690    TVX2a4bVuCE2VUIkiLdZrQ
# 7689    TVX2a4bVuCE2VUIkiLdZrQ
# Name: business_id, dtype: object
# p_sorted:
#  7691    TVX2a4bVuCE2VUIkiLdZrQ
# 7688    TVX2a4bVuCE2VUIkiLdZrQ
# 7690    TVX2a4bVuCE2VUIkiLdZrQ
# 7689    TVX2a4bVuCE2VUIkiLdZrQ
# Name: business_id, dtype: object
# a_sorted:
#  1134    7pxE4BFDibv6Q7MBbNOPQA
# 1137    7pxE4BFDibv6Q7MBbNOPQA
# 1139    7pxE4BFDibv6Q7MBbNOPQA
# 1140    7pxE4BFDibv6Q7MBbNOPQA
# 1135    7pxE4BFDibv6Q7MBbNOPQA
# 1138    7pxE4BFDibv6Q7MBbNOPQA
# 1136    7pxE4BFDibv6Q7MBbNOPQA
# Name: business_id, dtype: object
# p_sorted:
#  1134    7pxE4BFDibv6Q7MBbNOPQA
# 1137    7pxE4BFDibv6Q7MBbNOPQA
# 1139    7pxE4BFDibv6Q7MBbNOPQA
# 1140    7pxE4BFDibv6Q7MBbNOPQA
# 1135    7pxE4BFDibv6Q7MBbNOPQA
# 1138    7pxE4BFDibv6Q7MBbNOPQA
# 1136    7pxE4BFDibv6Q7MBbNOPQA
# Name: business_id, dtype: object
# a_sorted:
#  5371    YbE-dvcWOgTGPbvkYxr9XA
# 5375    YbE-dvcWOgTGPbvkYxr9XA
# 5376    YbE-dvcWOgTGPbvkYxr9XA
# 5373    YbE-dvcWOgTGPbvkYxr9XA
# 5372    YbE-dvcWOgTGPbvkYxr9XA
# 5374    YbE-dvcWOgTGPbvkYxr9XA
# 5377    YbE-dvcWOgTGPbvkYxr9XA
# Name: business_id, dtype: object
# p_sorted:
#  5375    YbE-dvcWOgTGPbvkYxr9XA
# 5376    YbE-dvcWOgTGPbvkYxr9XA
# 5373    YbE-dvcWOgTGPbvkYxr9XA
# 5372    YbE-dvcWOgTGPbvkYxr9XA
# 5374    YbE-dvcWOgTGPbvkYxr9XA
# 5377    YbE-dvcWOgTGPbvkYxr9XA
# 5371    YbE-dvcWOgTGPbvkYxr9XA
# Name: business_id, dtype: object
# a_sorted:
#  5112    3cVdKfNDrx0IYjEYk5Yauw
# 5114    3cVdKfNDrx0IYjEYk5Yauw
# 5116    3cVdKfNDrx0IYjEYk5Yauw
# 5115    3cVdKfNDrx0IYjEYk5Yauw
# 5117    3cVdKfNDrx0IYjEYk5Yauw
# 5113    3cVdKfNDrx0IYjEYk5Yauw
# 5118    3cVdKfNDrx0IYjEYk5Yauw
# 5119    3cVdKfNDrx0IYjEYk5Yauw
# Name: business_id, dtype: object
# p_sorted:
#  5114    3cVdKfNDrx0IYjEYk5Yauw
# 5116    3cVdKfNDrx0IYjEYk5Yauw
# 5115    3cVdKfNDrx0IYjEYk5Yauw
# 5117    3cVdKfNDrx0IYjEYk5Yauw
# 5112    3cVdKfNDrx0IYjEYk5Yauw
# 5113    3cVdKfNDrx0IYjEYk5Yauw
# 5118    3cVdKfNDrx0IYjEYk5Yauw
# 5119    3cVdKfNDrx0IYjEYk5Yauw
# Name: business_id, dtype: object
# a_sorted:
#  4312    X9e_btDPux6JGqqw8UF_Pg
# 4316    X9e_btDPux6JGqqw8UF_Pg
# 4311    X9e_btDPux6JGqqw8UF_Pg
# 4313    X9e_btDPux6JGqqw8UF_Pg
# 4315    X9e_btDPux6JGqqw8UF_Pg
# 4317    X9e_btDPux6JGqqw8UF_Pg
# 4314    X9e_btDPux6JGqqw8UF_Pg
# Name: business_id, dtype: object
# p_sorted:
#  4312    X9e_btDPux6JGqqw8UF_Pg
# 4316    X9e_btDPux6JGqqw8UF_Pg
# 4311    X9e_btDPux6JGqqw8UF_Pg
# 4313    X9e_btDPux6JGqqw8UF_Pg
# 4315    X9e_btDPux6JGqqw8UF_Pg
# 4317    X9e_btDPux6JGqqw8UF_Pg
# 4314    X9e_btDPux6JGqqw8UF_Pg
# Name: business_id, dtype: object
# a_sorted:
#  7714    bVV6Y8WAPMyn5Cqqy8cU1A
# 7713    bVV6Y8WAPMyn5Cqqy8cU1A
# 7712    bVV6Y8WAPMyn5Cqqy8cU1A
# 7710    bVV6Y8WAPMyn5Cqqy8cU1A
# 7708    bVV6Y8WAPMyn5Cqqy8cU1A
# 7709    bVV6Y8WAPMyn5Cqqy8cU1A
# 7711    bVV6Y8WAPMyn5Cqqy8cU1A
# Name: business_id, dtype: object
# p_sorted:
#  7714    bVV6Y8WAPMyn5Cqqy8cU1A
# 7713    bVV6Y8WAPMyn5Cqqy8cU1A
# 7712    bVV6Y8WAPMyn5Cqqy8cU1A
# 7710    bVV6Y8WAPMyn5Cqqy8cU1A
# 7708    bVV6Y8WAPMyn5Cqqy8cU1A
# 7709    bVV6Y8WAPMyn5Cqqy8cU1A
# 7711    bVV6Y8WAPMyn5Cqqy8cU1A
# Name: business_id, dtype: object
# a_sorted:
#  5901    0jQiSHnQTFyJnw1HHV9NVQ
# 5899    0jQiSHnQTFyJnw1HHV9NVQ
# 5902    0jQiSHnQTFyJnw1HHV9NVQ
# 5904    0jQiSHnQTFyJnw1HHV9NVQ
# 5900    0jQiSHnQTFyJnw1HHV9NVQ
# 5905    0jQiSHnQTFyJnw1HHV9NVQ
# 5903    0jQiSHnQTFyJnw1HHV9NVQ
# Name: business_id, dtype: object
# p_sorted:
#  5901    0jQiSHnQTFyJnw1HHV9NVQ
# 5899    0jQiSHnQTFyJnw1HHV9NVQ
# 5902    0jQiSHnQTFyJnw1HHV9NVQ
# 5904    0jQiSHnQTFyJnw1HHV9NVQ
# 5900    0jQiSHnQTFyJnw1HHV9NVQ
# 5905    0jQiSHnQTFyJnw1HHV9NVQ
# 5903    0jQiSHnQTFyJnw1HHV9NVQ
# Name: business_id, dtype: object
# a_sorted:
#  1334    Vv5Fxre786NpKFR_3OduKw
# 1341    Vv5Fxre786NpKFR_3OduKw
# 1338    Vv5Fxre786NpKFR_3OduKw
# 1336    Vv5Fxre786NpKFR_3OduKw
# 1339    Vv5Fxre786NpKFR_3OduKw
# 1337    Vv5Fxre786NpKFR_3OduKw
# 1340    Vv5Fxre786NpKFR_3OduKw
# 1335    Vv5Fxre786NpKFR_3OduKw
# Name: business_id, dtype: object
# p_sorted:
#  1341    Vv5Fxre786NpKFR_3OduKw
# 1338    Vv5Fxre786NpKFR_3OduKw
# 1336    Vv5Fxre786NpKFR_3OduKw
# 1339    Vv5Fxre786NpKFR_3OduKw
# 1337    Vv5Fxre786NpKFR_3OduKw
# 1334    Vv5Fxre786NpKFR_3OduKw
# 1340    Vv5Fxre786NpKFR_3OduKw
# 1335    Vv5Fxre786NpKFR_3OduKw
# Name: business_id, dtype: object
# a_sorted:
#  6424    I8n5N-GsqvyGG62ug1TrRQ
# 6427    I8n5N-GsqvyGG62ug1TrRQ
# 6429    I8n5N-GsqvyGG62ug1TrRQ
# 6430    I8n5N-GsqvyGG62ug1TrRQ
# 6428    I8n5N-GsqvyGG62ug1TrRQ
# 6425    I8n5N-GsqvyGG62ug1TrRQ
# 6426    I8n5N-GsqvyGG62ug1TrRQ
# Name: business_id, dtype: object
# p_sorted:
#  6424    I8n5N-GsqvyGG62ug1TrRQ
# 6427    I8n5N-GsqvyGG62ug1TrRQ
# 6429    I8n5N-GsqvyGG62ug1TrRQ
# 6430    I8n5N-GsqvyGG62ug1TrRQ
# 6428    I8n5N-GsqvyGG62ug1TrRQ
# 6425    I8n5N-GsqvyGG62ug1TrRQ
# 6426    I8n5N-GsqvyGG62ug1TrRQ
# Name: business_id, dtype: object
# a_sorted:
#  7309    knMaadLnS34vPDNkNlRLrA
# 7311    knMaadLnS34vPDNkNlRLrA
# 7312    knMaadLnS34vPDNkNlRLrA
# 7314    knMaadLnS34vPDNkNlRLrA
# 7316    knMaadLnS34vPDNkNlRLrA
# 7315    knMaadLnS34vPDNkNlRLrA
# 7310    knMaadLnS34vPDNkNlRLrA
# 7313    knMaadLnS34vPDNkNlRLrA
# Name: business_id, dtype: object
# p_sorted:
#  7311    knMaadLnS34vPDNkNlRLrA
# 7312    knMaadLnS34vPDNkNlRLrA
# 7309    knMaadLnS34vPDNkNlRLrA
# 7314    knMaadLnS34vPDNkNlRLrA
# 7316    knMaadLnS34vPDNkNlRLrA
# 7315    knMaadLnS34vPDNkNlRLrA
# 7310    knMaadLnS34vPDNkNlRLrA
# 7313    knMaadLnS34vPDNkNlRLrA
# Name: business_id, dtype: object
# a_sorted:
#  3064    DWuZw05HAhZFpD4kCAvDew
# 3061    DWuZw05HAhZFpD4kCAvDew
# 3066    DWuZw05HAhZFpD4kCAvDew
# 3062    DWuZw05HAhZFpD4kCAvDew
# 3065    DWuZw05HAhZFpD4kCAvDew
# 3063    DWuZw05HAhZFpD4kCAvDew
# 3067    DWuZw05HAhZFpD4kCAvDew
# Name: business_id, dtype: object
# p_sorted:
#  3064    DWuZw05HAhZFpD4kCAvDew
# 3061    DWuZw05HAhZFpD4kCAvDew
# 3066    DWuZw05HAhZFpD4kCAvDew
# 3062    DWuZw05HAhZFpD4kCAvDew
# 3065    DWuZw05HAhZFpD4kCAvDew
# 3063    DWuZw05HAhZFpD4kCAvDew
# 3067    DWuZw05HAhZFpD4kCAvDew
# Name: business_id, dtype: object
# a_sorted:
#  118    k82r04xQpJ7u9Db_aHRJpQ
# 116    k82r04xQpJ7u9Db_aHRJpQ
# 121    k82r04xQpJ7u9Db_aHRJpQ
# 117    k82r04xQpJ7u9Db_aHRJpQ
# 120    k82r04xQpJ7u9Db_aHRJpQ
# 115    k82r04xQpJ7u9Db_aHRJpQ
# 119    k82r04xQpJ7u9Db_aHRJpQ
# Name: business_id, dtype: object
# p_sorted:
#  118    k82r04xQpJ7u9Db_aHRJpQ
# 116    k82r04xQpJ7u9Db_aHRJpQ
# 121    k82r04xQpJ7u9Db_aHRJpQ
# 117    k82r04xQpJ7u9Db_aHRJpQ
# 120    k82r04xQpJ7u9Db_aHRJpQ
# 115    k82r04xQpJ7u9Db_aHRJpQ
# 119    k82r04xQpJ7u9Db_aHRJpQ
# Name: business_id, dtype: object
# a_sorted:
#  1849    ym8OZtQKkXC2SOjJKew5Tw
# 1845    ym8OZtQKkXC2SOjJKew5Tw
# 1847    ym8OZtQKkXC2SOjJKew5Tw
# 1846    ym8OZtQKkXC2SOjJKew5Tw
# 1848    ym8OZtQKkXC2SOjJKew5Tw
# Name: business_id, dtype: object
# p_sorted:
#  1849    ym8OZtQKkXC2SOjJKew5Tw
# 1845    ym8OZtQKkXC2SOjJKew5Tw
# 1847    ym8OZtQKkXC2SOjJKew5Tw
# 1846    ym8OZtQKkXC2SOjJKew5Tw
# 1848    ym8OZtQKkXC2SOjJKew5Tw
# Name: business_id, dtype: object
# a_sorted:
#  2656    zUFgmNOQqIL71lT_WKplFw
# 2655    zUFgmNOQqIL71lT_WKplFw
# 2657    zUFgmNOQqIL71lT_WKplFw
# 2658    zUFgmNOQqIL71lT_WKplFw
# 2653    zUFgmNOQqIL71lT_WKplFw
# 2659    zUFgmNOQqIL71lT_WKplFw
# 2654    zUFgmNOQqIL71lT_WKplFw
# Name: business_id, dtype: object
# p_sorted:
#  2658    zUFgmNOQqIL71lT_WKplFw
# 2656    zUFgmNOQqIL71lT_WKplFw
# 2655    zUFgmNOQqIL71lT_WKplFw
# 2657    zUFgmNOQqIL71lT_WKplFw
# 2653    zUFgmNOQqIL71lT_WKplFw
# 2659    zUFgmNOQqIL71lT_WKplFw
# 2654    zUFgmNOQqIL71lT_WKplFw
# Name: business_id, dtype: object
# a_sorted:
#  6650    vKBQmHjx5K9cYoGqWLyBhQ
# 6652    vKBQmHjx5K9cYoGqWLyBhQ
# 6651    vKBQmHjx5K9cYoGqWLyBhQ
# 6646    vKBQmHjx5K9cYoGqWLyBhQ
# 6648    vKBQmHjx5K9cYoGqWLyBhQ
# 6647    vKBQmHjx5K9cYoGqWLyBhQ
# 6649    vKBQmHjx5K9cYoGqWLyBhQ
# Name: business_id, dtype: object
# p_sorted:
#  6648    vKBQmHjx5K9cYoGqWLyBhQ
# 6650    vKBQmHjx5K9cYoGqWLyBhQ
# 6652    vKBQmHjx5K9cYoGqWLyBhQ
# 6651    vKBQmHjx5K9cYoGqWLyBhQ
# 6646    vKBQmHjx5K9cYoGqWLyBhQ
# 6647    vKBQmHjx5K9cYoGqWLyBhQ
# 6649    vKBQmHjx5K9cYoGqWLyBhQ
# Name: business_id, dtype: object
# a_sorted:
#  6977    SXonfRypO6uQa3Wfl1BcxA
# 6976    SXonfRypO6uQa3Wfl1BcxA
# 6975    SXonfRypO6uQa3Wfl1BcxA
# 6978    SXonfRypO6uQa3Wfl1BcxA
# 6974    SXonfRypO6uQa3Wfl1BcxA
# 6979    SXonfRypO6uQa3Wfl1BcxA
# 6973    SXonfRypO6uQa3Wfl1BcxA
# Name: business_id, dtype: object
# p_sorted:
#  6977    SXonfRypO6uQa3Wfl1BcxA
# 6976    SXonfRypO6uQa3Wfl1BcxA
# 6975    SXonfRypO6uQa3Wfl1BcxA
# 6978    SXonfRypO6uQa3Wfl1BcxA
# 6974    SXonfRypO6uQa3Wfl1BcxA
# 6979    SXonfRypO6uQa3Wfl1BcxA
# 6973    SXonfRypO6uQa3Wfl1BcxA
# Name: business_id, dtype: object
# a_sorted:
#  6313    TuYFF4EyehNbGPQRKQMo0A
# 6315    TuYFF4EyehNbGPQRKQMo0A
# 6316    TuYFF4EyehNbGPQRKQMo0A
# 6314    TuYFF4EyehNbGPQRKQMo0A
# 6311    TuYFF4EyehNbGPQRKQMo0A
# 6312    TuYFF4EyehNbGPQRKQMo0A
# 6310    TuYFF4EyehNbGPQRKQMo0A
# Name: business_id, dtype: object
# p_sorted:
#  6313    TuYFF4EyehNbGPQRKQMo0A
# 6315    TuYFF4EyehNbGPQRKQMo0A
# 6316    TuYFF4EyehNbGPQRKQMo0A
# 6314    TuYFF4EyehNbGPQRKQMo0A
# 6311    TuYFF4EyehNbGPQRKQMo0A
# 6312    TuYFF4EyehNbGPQRKQMo0A
# 6310    TuYFF4EyehNbGPQRKQMo0A
# Name: business_id, dtype: object
# a_sorted:
#  2365    8xeP-hY-mIBYufHVeMvokA
# 2360    8xeP-hY-mIBYufHVeMvokA
# 2363    8xeP-hY-mIBYufHVeMvokA
# 2359    8xeP-hY-mIBYufHVeMvokA
# 2364    8xeP-hY-mIBYufHVeMvokA
# 2362    8xeP-hY-mIBYufHVeMvokA
# 2361    8xeP-hY-mIBYufHVeMvokA
# Name: business_id, dtype: object
# p_sorted:
#  2365    8xeP-hY-mIBYufHVeMvokA
# 2360    8xeP-hY-mIBYufHVeMvokA
# 2363    8xeP-hY-mIBYufHVeMvokA
# 2359    8xeP-hY-mIBYufHVeMvokA
# 2364    8xeP-hY-mIBYufHVeMvokA
# 2362    8xeP-hY-mIBYufHVeMvokA
# 2361    8xeP-hY-mIBYufHVeMvokA
# Name: business_id, dtype: object
# a_sorted:
#  6156    P9ltq8KT6pgKjyZSKspHfA
# 6153    P9ltq8KT6pgKjyZSKspHfA
# 6155    P9ltq8KT6pgKjyZSKspHfA
# 6152    P9ltq8KT6pgKjyZSKspHfA
# 6154    P9ltq8KT6pgKjyZSKspHfA
# Name: business_id, dtype: object
# p_sorted:
#  6156    P9ltq8KT6pgKjyZSKspHfA
# 6153    P9ltq8KT6pgKjyZSKspHfA
# 6155    P9ltq8KT6pgKjyZSKspHfA
# ...
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):0
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):0
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):0
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):0
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# Score(分子):1
# len(prediction)(分母):1
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_8308/2541321990.py in <module>
#      30 #     dcg_list , ndcg_list = calculate_dcg_ndcg(pred_list , true_list,pred_rel)
#      31     precision_list_1 = _precision(pred_list , true_list, k=1)
# ---> 32     recall_list_1 = _recall(pred_list , true_list, k=1)
#      33 #     precision_list_3 = _precision(pred_list , true_list, k=3)
#      34 #     recall_list_3 = _recall(pred_list , true_list,k=3)
#
# /tmp/ipykernel_8308/1021184215.py in _recall(predictions, actuals, k)
#      52             if prediction[j] in actuals[i]:
#      53                 score+=1
# ---> 54         recalls.append(score/len(actuals[i]))
#      55
#      56     return recalls
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # Evaluation

# %%
pd.DataFrame(score_dict).round(3)
# Out:
# Empty DataFrame
# Columns: [LR]
# Index: []
