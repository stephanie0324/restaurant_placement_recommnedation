# %% [markdown]
# # 論文資料及整理
# * YELP
#     * EDA
#     * 50 review above
#     * join business, check-in and tips

# %% [markdown]
# # Import

# %%
import pandas as pd
import json
import numpy as np
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt

# %%
business_path = '/home/adam/Steph_C/my_thesis/Data/yelp/yelp_academic_dataset_business.json'
checkin_path = '/home/adam/Steph_C/my_thesis/Data/yelp/yelp_academic_dataset_checkin.json'
tip_path = '/home/adam/Steph_C/my_thesis/Data/yelp/yelp_academic_dataset_tip.json'
review_path = '/home/adam/Steph_C/my_thesis/Data/yelp/yelp_academic_dataset_review.json'

# pickle file
business_pk = '/home/adam/Steph_C/my_thesis/Data/yelp/business.pkl'
checkin_pk = '/home/adam/Steph_C/my_thesis/Data/yelp/checkin.pkl'
tip_pk = '/home/adam/Steph_C/my_thesis/Data/yelp/tip.pkl'
review_pk = '/home/adam/Steph_C/my_thesis/Data/yelp/review.pkl'
final_pk = '/home/adam/Steph_C/my_thesis/Data/yelp/final.pkl'

# %% [markdown]
# # Load Data

# %%
# # unhash this part if necessary

# # load review data
# r_dict = []

# r_dtypes = {"stars": np.float16, 
#             "useful": np.int32, 
#             "funny": np.int32,
#             "cool": np.int32,
#            }
# with open(review_path, "r") as f:
#     reader = pd.read_json(f, orient="records", lines=True, 
#                           dtype=r_dtypes, chunksize=1000)
#     for chunk in reader:
#.        # get 5 years data from '2018-2022'
#         reduced_chunk = chunk.drop(columns=['review_id', 'user_id'])\
#                              .query("date >= '2018-1-01'").query("date <= '2022-12-31'")
#         r_dict.append(reduced_chunk)
    
# r_dict = pd.concat(r_dict, ignore_index=True)

# # load business data
# b_dict =[]

# with open(business_path, "r") as f:
#     reader = pd.read_json(f, orient="records", lines=True, chunksize=1000)
        
#     for chunk in reader:
#         reduced_chunk = chunk.drop(
#             columns=['latitude','longitude'])
#         b_dict.append(reduced_chunk)
    
# b_dict = pd.concat(b_dict, ignore_index=True)

# # load check-in data
# c_dict =[]

# with open(checkin_path, "r") as f:
#     reader = pd.read_json(f, orient="records", lines=True, chunksize=1000)
        
#     for chunk in reader:
# #         reduced_chunk = chunk.drop(
# #             columns=['postal_code','latitude','longitude','is_open','attributes','hours'])
#         c_dict.append(chunk)
    
# c_dict = pd.concat(c_dict, ignore_index=True)

# # load tip data
# t_dict =[]

# with open(tip_path, "r") as f:
#     reader = pd.read_json(f, orient="records", lines=True, chunksize=1000)
        
#     for chunk in reader:
#         reduced_chunk = chunk.drop(
#             columns=['user_id'])
#         t_dict.append(reduced_chunk)
    
# t_dict = pd.concat(t_dict, ignore_index=True)

# %%
# business_df = pd.DataFrame(b_dict)
# review_df = pd.DataFrame(r_dict)
# checkin_df = pd.DataFrame(c_dict)
# tip_df = pd.DataFrame(t_dict)

# %%
# review_df.to_pickle("../Data/yelp/review.pkl")  
# business_df.to_pickle("../Data/yelp/business.pkl") 
# checkin_df.to_pickle("../Data/yelp/checkin.pkl")  
# tip_df.to_pickle("../Data/yelp/tip.pkl")

# %% [markdown]
# # Join tables

# %%
# business_df = pd.read_pickle (business_pk)
# review_df = pd.read_pickle(review_pk)
# checkin_df = pd.read_pickle(checkin_pk)
# tip_df = pd.read_pickle(tip_pk)

# print shape
# print(review_df.shape)
# print(business_df.shape)
# print(checkin_df.shape)
# print(tip_df.shape)

# %%
#### All sorts of processing 

# # get 50 reviews above 
# review_df = review_df[review_df.groupby('business_id')['business_id'].transform('count')>50]
# print(review_df.shape)

# # get only the open stores
# business_df = business_df[business_df.is_open==1]
# print(business_df.shape)

# # spread the check-in data
# checkin_df = checkin_df.assign(date=checkin_df.date.str.split(','))
# checkin_df = checkin_df.explode('date')
# print(checkin_df.shape)

# %%
# # join tables
# final_df = review_df.merge(business_df, on='business_id')

# %%
# drop not restaurants
# drop_l = [final_df.business_id[i] for i in range(len(final_df))if 'Restaurant' not in final_df.categories[i] ]
# drop_l = list(set(drop_l))

# final_df = final_df[~final_df.business_id.isin(drop_l)]
# final_df.shape

# final_df.shape
# final_df.to_pickle("../Data/yelp/final.pkl")

# %% [markdown]
# # Pre-process

# %%
df = pd.read_pickle('/home/adam/Steph_C/Data/yelp/final.pkl')

# %%
df.shape
# Out:
# (1618930, 18)

# %%
df.columns
# Out:
# Index(['business_id', 'stars_x', 'useful', 'funny', 'cool', 'text', 'date',
#        'name', 'address', 'city', 'state', 'postal_code', 'stars_y',
#        'review_count', 'is_open', 'attributes', 'categories', 'hours'],
#       dtype='object')

# %% [markdown]
# # EDA

# %%
# calculate the city number of each state
for i in Counter(df.state):
    tmp = df[df.state==i]
    print(f'State : {i} ,\
    city no. : {len(Counter(tmp.city))},\
    postal_code cnt : {len(Counter(tmp.postal_code))},\
    restaurant no. : {len(Counter(tmp.name))}')
# Out:
# State : PA ,    city no. : 143,    postal_code cnt : 163,    restaurant no. : 2123
# State : TN ,    city no. : 22,    postal_code cnt : 42,    restaurant no. : 1067
# State : LA ,    city no. : 18,    postal_code cnt : 41,    restaurant no. : 1047
# State : FL ,    city no. : 76,    postal_code cnt : 116,    restaurant no. : 2185
# State : IN ,    city no. : 18,    postal_code cnt : 53,    restaurant no. : 892
# State : MO ,    city no. : 48,    postal_code cnt : 53,    restaurant no. : 752
# State : NV ,    city no. : 8,    postal_code cnt : 20,    restaurant no. : 792
# State : ID ,    city no. : 4,    postal_code cnt : 14,    restaurant no. : 328
# State : CA ,    city no. : 7,    postal_code cnt : 12,    restaurant no. : 558
# State : AZ ,    city no. : 10,    postal_code cnt : 35,    restaurant no. : 726
# State : NJ ,    city no. : 81,    postal_code cnt : 66,    restaurant no. : 415
# State : IL ,    city no. : 18,    postal_code cnt : 17,    restaurant no. : 57
# State : DE ,    city no. : 9,    postal_code cnt : 19,    restaurant no. : 118
# State : AB ,    city no. : 3,    postal_code cnt : 41,    restaurant no. : 43

# %%
cnt = 0
state_list = [i for i in Counter(df.state)]
# Index 4 Axes arrays in 4 subplots within 1 Figure: 
for state_name in state_list:
    plt.title(state_name)
    plt.xlabel('city')
    plt.ylabel('postal code cnt ')
    state = df[df.state == state_name]
    city_list = [c for c in Counter(state.city) ]
    postal_code_list = [  len(Counter(state[state.city == city_name].postal_code)) for city_name in city_list]
    plt.plot(city_list, postal_code_list)
    plt.show()

# %%
# Count the postal code per restaurant
restaurant_postal = {}
cnt = 0
for i in Counter(df.name):
    if cnt%500 ==0:
        print(f'Now progress .... : {cnt}')
    restaurant_postal[i] = {}
    tmp = df[df.name==i]
    restaurant_postal[i]['state']=Counter(tmp.state).keys()
    restaurant_postal[i]['city']=Counter(tmp.city).keys()
    restaurant_postal[i]['postal_count']=len(Counter(tmp.postal_code))
    cnt+=1
# Out:
# Now progress .... : 0
# Now progress .... : 500
# Now progress .... : 1000
# Now progress .... : 1500
# Now progress .... : 2000
# Now progress .... : 2500
# Now progress .... : 3000
# Now progress .... : 3500
# Now progress .... : 4000
# Now progress .... : 4500
# Now progress .... : 5000
# Now progress .... : 5500
# Now progress .... : 6000
# Now progress .... : 6500
# Now progress .... : 7000
# Now progress .... : 7500
# Now progress .... : 8000
# Now progress .... : 8500
# Now progress .... : 9000
# Now progress .... : 9500
# Now progress .... : 10000
# Now progress .... : 10500

# %%
for i in restaurant_postal:
# Out:
# {'Turning Point of North Wales': {'state': dict_keys(['PA']),
#   'city': dict_keys(['North Wales']),
#   'postal_count': 1},
#  'Milk and Honey Nashville': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Cafe Beignet on Bourbon Street': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Termini Bros Bakery': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 2},
#  'Ava': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Creole House Restaurant & Oyster Bar': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Milktooth': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Hyatt Regency St. Louis at the Arch': {'state': dict_keys(['MO']),
#   'city': dict_keys(['Saint Louis']),
#   'postal_count': 1},
#  'Lobster Haven': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Saki Endless Sushi & Hibachi Eatery': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Clearwater', 'Palm Harbor']),
#   'postal_count': 2},
#  'The Pancake Pantry': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  "Landry's Seafood House": {'state': dict_keys(['MO', 'LA']),
#   'city': dict_keys(['Saint Louis', 'New Orleans']),
#   'postal_count': 3},
#  "Captain Bill's Oyster Bar": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Treasure Island']),
#   'postal_count': 1},
#  'Bab Café - Reno': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'Biscuit Love: Hillsboro Village': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Ichicoro Ane': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Saint Petersburg']),
#   'postal_count': 1},
#  'Sips Specialty Coffee House': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Tandoor & Tikka': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 2},
#  'Capitol Cellars': {'state': dict_keys(['ID']),
#   'city': dict_keys(['Boise']),
#   'postal_count': 1},
#  'Trophy Fish': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Saint Petersburg']),
#   'postal_count': 1},
#  'Sen Thai Asian Bistro': {'state': dict_keys(['MO']),
#   'city': dict_keys(['St Louis']),
#   'postal_count': 1},
#  'State Street Kitchen': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Newtown']),
#   'postal_count': 1},
#  "Giordano's": {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis', 'Greenwood']),
#   'postal_count': 3},
#  'Crazy Sushi': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Tastee Restaurant': {'state': dict_keys(['LA']),
#   'city': dict_keys(['Kenner']),
#   'postal_count': 1},
#  "Jesse's Steak and Seafood": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Brandon']),
#   'postal_count': 1},
#  'Cured Nails': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'United Van Lines Movers -  Saint Louis': {'state': dict_keys(['MO']),
#   'city': dict_keys(['St. Louis']),
#   'postal_count': 1},
#  'Nectar Urban Cantina': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Montesano Bros Trattoria & Catering': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Chester Springs']),
#   'postal_count': 1},
#  'Butcher & Bee': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  "Earl's New American": {'state': dict_keys(['PA']),
#   'city': dict_keys(['New Hope']),
#   'postal_count': 1},
#  'The Cuban Sandwich Shop': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Madre - Boutique Taqueria': {'state': dict_keys(['ID']),
#   'city': dict_keys(['Boise']),
#   'postal_count': 1},
#  "Li'l Dizzy's Cafe": {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Fellini Cafe of Media': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Media']),
#   'postal_count': 1},
#  "Mahony's Po-Boys & Seafood": {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Red Owl Tavern': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Dairy Joy': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Glanzmann Subaru': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Hatboro']),
#   'postal_count': 1},
#  'Urban South Brewery': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Burger Republic': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville', 'Mt. Juliet']),
#   'postal_count': 3},
#  'Dawn Patrol': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'HipCityVeg': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 2},
#  "Surrey's Café & Juice Bar": {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Loco Mexican Restaurant & Cantina': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 2},
#  "Mena's Palace": {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Blues City Deli': {'state': dict_keys(['MO']),
#   'city': dict_keys(['Saint Louis']),
#   'postal_count': 1},
#  'Hotel Indigo Nashville': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Ekta Indian Cuisine': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Bryn Mawr', 'Philadelphia']),
#   'postal_count': 3},
#  'Tomo Sushi & Ramen': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Spasso Italian Grill': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Media', 'Philadelphia']),
#   'postal_count': 2},
#  'American Social': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'The Fountain On Locust': {'state': dict_keys(['MO']),
#   'city': dict_keys(['Saint Louis']),
#   'postal_count': 1},
#  'Top Hog': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Gallatin']),
#   'postal_count': 1},
#  'Nails & Beauty Lounge': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Brandon']),
#   'postal_count': 1},
#  'Unique Indoor Comfort': {'state': dict_keys(['PA']),
#   'city': dict_keys(['King of Prussia']),
#   'postal_count': 1},
#  'Street- Taco and Beer Co.': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson', 'Oro Valley']),
#   'postal_count': 2},
#  'RumFish Grill': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Saint Pete Beach']),
#   'postal_count': 1},
#  'Helena Avenue Bakery': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'Thai Legacy Restaurant': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Brandon']),
#   'postal_count': 1},
#  'Raijin Ramen': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  "Willie's Chicken Shack": {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Lama Dog Tap Room': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'Blaze Pizza': {'state': dict_keys(['NV', 'LA', 'IN', 'FL', 'TN', 'ID', 'CA', 'PA']),
#   'city': dict_keys(['Reno', 'New Orleans', 'Sparks', 'Indianapolis', 'Trinity', 'Brentwood', 'Lutz', 'Meridian', 'Carmel', 'Santa Barbara', 'Philadelphia', 'Fishers']),
#   'postal_count': 14},
#  'Broad Ripple Brewpub': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'The Saint Hotel, Autograph Collection': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Chick-fil-A': {'state': dict_keys(['NV', 'TN', 'FL', 'IN', 'LA', 'AZ', 'CA', 'MO']),
#   'city': dict_keys(['Reno', 'Nashville', 'Riverview', 'Saint Petersburg', 'Indianapolis', 'Metairie', 'Tucson', 'Santa Barbara', 'Tampa', 'Brandon', 'Brentwood', 'Lutz', 'Sparks']),
#   'postal_count': 19},
#  'The Three Coins Diner': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Mammoth Espresso': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'NoBaked Cookie Dough': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'KRĒM': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'Buddy Brew - Hyde Park': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  "Salty's Island Bar & Grille": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Clearwater Beach']),
#   'postal_count': 1},
#  'Bacchanal Fine Wine & Spirits': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Three Muses': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Sockeye Brewing': {'state': dict_keys(['ID']),
#   'city': dict_keys(['Boise']),
#   'postal_count': 1},
#  'Cafe Square One': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Tria Cafe Wash West': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Vecchia Osteria': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Newtown']),
#   'postal_count': 1},
#  'On The Border Mexican Grill & Cantina': {'state': dict_keys(['NJ', 'IN', 'PA']),
#   'city': dict_keys(['Mt. Laurel', 'Greenwood', 'Avon', 'Bensalem', 'Indianapolis', 'Exton']),
#   'postal_count': 6},
#  'Peppermill Reno': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'Venus Nail and Spa': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  "Mazzaro's Italian Market": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Saint Petersburg']),
#   'postal_count': 1},
#  'Redwood Rotisserie + Grill': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  "Ron's Original Bar & Grille": {'state': dict_keys(['PA']),
#   'city': dict_keys(['Exton']),
#   'postal_count': 1},
#  'The Turning Point - Cherry Hill': {'state': dict_keys(['NJ']),
#   'city': dict_keys(['Cherry Hill']),
#   'postal_count': 1},
#  'The Alexander': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  "L'amour Nails & Spa": {'state': dict_keys(['LA']),
#   'city': dict_keys(['Metairie']),
#   'postal_count': 1},
#  'The Mad Crab': {'state': dict_keys(['MO']),
#   'city': dict_keys(['University City']),
#   'postal_count': 1},
#  'Yolk Iron Works': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Cafe Fleur De Lis': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Bourbon & Branch': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Silver In the City': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Two Chicks Cafe': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Copabanana': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 2},
#  'Sushiya Express': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Goleta']),
#   'postal_count': 1},
#  "Glazer Children's Museum": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  "Katie's Restaurant & Bar": {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Williams Sub Shop': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Saint Petersburg']),
#   'postal_count': 1},
#  'Masami Japanese Steakhouse & Sushi Bar': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Drexel Hill']),
#   'postal_count': 1},
#  "Barro's Pizza": {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Marana', 'Tucson']),
#   'postal_count': 2},
#  'Sweet Soulfood': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Luke': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'The Love': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Delicia': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Hellas Restaurant': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tarpon Springs']),
#   'postal_count': 1},
#  'The Sweet Life Bakeshop': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'San Antonio Taco Co': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'The C House': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Han Dynasty': {'state': dict_keys(['PA', 'NJ']),
#   'city': dict_keys(['Philadelphia', 'Exton', 'Cherry Hill', 'Royersford']),
#   'postal_count': 6},
#  'Hendricks BBQ': {'state': dict_keys(['MO']),
#   'city': dict_keys(['St Charles']),
#   'postal_count': 1},
#  'Marrakesh': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Penang': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  "Dave & Buster's": {'state': dict_keys(['LA', 'IN', 'PA', 'TN', 'FL', 'AZ', 'MO']),
#   'city': dict_keys(['New Orleans', 'Indianapolis', 'Philadelphia', 'Nashville', 'Tampa', 'Tucson', 'Maryland Heights', 'Plymouth Meeting']),
#   'postal_count': 9},
#  'SF Kitchen': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'Clear Sky on Cleveland': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Clearwater']),
#   'postal_count': 1},
#  'Angry Chair Brewing': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Crown & Bull': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Dunedin']),
#   'postal_count': 1},
#  'Tuna Bar': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Mamas Kitchen': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa', 'Seminole']),
#   'postal_count': 3},
#  '4 Rivers Smokehouse': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa Bay', 'Tampa']),
#   'postal_count': 2},
#  'Johnny Rockets': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'Earnest Bar & Hideaway': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Coco Blue Nail & Spa': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 2},
#  'The Cake Bake Shop by Gwendolyn Rogers-Broad Ripple Village': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Five Star Pizza': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'honeygrow': {'state': dict_keys(['PA', 'NJ', 'DE']),
#   'city': dict_keys(['Bala Cynwyd', 'Marlton', 'Philadelphia', 'Christiana', 'Cherry Hill', 'Wilmington', 'King Of Prussia']),
#   'postal_count': 8},
#  'Fireside Pizza Cafe': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Palm Harbor']),
#   'postal_count': 1},
#  'Grand Isle': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'The Screamery HandCrafted Ice Cream': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 2},
#  'Persian Room Fine Dining': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Magasin Kitchen': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  "Growler's Taphouse": {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Berlins Doener': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Saint Petersburg']),
#   'postal_count': 1},
#  'Cajun Encounters Tour Company': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Hollander Hotel': {'state': dict_keys(['FL']),
#   'city': dict_keys(['St. Petersburg']),
#   'postal_count': 1},
#  'The Pasta House': {'state': dict_keys(['MO']),
#   'city': dict_keys(['St. Louis']),
#   'postal_count': 1},
#  'Tucson / Lazydays KOA': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Crooked Thumb Brewery': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Safety Harbor']),
#   'postal_count': 1},
#  'Zoes Kitchen': {'state': dict_keys(['FL', 'LA', 'NJ']),
#   'city': dict_keys(['Tampa', 'Metairie', 'Harahan', 'Cherry Hill']),
#   'postal_count': 5},
#  'Cafe Du Monde': {'state': dict_keys(['LA']),
#   'city': dict_keys(['Metairie', 'New Orleans', 'Kenner']),
#   'postal_count': 3},
#  "Yoichi's": {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'Preservation Hall': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Padaro Beach Grill': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Carpinteria']),
#   'postal_count': 1},
#  'Tavern': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Brunchies - Lutz': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Lutz']),
#   'postal_count': 1},
#  'Samurai Sushi': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Burger Up': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Kei Sushi': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  "Jalapeño's 2": {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  "Cheddar's Scratch Kitchen": {'state': dict_keys(['IL', 'TN', 'FL', 'AZ', 'IN']),
#   'city': dict_keys(['Fairview Heights', 'Mt Juliet', 'Lutz', 'Tucson', 'Avon', 'Pinellas Park', 'Smyrna', 'Tampa', 'Indianapolis', 'Brentwood', 'Clearwater']),
#   'postal_count': 11},
#  "Mike's Ice Cream": {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  '21st Amendment at La Louisiane': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'The Little Lamb': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Clearwater']),
#   'postal_count': 1},
#  'Zen Yai Thai Cuisine': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'Margaritaville - Nashville': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Bittersweet Confections': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'District Donuts Sliders Brew': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans', 'Jefferson']),
#   'postal_count': 2},
#  "Joey's New York Pizza and Italian Restaurant": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Palm Harbor', 'New Port Richey']),
#   'postal_count': 3},
#  'Fresco Pizzeria': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Granite City Food & Brewery': {'state': dict_keys(['TN', 'IN', 'MO']),
#   'city': dict_keys(['Franklin', 'Indianapolis', 'Creve Coeur']),
#   'postal_count': 3},
#  'Café Piazza': {'state': dict_keys(['MO']),
#   'city': dict_keys(['Saint Louis']),
#   'postal_count': 1},
#  'Ted Drewes': {'state': dict_keys(['MO']),
#   'city': dict_keys(['Saint Louis']),
#   'postal_count': 1},
#  "Goody's Soda Fountain & Candy Store": {'state': dict_keys(['ID']),
#   'city': dict_keys(['Boise']),
#   'postal_count': 1},
#  'Ole Red': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Yolklore': {'state': dict_keys(['MO']),
#   'city': dict_keys(['St. Louis']),
#   'postal_count': 1},
#  "Dean's Service": {'state': dict_keys(['NJ']),
#   'city': dict_keys(['Marlton']),
#   'postal_count': 1},
#  'Bangkokville Thai Cuisine': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Vela': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Doylestown']),
#   'postal_count': 1},
#  'The Spot Sushi Burritos': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Largo']),
#   'postal_count': 1},
#  'Flambo Caribbean Restaurant': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Ralphs Italian Restaurant': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Las Palmas Mexican Restaurant': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  "Maggie Mae's Sunrise Cafe": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Clearwater Beach']),
#   'postal_count': 1},
#  'Fleming’s Prime Steakhouse & Wine Bar': {'state': dict_keys(['LA', 'FL', 'PA', 'AZ', 'NJ', 'TN', 'MO']),
#   'city': dict_keys(['Metairie', 'Tampa', 'Radnor', 'Tucson', 'Marlton', 'Nashville', 'St. Louis']),
#   'postal_count': 7},
#  'Hooters': {'state': dict_keys(['AZ', 'FL', 'IN', 'MO']),
#   'city': dict_keys(['Tucson', 'Clearwater', 'Indianapolis', 'Tampa', 'Port Richey', 'Madeira Beach', 'St. Louis']),
#   'postal_count': 9},
#  'Indy Tacos': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Mint Modern Vietnamese Bistro & Bar': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Sauce on the Side': {'state': dict_keys(['MO', 'IN']),
#   'city': dict_keys(['St. Louis', 'Clayton', 'Saint Louis', 'Carmel', 'Indianapolis']),
#   'postal_count': 5},
#  'ABC Pizza House': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Rescue Spa': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'NOLA Automotive Repairs': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'The Hattery Stove & Still': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Doylestown']),
#   'postal_count': 1},
#  'Suraya': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Desire Oyster Bar': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Livery - Indianapolis': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'El Charro Cafe': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Oro Valley', 'Tucson']),
#   'postal_count': 3},
#  'Karma Juice Bar & Eatery - Saint Petersburg': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Saint Petersburg']),
#   'postal_count': 1},
#  'Smyrna Cafe': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Smyrna']),
#   'postal_count': 1},
#  'Harbor Seafood & Oyster Bar': {'state': dict_keys(['LA']),
#   'city': dict_keys(['Kenner']),
#   'postal_count': 1},
#  "Boostin' Bowls": {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Santa Barbara Shellfish Company': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  "Puckett's Grocery & Restaurant": {'state': dict_keys(['TN']),
#   'city': dict_keys(['Franklin', 'Nashville']),
#   'postal_count': 2},
#  'Peno': {'state': dict_keys(['MO']),
#   'city': dict_keys(['Clayton']),
#   'postal_count': 1},
#  'Third Window Brewing': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'Orchids Thai Restaurant': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Port Richey']),
#   'postal_count': 1},
#  "Hendel's": {'state': dict_keys(['MO']),
#   'city': dict_keys(['Florissant']),
#   'postal_count': 1},
#  'DoubleTree by Hilton Hotel Philadelphia Center City': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Kawa Japanese Cuisine': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Springfield']),
#   'postal_count': 1},
#  'New China': {'state': dict_keys(['MO']),
#   'city': dict_keys(['Saint Louis']),
#   'postal_count': 1},
#  'Chase Restaurant': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'Chadds Ford Tavern': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Chadds Ford']),
#   'postal_count': 1},
#  "Ted Peter's Famous Smoked Fish": {'state': dict_keys(['FL']),
#   'city': dict_keys(['South Pasadena']),
#   'postal_count': 1},
#  'Sheraton Indianapolis Hotel at Keystone Crossing': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Noble Crust': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Wesley Chapel', 'St. Petersburg', 'Tampa']),
#   'postal_count': 3},
#  'Buff Beauty Bar': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Gaylord Opryland Resort & Convention Center': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  "Sam's Beach Bar": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Hudson']),
#   'postal_count': 1},
#  'Sushi Bar': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  "Cuenelli's Peruvian Restaurant": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  "Al's Finger Licking Good Bar-B-Que": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  "Inchin's Bamboo Garden": {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  "Guru's Indian Cuisine": {'state': dict_keys(['PA']),
#   'city': dict_keys(['Newtown']),
#   'postal_count': 1},
#  'West Ave Grille Jenkintown Restaurant and Food Truck ': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Jenkintown']),
#   'postal_count': 1},
#  'Old Times Kafe': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  "Blondie's Coffee and Wine Bar": {'state': dict_keys(['MO']),
#   'city': dict_keys(['Saint Louis']),
#   'postal_count': 1},
#  'The Depot Craft Brewery Distillery': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  '3 Sisters Café': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  "Morrow's": {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'House of Blues Restaurant & Bar': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Bobby Hotel': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  "Mr. B's Bistro": {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Bayou Bistro Louisiana Cuisine': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Federal Donuts': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 4},
#  'Coffeebar': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  '1200 Chophouse': {'state': dict_keys(['FL']),
#   'city': dict_keys(['St. Petersburg']),
#   'postal_count': 1},
#  'Rembrandts': {'state': dict_keys(['ID']),
#   'city': dict_keys(['Eagle']),
#   'postal_count': 1},
#  "Muriel's Jackson Square": {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  "J's Seafood Dock": {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Glossy 130 Nails & Spa': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Palm Harbor']),
#   'postal_count': 1},
#  'Tacodelphia': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'In-N-Out Burger': {'state': dict_keys(['CA', 'NV', 'AZ']),
#   'city': dict_keys(['Goleta', 'Sparks', 'Reno', 'Tucson']),
#   'postal_count': 6},
#  'Treme Coffeehouse': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Sea Turtle Restaurant': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Saint Pete Beach']),
#   'postal_count': 1},
#  'Crown Honda': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Pinellas Park']),
#   'postal_count': 1},
#  'Kimpton Hotel Monaco Philadelphia': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Three Carrots Fountain Square': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Pikpon Thai': {'state': dict_keys(['NJ']),
#   'city': dict_keys(['Sicklerville']),
#   'postal_count': 1},
#  'The Mona Lisa Lounge': {'state': dict_keys(['LA']),
#   'city': dict_keys(['Westwego']),
#   'postal_count': 1},
#  'Vineyards Cafe': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Barrio Brewing': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Trident Grill': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'JW Marriott Indianapolis': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  '312 Pizza Company': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Plat 99': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  "The Children's Museum of Indianapolis": {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  "Tony's Luke": {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Tampa Bay Brewing Company Westchase': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  "Mei's World Pizza": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Alpine Lock and Key': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  "Chickie's & Pete's": {'state': dict_keys(['PA', 'NJ']),
#   'city': dict_keys(['Philadelphia', 'Glassboro', 'Bordentown', 'Drexel Hill', 'Warrington', 'Bensalem', 'Audubon', 'Marlton']),
#   'postal_count': 9},
#  'Pho Street': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia', 'Bryn Mawr']),
#   'postal_count': 3},
#  "Ghini's French Caffe": {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Breakfast Boutique Chestnut Hill': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Texas Roadhouse': {'state': dict_keys(['IN', 'NJ', 'PA', 'FL', 'AZ', 'LA', 'MO', 'NV', 'ID']),
#   'city': dict_keys(['Avon', 'Sicklerville', 'Bensalem', 'St. Petersburg', 'Royersford', 'Tucson', 'Indianapolis', 'Harvey', 'Montgomeryville', 'Ballwin', 'Fishers', 'Reno', 'Meridian', 'Wesley Chapel', 'Riverview', 'Marana', 'Arnold', 'Glen Mills', 'Kirkwood', 'St. Charles']),
#   'postal_count': 23},
#  'Hotel Monteleone': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  "Jimmy Guana's": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Indian Rocks Beach']),
#   'postal_count': 1},
#  'Moto Cucina + Enoteca': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'El Camino Real': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Besito Mexican Restaurant': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  "Sabrina's Café": {'state': dict_keys(['NJ', 'PA']),
#   'city': dict_keys(['Collingswood', 'Philadelphia', 'Wynnewood']),
#   'postal_count': 4},
#  "Michael's Grill": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Brick & Mortar': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Saint Petersburg']),
#   'postal_count': 1},
#  'Tropical Isle Original': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  "Larry's Steaks": {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Ants Pants Café': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Kuchi Sushi & Hibachi': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Provisions Coffee & Kitchen': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Wesley Chapel']),
#   'postal_count': 1},
#  'Copper Vine': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'College Hunks Hauling Junk & Moving - Philadelphia': {'state': dict_keys(['PA']),
#   'city': dict_keys(['West Chester']),
#   'postal_count': 1},
#  'Hachi': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Chalfont']),
#   'postal_count': 1},
#  'Fiamme Pizza': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Taj Mahal Homestyle Indian & Pakistani Cuisine': {'state': dict_keys(['ID']),
#   'city': dict_keys(['Boise']),
#   'postal_count': 1},
#  'Schlafly Bottleworks': {'state': dict_keys(['MO']),
#   'city': dict_keys(['Saint Louis']),
#   'postal_count': 1},
#  "Sabrina's West Street Kitchen": {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'Greko Greek Street Food': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Ooka Restaurant': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Willow Grove']),
#   'postal_count': 1},
#  'Islands Restaurant': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'Timpano Hyde Park': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Cold Spring Tavern': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'Café at The Square': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Cedar Park Cafe': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Tomo Japanese Steakhouse and Sushi Bar': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Cracker Barrel Old Country Store': {'state': dict_keys(['FL', 'NJ', 'PA', 'TN', 'IL', 'AZ', 'IN', 'ID']),
#   'city': dict_keys(['Tampa', 'Mount Laurel', 'Plymouth Meeting', 'Goodlettsville', 'Nashville', 'Shiloh', 'Tucson', 'Wesley Chapel', 'Ridley Park', 'Trevose', 'Mount Holly', 'Seffner', 'Clearwater', 'Fishers', 'Boise']),
#   'postal_count': 17},
#  'The Original Habit Burger Grill': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Goleta']),
#   'postal_count': 1},
#  "BJ's Restaurant & Brewhouse": {'state': dict_keys(['FL', 'NV', 'IN', 'AZ']),
#   'city': dict_keys(['Lutz', 'Reno', 'Greenwood', 'Pinellas Park', 'Clearwater', 'Citrus Park', 'Sparks', 'Tucson', 'Avon']),
#   'postal_count': 10},
#  'Bar Louie - Carmel': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Carmel']),
#   'postal_count': 1},
#  'Cake Life Bake Shop': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Compère Lapin': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  "P J Whelihan's Pub & Restaurant - Oaks": {'state': dict_keys(['PA']),
#   'city': dict_keys(['Oaks']),
#   'postal_count': 1},
#  'The Boiling House': {'state': dict_keys(['NJ']),
#   'city': dict_keys(['Cherry Hill']),
#   'postal_count': 1},
#  'The Blue Duck': {'state': dict_keys(['MO']),
#   'city': dict_keys(['Maplewood']),
#   'postal_count': 1},
#  'Loews Philadelphia Hotel': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Duck Donuts': {'state': dict_keys(['NJ']),
#   'city': dict_keys(['Marlton']),
#   'postal_count': 1},
#  "Guido's Italian Restaurant": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Spring Hill']),
#   'postal_count': 1},
#  '51st Deli': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  "Beck's Cajun Cafe": {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Southern Candymakers': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Barbers Club of Cherry Hill': {'state': dict_keys(['NJ']),
#   'city': dict_keys(['Cherry Hill']),
#   'postal_count': 1},
#  'BB Nails & Spa': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Fishers']),
#   'postal_count': 1},
#  'Chatham Tap Mass. Ave.': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  '1 Tippling Place': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  "Iguana's Mexican Restaurant": {'state': dict_keys(['IN']),
#   'city': dict_keys(['Brownsburg', 'Plainfield']),
#   'postal_count': 2},
#  'Hollywood Grill': {'state': dict_keys(['DE']),
#   'city': dict_keys(['Wilmington']),
#   'postal_count': 1},
#  'Rittenhouse Grill': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Siam Elephant': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Carpinteria']),
#   'postal_count': 1},
#  'European Wax Center': {'state': dict_keys(['PA', 'AZ', 'NV', 'LA', 'FL', 'TN']),
#   'city': dict_keys(['Philadelphia', 'Tucson', 'Reno', 'New Orleans', 'Sparks', 'Tampa', 'Nashville', 'Oro Valley']),
#   'postal_count': 10},
#  "Carmine's Steakhouse": {'state': dict_keys(['MO']),
#   'city': dict_keys(['Saint Louis']),
#   'postal_count': 1},
#  "Smiley's Cafe": {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Mirko Pasta': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Buddy Brew Coffee ': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Kauboi Izakaya': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'IHOP': {'state': dict_keys(['LA', 'PA', 'FL', 'AZ', 'NV', 'IN']),
#   'city': dict_keys(['New Orleans', 'Philadelphia', 'Riverview', 'Exton', 'Tucson', 'Sparks', 'Glen Mills', 'Reno', 'Fishers']),
#   'postal_count': 12},
#  "Johnson's Corner Farm": {'state': dict_keys(['NJ']),
#   'city': dict_keys(['Medford']),
#   'postal_count': 1},
#  'Diva nails': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'New Orleans Social House': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Fellini Cafe': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Newtown Square']),
#   'postal_count': 1},
#  'Los Comparres': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Thai House': {'state': dict_keys(['IL']),
#   'city': dict_keys(['Columbia']),
#   'postal_count': 1},
#  "J Gilbert's Wood-Fired Steaks & Seafood St Louis": {'state': dict_keys(['MO']),
#   'city': dict_keys(['Des Peres']),
#   'postal_count': 1},
#  "Honey's Sit-N-Eat": {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Golden Triangle': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Organico Pizza': {'state': dict_keys(['NJ']),
#   'city': dict_keys(['Marlton']),
#   'postal_count': 1},
#  'Burger Up - Franklin': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Franklin']),
#   'postal_count': 1},
#  'Chiang Mai Thai Noodle': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Charro Steak & Del Rey': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  "Edley's Bar-B-Que - 12 South": {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Bubba Gump Shrimp Co.': {'state': dict_keys(['AB']),
#   'city': dict_keys(['Edmonton']),
#   'postal_count': 1},
#  'St. Pete Bagel Co.': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Saint Petersburg']),
#   'postal_count': 1},
#  "Baileys' Range": {'state': dict_keys(['MO']),
#   'city': dict_keys(['Saint Louis']),
#   'postal_count': 1},
#  'LongHorn Steakhouse': {'state': dict_keys(['FL', 'AZ', 'PA', 'IN', 'ID']),
#   'city': dict_keys(['Saint Petersburg', 'Tucson', 'Clearwater', 'Brandon', 'Philadelphia', 'Lutz', 'Castleton', 'Bala Cynwyd', 'Boise', 'Tampa', 'Springfield']),
#   'postal_count': 12},
#  'Pearl Diver': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Star Nails': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Goleta']),
#   'postal_count': 1},
#  "Chili's": {'state': dict_keys(['NV', 'FL', 'AZ', 'CA', 'PA', 'LA', 'TN', 'ID', 'NJ']),
#   'city': dict_keys(['Reno', 'Tampa', 'Tucson', 'Goleta', 'Philadelphia', 'Metairie', 'Nashville', 'Meridian', 'Saint Petersburg', 'Deptford', 'Harvey', 'Brandon', 'Bala Cynwyd']),
#   'postal_count': 17},
#  'Backyard Bowls': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara', 'Goleta']),
#   'postal_count': 3},
#  'Howl At the Moon Philadelphia': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'HipCityVeg - University City': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Sierra Air-Heating And Air Conditioning': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'Thai 5 Fast Food': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Los Jefes Tortilleria & Grill': {'state': dict_keys(['LA']),
#   'city': dict_keys(['Metairie']),
#   'postal_count': 1},
#  'The Workshop Eatery': {'state': dict_keys(['AB']),
#   'city': dict_keys(['Edmonton']),
#   'postal_count': 1},
#  'Sandyland Reef Inn': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Carpinteria']),
#   'postal_count': 1},
#  'Circle S BBQ': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Hudson']),
#   'postal_count': 1},
#  "Felix's Restaurant & Oyster Bar": {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 2},
#  "St Mary's Mexican Food": {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Meun Fan Thai Cafe': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara', 'Goleta']),
#   'postal_count': 2},
#  "Dickey's Barbecue Pit": {'state': dict_keys(['LA', 'FL', 'NV', 'ID', 'AZ']),
#   'city': dict_keys(['Metairie', 'St. Petersburg', 'Reno', 'Meridian', 'Tucson']),
#   'postal_count': 6},
#  'Tryst Gastro Lounge': {'state': dict_keys(['FL']),
#   'city': dict_keys(['St Petersburg']),
#   'postal_count': 1},
#  'Nashville KOA': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Tasties': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Chicken and Watermelon': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  "The Captain's Boil": {'state': dict_keys(['AB']),
#   'city': dict_keys(['Edmonton']),
#   'postal_count': 1},
#  'Jazmine': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'Uno Pizzeria & Grill': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Oaks']),
#   'postal_count': 1},
#  'Dots Diner - Williams Blvd.': {'state': dict_keys(['LA']),
#   'city': dict_keys(['Kenner']),
#   'postal_count': 1},
#  'Backspace Bar & Kitchen': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Maynards': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Thai Place Restaurant': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Phoenixville']),
#   'postal_count': 1},
#  'Glory Days Grill': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Brandon', 'St. Petersburg', 'Riverview', 'St Pete', 'Wesley Chapel', 'Lutz', 'Palm Harbor', 'Tampa']),
#   'postal_count': 9},
#  "P.F. Chang's": {'state': dict_keys(['PA', 'TN', 'NJ', 'AZ', 'LA', 'MO', 'ID', 'NV', 'IN', 'FL']),
#   'city': dict_keys(['Plymouth Meeting', 'Franklin', 'Marlton', 'Tucson', 'Metairie', 'Warrington', 'Saint Charles', 'Boise', 'Reno', 'Indianapolis', 'Tampa', 'Glen Mills', 'Collegeville', 'Nashville', 'Brandon', 'Clearwater']),
#   'postal_count': 17},
#  'Wang Gang Asian': {'state': dict_keys(['IL']),
#   'city': dict_keys(['Edwardsville']),
#   'postal_count': 1},
#  'Revolucion': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'La Guerrerita Mexican Food': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Goleta']),
#   'postal_count': 1},
#  'St. Louis Union Station Hotel, Curio Collection by Hilton': {'state': dict_keys(['MO']),
#   'city': dict_keys(['St Louis']),
#   'postal_count': 1},
#  'Plaza Deli': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  "Bitar's": {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Angelos Pizza': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Holiday']),
#   'postal_count': 1},
#  'Gray Brothers Cafeteria': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Mooresville']),
#   'postal_count': 1},
#  'Tokyo': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'World of Beer': {'state': dict_keys(['PA', 'FL', 'IN']),
#   'city': dict_keys(['Exton', 'Brandon', 'Indianapolis', 'Tampa']),
#   'postal_count': 5},
#  'Grace Meat + Three': {'state': dict_keys(['MO']),
#   'city': dict_keys(['St. Louis']),
#   'postal_count': 1},
#  'Old World Coffee Lab - Midtown': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'Sher-e-Punjab': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Newfields: A Place for Nature and the Arts': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Please-U-Restaurant': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Well Crafted Beer Company': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Lansdale']),
#   'postal_count': 1},
#  "Harry & Izzy's": {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 2},
#  'Deccan Spice': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Clearwater']),
#   'postal_count': 1},
#  'Ice Cream 504': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'India Café': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Nails By Yen': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Embassy Suites by Hilton Tampa Airport Westshore': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Sushi Ushi': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Valrico']),
#   'postal_count': 1},
#  'La Patisserie Chouquette': {'state': dict_keys(['MO']),
#   'city': dict_keys(['Saint Louis']),
#   'postal_count': 1},
#  'Rusty Pelican - Tampa': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Spice Finch': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  "Keke's Breakfast Cafe": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa', 'Largo', 'Lutz', 'Riverview']),
#   'postal_count': 7},
#  'La Colombe Coffee': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia', 'Bryn Mawr']),
#   'postal_count': 5},
#  'Dots Diner': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Nothing Bundt Cakes': {'state': dict_keys(['AZ', 'IN', 'NV']),
#   'city': dict_keys(['Tucson', 'Fishers', 'Reno', 'Indianapolis']),
#   'postal_count': 4},
#  'Iron Hill Brewery & Restaurant': {'state': dict_keys(['NJ', 'PA', 'DE']),
#   'city': dict_keys(['Voorhees', 'Abington Township', 'West Chester', 'Philadelphia', 'Phoenixville', 'Media', 'Wilmington', 'Maple Shade', 'North Wales', 'Ardmore', 'Newtown']),
#   'postal_count': 12},
#  'Creole Creamery': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Taqueria Pico De Gallo': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Deviate Brewing': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'The Woodhouse Day Spa - New Orleans': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Dove Mountain Brewing': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Marana']),
#   'postal_count': 1},
# ...
#   'city': dict_keys(['Washington Crossing']),
#   'postal_count': 1},
#  'Stigma Ink': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Castillo Inn at the Beach': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  "Pinocchio's Restaurant": {'state': dict_keys(['PA']),
#   'city': dict_keys(['Media']),
#   'postal_count': 1},
#  'NY Pie': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Hendersonville', 'Nashville']),
#   'postal_count': 2},
#  "Chago's Mexican Restaurant": {'state': dict_keys(['TN']),
#   'city': dict_keys(['Smyrna']),
#   'postal_count': 1},
#  "Marjie's Grill": {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Yats': {'state': dict_keys(['IN', 'TN']),
#   'city': dict_keys(['Indianapolis', 'Franklin', 'Carmel', 'Greenwood']),
#   'postal_count': 7},
#  'Octopus Car Wash': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson', 'Green Valley']),
#   'postal_count': 3},
#  'College Hunks Hauling Junk & Moving - St Louis': {'state': dict_keys(['MO']),
#   'city': dict_keys(['Saint Louis']),
#   'postal_count': 1},
#  'Top Tomato Bar & Pizza': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Embassy Suites by Hilton Tampa Downtown Convention Center': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Beach Hut Deli': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'Chicago Paulies': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Side Splitters Comedy Club': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Kung Fu Noodle': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  "Bro's Pizzeria & Bar": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Largo']),
#   'postal_count': 1},
#  "Caruso's": {'state': dict_keys(['AZ', 'CA']),
#   'city': dict_keys(['Tucson', 'Montecito']),
#   'postal_count': 2},
#  "Corks n' Crowns": {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'Barrelhouse Pub and Grill': {'state': dict_keys(['ID']),
#   'city': dict_keys(['Garden City']),
#   'postal_count': 1},
#  "Portillo's Hot Dogs": {'state': dict_keys(['IN', 'FL']),
#   'city': dict_keys(['Avon', 'Fishers', 'Indianapolis', 'Brandon']),
#   'postal_count': 4},
#  "Cappy's Pizzeria- Seminole Heights": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Bourbon Cowboy': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Restoration Hardware': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Meadows Diner': {'state': dict_keys(['NJ']),
#   'city': dict_keys(['Blackwood']),
#   'postal_count': 1},
#  'Bridgestone Arena': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Shooters World': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Ferman Chevrolet - Tampa': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  "Layla's Honky Tonk": {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Burger King': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Sparks']),
#   'postal_count': 1},
#  'Thai Orchid': {'state': dict_keys(['PA', 'IN']),
#   'city': dict_keys(['Blue Bell', 'Plainfield', 'Indianapolis']),
#   'postal_count': 3},
#  'Salon L Manayunk': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'The Cobblestone Eatery and Drinkery': {'state': dict_keys(['IL']),
#   'city': dict_keys(['Lebanon']),
#   'postal_count': 1},
#  'Soho Wellness & Med Spa': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Comfy Nails Zone': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  "Applebee's Grill + Bar": {'state': dict_keys(['FL', 'AZ', 'NV']),
#   'city': dict_keys(['Temple Terrace', 'Tucson', 'Reno', 'Tampa', 'Sparks']),
#   'postal_count': 5},
#  'Kings and Queens Liberian Cuisine': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Upper Darby']),
#   'postal_count': 1},
#  'Conicelli Honda': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Conshohocken']),
#   'postal_count': 1},
#  'Le Rendez-vous': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Amber Indian Restaurant': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Carmel']),
#   'postal_count': 1},
#  "Ron's Caribbean Cuisine": {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  "Logan's Roadhouse": {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville', 'Smyrna']),
#   'postal_count': 3},
#  'Symphony Nails': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Maico': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Total Wine & More': {'state': dict_keys(['FL', 'NV', 'IN']),
#   'city': dict_keys(['Tampa', 'Reno', 'Indianapolis']),
#   'postal_count': 3},
#  'Buffalo Wild Wings': {'state': dict_keys(['IN', 'LA', 'PA', 'MO', 'TN', 'FL', 'AZ', 'ID', 'NV']),
#   'city': dict_keys(['Zionsville', 'New Orleans', 'Indianapolis', 'Warrington', 'Creve Coeur', 'Hermitage', 'Oldsmar', 'Brandon', 'Jefferson', 'Metairie', 'New Port Richey', 'Tampa', 'Tucson', 'Meridian', 'Brentwood', 'Riverview', 'Sparks', 'Wesley Chapel', 'Fishers']),
#   'postal_count': 26},
#  'Ferman Chrysler Jeep Dodge RAM - Wesley Chapel': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Lutz']),
#   'postal_count': 1},
#  'Safelite AutoGlass': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'Tamarindos Restaurant': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Flourtown']),
#   'postal_count': 1},
#  'Envy Nail': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Santa Barbara County Courthouse': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'Indy Massage Company': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Oregon Steaks': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Felicias Pizza Kitchen': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Ardmore']),
#   'postal_count': 1},
#  'Casa Del Mar Inn': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'Thai Country Cafe': {'state': dict_keys(['MO']),
#   'city': dict_keys(['Saint Louis']),
#   'postal_count': 1},
#  'Liberty Bell Gastropub': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Bensalem']),
#   'postal_count': 1},
#  'Gourmet Pizza Company': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Cal Taco': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Goleta']),
#   'postal_count': 1},
#  'Pima Pet Clinic': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  "Scout's Pub": {'state': dict_keys(['TN']),
#   'city': dict_keys(['Franklin']),
#   'postal_count': 1},
#  'Rubyz Threading Studio': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Phone Repair Philly - Center City': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  "Morton's The Steakhouse": {'state': dict_keys(['PA', 'TN']),
#   'city': dict_keys(['King Of Prussia', 'Nashville']),
#   'postal_count': 2},
#  "Sisters' Nails and Spa": {'state': dict_keys(['IN']),
#   'city': dict_keys(['Whitestown']),
#   'postal_count': 1},
#  'Spot House Restaurant and Bar': {'state': dict_keys(['MO']),
#   'city': dict_keys(['Florissant']),
#   'postal_count': 1},
#  'Asian Pho': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'The Eagle Inn': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'Leather Surgeons': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Doylestown']),
#   'postal_count': 1},
#  'La Collina': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Bala Cynwyd']),
#   'postal_count': 1},
#  'Slices Pizza': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Green Eggs Cafe': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia', 'philadelphia']),
#   'postal_count': 4},
#  'Champion Chevrolet': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  "Pan D'olive": {'state': dict_keys(['MO']),
#   'city': dict_keys(['Saint Louis']),
#   'postal_count': 1},
#  'Szechuan House': {'state': dict_keys(['NJ']),
#   'city': dict_keys(['Hamilton']),
#   'postal_count': 1},
#  'Nashville Apartment Locators': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Blind Dog Tavern': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'The Centurion Lounge': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Nk Nails & Spa-Creve Coeur': {'state': dict_keys(['MO']),
#   'city': dict_keys(['Saint Louis']),
#   'postal_count': 1},
#  'Dugout Bar': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Tsunami Sushi & Hibachi Grill': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Brandon']),
#   'postal_count': 1},
#  "Frabotta's Beach Kitchen": {'state': dict_keys(['FL']),
#   'city': dict_keys(['Madeira Beach']),
#   'postal_count': 1},
#  'India Sizzling II': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Outback Steakhouse': {'state': dict_keys(['FL', 'TN', 'MO', 'LA', 'IN', 'NV', 'PA', 'NJ', 'AZ', 'ID']),
#   'city': dict_keys(['Brandon', 'Tampa', 'Lithia', 'Seminole', 'Brentwood', 'Sappington', 'Metairie', 'Indianapolis', 'Largo', 'Reno', 'Wesley Chapel', 'New Port Richey', 'Palm Harbor', 'Carmel', 'Jenkintown', 'Cherry Hill', 'Tucson', 'Boise', 'Sparks', 'Saint Petersburg', 'King Of Prussia', 'Bensalem', 'Springfield']),
#   'postal_count': 30},
#  "Ellington's": {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Strange Donuts': {'state': dict_keys(['MO']),
#   'city': dict_keys(['Maplewood']),
#   'postal_count': 1},
#  'Maple Street Patisserie': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'VCA Valley Animal Hospital and Emergency Center': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Flying Pie Pizzaria': {'state': dict_keys(['ID']),
#   'city': dict_keys(['Meridian', 'Boise']),
#   'postal_count': 3},
#  'RV One Superstores - Tampa': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Dover']),
#   'postal_count': 1},
#  'Allisonville Nursery': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Fishers']),
#   'postal_count': 1},
#  'The Grove Hotel': {'state': dict_keys(['ID']),
#   'city': dict_keys(['Boise']),
#   'postal_count': 1},
#  'Pontilly Coffee': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Intermezzo By Wine Cask': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'Aroma Indian Bistro': {'state': dict_keys(['NJ']),
#   'city': dict_keys(['Merchantville']),
#   'postal_count': 1},
#  'Sushi Tyme': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'Gaslight Theatre': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Natura Pest Control': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'Sabino Canyon': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Saloon 151': {'state': dict_keys(['PA']),
#   'city': dict_keys(['West Chester']),
#   'postal_count': 1},
#  'Char Restaurant': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  'Sierra Car Wash': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno', 'Sparks']),
#   'postal_count': 2},
#  "Porter & Luke's": {'state': dict_keys(['LA']),
#   'city': dict_keys(['Metairie']),
#   'postal_count': 1},
#  'Twin Peaks': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  "H & T's Homecooking": {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  "Andrea's Restaurant": {'state': dict_keys(['LA']),
#   'city': dict_keys(['Metairie']),
#   'postal_count': 1},
#  'Pupuseria & Cafeteria Centroamericana': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Top Notch Axe Throwing - St Louis': {'state': dict_keys(['MO']),
#   'city': dict_keys(['St. Louis']),
#   'postal_count': 1},
#  'High Brow Coffee + Tea': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Franklin']),
#   'postal_count': 1},
#  "Trader Joe's": {'state': dict_keys(['IN', 'FL', 'NV', 'TN', 'LA', 'PA']),
#   'city': dict_keys(['Indianapolis', 'Tampa', 'Reno', 'Saint Petersburg', 'Nashville', 'Metairie', 'Philadelphia']),
#   'postal_count': 8},
#  'Courtesy Hyundai Tampa': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Bai Wei': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'The Red Bicycle': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Nashville']),
#   'postal_count': 1},
#  '4:59 Barber Lounge': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Carnival Cruise Lines': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Belleair Coffee Company': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Belleair Bluffs']),
#   'postal_count': 1},
#  'Monon Coffee Company': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Tucson Massage Company': {'state': dict_keys(['AZ']),
#   'city': dict_keys(['Tucson']),
#   'postal_count': 1},
#  'Maher Chevrolet': {'state': dict_keys(['FL']),
#   'city': dict_keys(['St. Petersburg']),
#   'postal_count': 1},
#  'Urban Optics Optometric Center': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'Black Tie Moving': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Brentwood']),
#   'postal_count': 1},
#  'Cru Cellars - Palma Ceia': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Tampa']),
#   'postal_count': 1},
#  'Two Chicks Café - CBD': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Rockwell Beer Company': {'state': dict_keys(['MO']),
#   'city': dict_keys(['St. Louis']),
#   'postal_count': 1},
#  'The Cruisery': {'state': dict_keys(['CA']),
#   'city': dict_keys(['Santa Barbara']),
#   'postal_count': 1},
#  'LouVino': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'French Toast': {'state': dict_keys(['LA']),
#   'city': dict_keys(['New Orleans']),
#   'postal_count': 1},
#  'Daredevil Hall': {'state': dict_keys(['IN']),
#   'city': dict_keys(['Indianapolis']),
#   'postal_count': 1},
#  'Clayman Thyroid Center': {'state': dict_keys(['FL']),
#   'city': dict_keys(["Town 'n' Country"]),
#   'postal_count': 1},
#  'Mr and Mrs Crab': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Pinellas Park', 'Brandon', 'Clearwater', 'Tampa']),
#   'postal_count': 4},
#  'The Growler Guys': {'state': dict_keys(['NV']),
#   'city': dict_keys(['Reno']),
#   'postal_count': 1},
#  'R&D': {'state': dict_keys(['PA']),
#   'city': dict_keys(['Philadelphia']),
#   'postal_count': 1},
#  'Franklin Burger': {'state': dict_keys(['TN']),
#   'city': dict_keys(['Franklin']),
#   'postal_count': 1},
#  'Carnivore': {'state': dict_keys(['MO']),
#   'city': dict_keys(['St. Louis']),
#   'postal_count': 1},
#  'Pacific Counter': {'state': dict_keys(['FL']),
#   'city': dict_keys(['Saint Petersburg']),
#   'postal_count': 1},
#  ...}

# %% [markdown]
# # By State
# * Use FL for starters , only 7 seven cities

# %%
df = df[df.state == 'FL']

# %%
df.shape

# %%
for_lda_df = df.copy()

# %%
for_lda_df.shape

# %%
# get the restaurants that has branches in at least 3 different cities
for j in Counter(df.name):
    tmp = df[df.name==j]
    if len(Counter(tmp.city))<3:
        df = df.drop(tmp.index)
        df.reset_index()

# %%
df.shape

# %%
for_lda_df[~for_lda_df.name.isin(df.name)]

# %%
brand = Counter(df.name)
plt.bar(brand.keys(), brand.values())

# %%
df.to_pickle("../Data/yelp/FL_only.pkl")  
for_lda_df.to_pickle("../Data/yelp/LDA_training.pkl")

# %% [markdown]
# ## Observe the Ratings by Brand

# %%
# # count the cities by one brand 
# for i in Counter(df.name):
#     tmp = df[df.name==i]
#     print(Counter(tmp.city))

# %%
# Count the overall std for each brand
l_= []
for i in Counter(df.name):
    tmp = df[df.name==i]
    dict_ = tmp.stars_x.describe().to_dict()
    dict_['name']=i
    l_.append(dict_)
b = pd.DataFrame(l_)
b

# %%
# Count the std for each brand by city 
l_= []
for i in Counter(df.name):
    tmp = df[df.name==i]
    dict_ = tmp.stars_x.describe().to_dict()
    dict_['name']=i
    l_.append(dict_)
b = pd.DataFrame(l_)
b

# %% [markdown]
# ## Obeserve the postal code

# %%
len(Counter(df.postal_code))

# %%
len(Counter(df.city))
